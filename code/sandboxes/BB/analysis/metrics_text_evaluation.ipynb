# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanlucjackson/w266_final_project/blob/main/code/sandboxes/BB/analysis/metrics_text_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Metrics: Text Evaluation

# %% [markdown]
# ### Imports/Setup

# %%
from os import listdir
from os.path import isfile, join

import csv
import json
import pprint

import pandas as pd
from tqdm import tqdm
from sklearn.utils import shuffle

# %%
# This cell will authenticate you and mount your Drive in the Colab.
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
evaluation_root = "/content/drive/MyDrive/w266 NLP Final Project/Evaluation/"
filename = join(evaluation_root, "evaluation_database.json")

# Read JSON into dataframe
evaluation_df = pd.read_json(filename)

# %% [markdown]
# ### Clean up evaluation dataframe to only include columns needed for text analysis

# %%
# Clean up evaluation db df to only include columns needed for text analysis
clean_eval_df = evaluation_df[
    [
        "nickname",
        "base_model",
        "trained_on",
        "tested_on",
        "hyperparameter",
        "target",
        "prediction",
        "bleu",
        "rougeL",
        "meteor",
        "bertscore-f1",
        "use",
    ]
]

clean_eval_df
# Out:
#                    nickname base_model trained_on tested_on  \
# 0                bart_nq_nq       bart         nq        nq
# 1                bart_nq_nq       bart         nq        nq
# 2                bart_nq_nq       bart         nq        nq
# 3                bart_nq_nq       bart         nq        nq
# 4                bart_nq_nq       bart         nq        nq
# ...                     ...        ...        ...       ...
# 286285  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286286  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286287  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286288  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286289  T5_amalgam_triviaqa         T5    amalgam  triviaqa
#
#             hyperparameter                                             target  \
# 0       {'defaults': True}             what was the real name of saudi arabia
# 1       {'defaults': True}     whats the most liked picture on instagram 2018
# 2       {'defaults': True}      where does the movie proof of life take place
# 3       {'defaults': True}           where is net profit on the balance sheet
# 4       {'defaults': True}   when was fingerprinting first used by the police
# ...                    ...                                                ...
# 286285  {'defaults': True}  Which ex British daily newspaper was first pub...
# 286286  {'defaults': True}  Which cartoon character lived in Bunkerton Cas...
# 286287  {'defaults': True}  In which prison was 'Amy' born in the novel 'L...
# 286288  {'defaults': True}  The Sign Of Four was a detective story written...
# 286289  {'defaults': True}  Albacore, bigeye and longtail are species of w...
#
#                                                prediction      bleu    rougeL  \
# 0         what is the name of the kingdom of saudi arabia  0.000000  0.666667
# 1             what is the most liked picture on instagram  0.680375  0.750000
# 2                    where does alice go in the new movie  0.000000  0.470588
# 3       where does net profit come from in a financial...  0.000000  0.333333
# 4       when was fingerprint technology first used in ...  0.000000  0.588235
# ...                                                   ...       ...       ...
# 286285        What is the name of the city of Manchester?  0.000000  0.093023
# 286286  What was the name of Lord Marmaduke of Bunkerton?  0.000000  0.125000
# 286287  What is the name of the prison in Charles Dick...  0.000000  0.416667
# 286288  Who wrote the novels 'The Sign of Four' and 'A...  0.000000  0.400000
# 286289             What is the largest fish in the world?  0.000000  0.210526
#
#           meteor  bertscore-f1       use
# 0       0.623306      0.915830  0.794086
# 1       0.864796      0.932259  0.884909
# 2       0.354635      0.835192  0.517866
# 3       0.311653      0.856130  0.728012
# 4       0.694444      0.876353  0.704206
# ...          ...           ...       ...
# 286285  0.058309      0.679618  0.322748
# 286286  0.121951      0.794428  0.515345
# 286287  0.248227      0.821790  0.593840
# 286288  0.381426      0.796076  0.585255
# 286289  0.119048      0.769767  0.537810
#
# [286290 rows x 12 columns]

# %%
clean_eval_df["bertscore-f1"].describe()
# Out:
# count    286290.000000
# mean          0.789801
# std           0.082735
# min           0.521592
# 25%           0.729552
# 50%           0.784537
# 75%           0.845546
# max           1.000000
# Name: bertscore-f1, dtype: float64

# %%
clean_eval_df["use"].describe()
# Out:
# count    286290.000000
# mean          0.483113
# std           0.246386
# min          -0.147977
# 25%           0.291765
# 50%           0.487792
# 75%           0.671069
# max           1.000000
# Name: use, dtype: float64

# %%
clean_eval_df.describe()
# Out:
#                 bleu         rougeL         meteor   bertscore-f1  \
# count  286290.000000  286290.000000  286290.000000  286290.000000
# mean        0.048842       0.295583       0.279015       0.789801
# std         0.158423       0.233494       0.234177       0.082735
# min         0.000000       0.000000       0.000000       0.521592
# 25%         0.000000       0.125000       0.097087       0.729552
# 50%         0.000000       0.250000       0.200000       0.784537
# 75%         0.000000       0.428571       0.408791       0.845546
# max         1.000000       1.000000       0.999937       1.000000
#
#                  use
# count  286290.000000
# mean        0.483113
# std         0.246386
# min        -0.147977
# 25%         0.291765
# 50%         0.487792
# 75%         0.671069
# max         1.000000

# %% [markdown]
# ### Find the overall averages for each prediction set and metric

# %%
# Find the overall averages for each prediction set and metric
eval_means_df = clean_eval_df.groupby(["nickname"]).mean()

# Reset index so able to groupby and sort below to find top scoring prediction sets for each metric
eval_means_df = eval_means_df.reset_index("nickname")

eval_means_df = eval_means_df[["nickname", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]]
eval_means_df
# Out:
#                   nickname      bleu    rougeL    meteor  bertscore-f1  \
# 0            T5_amalgam_nq  0.169746  0.527758  0.497871      0.858036
# 1          T5_amalgam_quac  0.053671  0.249039  0.262385      0.778060
# 2         T5_amalgam_squad  0.142885  0.470772  0.469798      0.867048
# 3      T5_amalgam_triviaqa  0.066390  0.359130  0.337926      0.822766
# 4                 T5_nq_nq  0.172979  0.527675  0.497261      0.859476
# 5               T5_nq_quac  0.001471  0.151900  0.111625      0.696885
# 6              T5_nq_squad  0.017446  0.346182  0.273460      0.791693
# 7           T5_nq_triviaqa  0.007450  0.278408  0.189823      0.766649
# 8               T5_quac_nq  0.000000  0.068525  0.040712      0.662784
# 9             T5_quac_quac  0.023456  0.173453  0.189914      0.756046
# 10           T5_quac_squad  0.000392  0.096745  0.097564      0.714181
# 11        T5_quac_triviaqa  0.000006  0.043162  0.056670      0.676198
# 12             T5_squad_nq  0.011952  0.415383  0.357760      0.799702
# 13           T5_squad_quac  0.007131  0.185156  0.207983      0.753711
# 14          T5_squad_squad  0.147281  0.467739  0.467691      0.868757
# 15       T5_squad_triviaqa  0.022352  0.265502  0.221913      0.788757
# 16          T5_triviaqa_nq  0.008441  0.308986  0.319191      0.781309
# 17        T5_triviaqa_quac  0.001679  0.110604  0.160580      0.715610
# 18       T5_triviaqa_squad  0.042573  0.280593  0.327971      0.808893
# 19    T5_triviaqa_triviaqa  0.055784  0.337024  0.323068      0.816313
# 20         bart_amalgam_nq  0.196693  0.545003  0.523538      0.864331
# 21       bart_amalgam_quac  0.027411  0.233675  0.250150      0.770516
# 22      bart_amalgam_squad  0.135813  0.458580  0.460132      0.862849
# 23   bart_amalgam_triviaqa  0.077973  0.368721  0.354559      0.826420
# 24              bart_nq_nq  0.203072  0.550431  0.528802      0.867402
# 25            bart_nq_quac  0.001083  0.149609  0.112613      0.697180
# 26           bart_nq_squad  0.014385  0.322623  0.252032      0.783824
# 27        bart_nq_triviaqa  0.007997  0.286437  0.200833      0.770833
# 28            bart_quac_nq  0.005041  0.326124  0.224375      0.750539
# 29          bart_quac_quac  0.057220  0.282748  0.288054      0.792803
# 30         bart_quac_squad  0.027720  0.290898  0.245610      0.802949
# 31      bart_quac_triviaqa  0.006868  0.197812  0.150911      0.755470
# 32           bart_squad_nq  0.011793  0.410598  0.355301      0.798603
# 33         bart_squad_quac  0.007123  0.184176  0.205870      0.753976
# 34        bart_squad_squad  0.151242  0.469155  0.475293      0.869525
# 35     bart_squad_triviaqa  0.021929  0.260254  0.219060      0.788075
# 36        bart_triviaqa_nq  0.011421  0.365830  0.367585      0.795629
# 37      bart_triviaqa_quac  0.001459  0.113614  0.162960      0.709303
# 38     bart_triviaqa_squad  0.047023  0.310570  0.337941      0.816628
# 39  bart_triviaqa_triviaqa  0.075994  0.367775  0.350981      0.825904
#
#          use
# 0   0.719863
# 1   0.378001
# 2   0.656399
# 3   0.601577
# 4   0.718928
# 5   0.287737
# 6   0.554671
# 7   0.518441
# 8   0.180669
# 9   0.303081
# 10  0.166183
# 11  0.119212
# 12  0.633868
# 13  0.320500
# 14  0.650666
# 15  0.494978
# 16  0.572548
# 17  0.244592
# 18  0.499839
# 19  0.591368
# 20  0.729291
# 21  0.363810
# 22  0.650527
# 23  0.609191
# 24  0.736651
# 25  0.286565
# 26  0.540661
# 27  0.534304
# 28  0.516567
# 29  0.418768
# 30  0.445580
# 31  0.396791
# 32  0.630303
# 33  0.318477
# 34  0.657032
# 35  0.492134
# 36  0.622989
# 37  0.243177
# 38  0.535130
# 39  0.607768

# %% [markdown]
# ### Create BART and T5 dataframes to use if want to focus on one

# %%
# Create BART dataframe
bart_df = clean_eval_df[clean_eval_df["base_model"] == "bart"]

# %%
# Create T5 dataframe
t5_df = clean_eval_df[clean_eval_df["base_model"] == "T5"]

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ## BERTScore vs. USE Scores

# %% [markdown]
# ### BERTScore > USE

# %% [markdown]
# All Models: BERTScore > USE

# %%
# Find predictions with semantic metric score differences

sem_diff = clean_eval_df[
    (clean_eval_df["bertscore-f1"] >= 0.85)  # top 25th percentile bertscore
    & (clean_eval_df["use"] <= 0.3)   # bottom 25th percentile use
]

sem_diff = sem_diff.sort_values(by="use", ascending=False)

sem_diff
# Out:
#                    nickname base_model trained_on tested_on  \
# 244410    T5_triviaqa_squad         T5   triviaqa     squad
# 240950    T5_triviaqa_squad         T5   triviaqa     squad
# 97805   bart_triviaqa_squad       bart   triviaqa     squad
# 75697      bart_squad_squad       bart      squad     squad
# 91534    bart_triviaqa_quac       bart   triviaqa      quac
# ...                     ...        ...        ...       ...
# 162552       T5_nq_triviaqa         T5         nq  triviaqa
# 247493    T5_triviaqa_squad         T5   triviaqa     squad
# 45397       bart_quac_squad       bart       quac     squad
# 238618    T5_triviaqa_squad         T5   triviaqa     squad
# 102655  bart_triviaqa_squad       bart   triviaqa     squad
#
#             hyperparameter                                             target  \
# 244410  {'defaults': True}                    What are Plastoglobuli made of?
# 240950  {'defaults': True}  A molecular phylogeny analysis confirmed that ...
# 97805   {'defaults': True}  A molecular phylogeny analysis confirmed that ...
# 75697   {'defaults': True}              What is one work by Olivier Messiaen?
# 91534   {'defaults': True}                             What was Azarath like?
# ...                    ...                                                ...
# 162552  {'defaults': True}       Hedonophobia is the irrational fear of what?
# 247493  {'defaults': True}  What are the small tentacles on Cydippids called?
# 45397   {'defaults': True}  Along with private individuals and organizatio...
# 238618  {'defaults': True}      What do Plastoglobuli exchange contents with?
# 102655  {'defaults': True}  Along with private individuals and organizatio...
#
#                                                prediction      bleu    rougeL  \
# 244410  The plastoglobules are spherical bubbles of what?  0.000000  0.333333
# 240950                        The cydippids are not what?  0.220834  0.400000
# 97805                         The cydippids are not what?  0.220834  0.400000
# 75697          What was the name of Messiaen's 1935 work?  0.000000  0.250000
# 91534   What was the name of the alternate dimension c...  0.000000  0.428571
# ...                                                   ...       ...       ...
# 162552                what is the meaning of hedonophobia  0.000000  0.461538
# 247493                           The cydippids have what?  0.000000  0.333333
# 45397                          What is Ergänzungsschulen?  0.000000  0.375000
# 238618   The plastoglobulus is anchored to which network?  0.000000  0.000000
# 102655                 Ergänzungsschulen are German what?  0.000000  0.235294
#
#           meteor  bertscore-f1       use
# 244410  0.322581      0.899336  0.299999
# 240950  0.474286      0.857079  0.299485
# 97805   0.474286      0.857079  0.299485
# 75697   0.243902      0.859928  0.299191
# 91534   0.563616      0.871783  0.298804
# ...          ...           ...       ...
# 162552  0.476923      0.859920  0.113248
# 247493  0.232558      0.873061  0.102150
# 45397   0.211203      0.871793  0.083942
# 238618  0.070423      0.862789  0.066797
# 102655  0.122951      0.851867  0.059189
#
# [184 rows x 12 columns]

# %% [markdown]
# Fairly good examples when looking at bottom two...

# %%
# Convert to Latex

# Take bottom two scoring ones
sem_diff = sem_diff.tail(2)

# Printe entire text
with pd.option_context("max_colwidth", 1000):
    print (sem_diff[["target", "prediction"]].to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                                                                          target &                                       prediction \\
# \midrule
#                                                   What do Plastoglobuli exchange contents with? & The plastoglobulus is anchored to which network? \\
# Along with private individuals and organizations, what groups sometimes runs ergänzungsschulen? &               Ergänzungsschulen are German what? \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# Not great examples when random shuffle...

# %%
# Convert to Latex

# Take random two scoring ones
sem_diff = shuffle(sem_diff).tail(2)

# Printe entire text
with pd.option_context("max_colwidth", 1000):
    print (sem_diff[["target", "prediction"]].to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                                                                  target &                                                prediction \\
# \midrule
# How much did the second stage increase thrust by with the integration of the S-IVB-200? &                       How much weight did the S-IVB have? \\
#                                                   What plateau has groups of clay pits? & What plateau has only a few natural and artificial ponds? \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# BART Model: BERScore > USE

# %%
# Find BART predictions with semantic metric score differences
# Specifically chose trained on = amalgam because high performing model

bart_sem_diff = bart_df[
    (bart_df["trained_on"] == "amalgam")
    & (bart_df["bertscore-f1"] >= 0.85)  # top 25th percentile bertscore
    & (bart_df["use"] <= 0.3)   # bottom 25th percentile use
]

bart_sem_diff = bart_sem_diff.sort_values(by="use", ascending=False)

bart_sem_diff
# Out:
#                      nickname base_model trained_on tested_on  \
# 128985     bart_amalgam_squad       bart    amalgam     squad
# 119148      bart_amalgam_quac       bart    amalgam      quac
# 125258     bart_amalgam_squad       bart    amalgam     squad
# 118099      bart_amalgam_quac       bart    amalgam      quac
# 130667     bart_amalgam_squad       bart    amalgam     squad
# 129804     bart_amalgam_squad       bart    amalgam     squad
# 123000     bart_amalgam_squad       bart    amalgam     squad
# 127483     bart_amalgam_squad       bart    amalgam     squad
# 120975      bart_amalgam_quac       bart    amalgam      quac
# 122949     bart_amalgam_squad       bart    amalgam     squad
# 130202     bart_amalgam_squad       bart    amalgam     squad
# 131113     bart_amalgam_squad       bart    amalgam     squad
# 127562     bart_amalgam_squad       bart    amalgam     squad
# 133239     bart_amalgam_squad       bart    amalgam     squad
# 123088     bart_amalgam_squad       bart    amalgam     squad
# 127146     bart_amalgam_squad       bart    amalgam     squad
# 131987     bart_amalgam_squad       bart    amalgam     squad
# 142535  bart_amalgam_triviaqa       bart    amalgam  triviaqa
# 122705      bart_amalgam_quac       bart    amalgam      quac
# 126980     bart_amalgam_squad       bart    amalgam     squad
#
#             hyperparameter                                             target  \
# 128985  {'defaults': True}     What type of support does co-teaching provide?
# 119148  {'defaults': True}                    What was Dana's character like?
# 125258  {'defaults': True}                 Where is the Tyneside Bar located?
# 118099  {'defaults': True}                  What was Brando's lifestyle like?
# 130667  {'defaults': True}                  How are ergänzungsschulen funded?
# 129804  {'defaults': True}  What do current ctenophores have that fossils ...
# 123000  {'defaults': True}  What were the fossils that were found to repre...
# 127483  {'defaults': True}         Who were two of Kublai's Chinese advisers?
# 120975  {'defaults': True}  did he break any other records with speed boat...
# 122949  {'defaults': True}                           What do pyrenoids store?
# 130202  {'defaults': True}  In what geographical portion of Wales is Aberc...
# 131113  {'defaults': True}                      What shape are Plastoglobuli?
# 127562  {'defaults': True}  What Revolutionary War midnight rider was a Hu...
# 133239  {'defaults': True}  What proclamation officially ended limited Hug...
# 123088  {'defaults': True}  What process down the line does rubisco's flaw...
# 127146  {'defaults': True}  Who explained that inertial reference frames e...
# 131987  {'defaults': True}                       What do pyrenoids look like?
# 142535  {'defaults': True}  The substances isoflurane, desflurane, nitrous...
# 122705  {'defaults': True}      What was the reaction to the 2009 revelation?
# 126980  {'defaults': True}                What does phycoerytherin appear in?
#
#                                                prediction  bleu    rougeL  \
# 128985  What does co-teaching provide to students to r...   0.0  0.476190
# 119148                           What was Scully's faith?   0.0  0.545455
# 125258      What extension does the Tyneside Cinema have?   0.0  0.307692
# 118099         What was Brando's reputation as a bad boy?   0.0  0.533333
# 130667    What does Ergungsschulen charge their students?   0.0  0.000000
# 129804              What are ctenophores thought to have?   0.0  0.352941
# 123000              What are ctenophores thought to have?   0.0  0.285714
# 127483  Who gave strong influence to Kublai's early co...   0.0  0.352941
# 120975                       Did he win any other awards?   0.0  0.533333
# 122949       What is accumulated as the pyrenoids mature?   0.0  0.363636
# 130202                   In what direction was Abercynon?   0.0  0.428571
# 131113          what are plastoglobuli in the chloroplast   0.0  0.600000
# 127562          Who was descended from Huguenot refugees?   0.0  0.266667
# 133239  What document ended Protestant rule in Montpel...   0.0  0.285714
# 123088                           What cycle uses rubisco?   0.0  0.266667
# 127146     Who extended the principle of inertia further?   0.0  0.100000
# 131987   Pyrenoids are spherical and what kind of bodies?   0.0  0.153846
# 142535  Sevoflurane, halothane and Halothane are all t...   0.0  0.260870
# 122705     What was Graham's response to the Nixon tapes?   0.0  0.470588
# 126980  Phycoerytherin is one of the pigments that mak...   0.0  0.133333
#
#           meteor  bertscore-f1       use
# 128985  0.524706      0.864651  0.298659
# 119148  0.457428      0.863713  0.297248
# 125258  0.359937      0.853858  0.296461
# 118099  0.663014      0.890210  0.295167
# 130667  0.096154      0.868782  0.287752
# 129804  0.274457      0.886462  0.282767
# 123000  0.209023      0.863050  0.280719
# 127483  0.346841      0.872934  0.278422
# 120975  0.459794      0.863179  0.273609
# 122949  0.283019      0.892096  0.272564
# 130202  0.328776      0.873489  0.269368
# 131113  0.501089      0.886374  0.266173
# 127562  0.206186      0.872630  0.264109
# 133239  0.187500      0.854998  0.262742
# 123088  0.132743      0.853177  0.245138
# 127146  0.074627      0.850367  0.240342
# 131987  0.238095      0.865828  0.238289
# 142535  0.173410      0.868395  0.222146
# 122705  0.490110      0.859419  0.212422
# 126980  0.230769      0.854091  0.152763

# %%
# Convert to Latex

# Take bottom two scoring ones
bart_sem_diff = bart_sem_diff.tail(2)

# Printe entire text
with pd.option_context("max_colwidth", 1000):
    print (bart_sem_diff[["target", "prediction"]].to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                        target &                                                 prediction \\
# \midrule
# What was the reaction to the 2009 revelation? &             What was Graham's response to the Nixon tapes? \\
#           What does phycoerytherin appear in? & Phycoerytherin is one of the pigments that makes what red? \\
# \bottomrule
# \end{tabular}

# %%
# Convert to Latex

# Take bottom two random ones
bart_sem_diff = shuffle(bart_sem_diff).tail(2)

# Print entire text
with pd.option_context("max_colwidth", 1000):
    print (bart_sem_diff[["target", "prediction"]].to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                        target &                                                 prediction \\
# \midrule
#           What does phycoerytherin appear in? & Phycoerytherin is one of the pigments that makes what red? \\
# What was the reaction to the 2009 revelation? &             What was Graham's response to the Nixon tapes? \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# T5 Model: BERScore > USE

# %%
# Find T5 predictions with semantic metric score differences

t5_sem_diff = t5_df[
    (t5_df["trained_on"] == "amalgam")
    & (t5_df["bertscore-f1"] >= 0.85)  # top 25th percentile bertscore
    & (t5_df["use"] <= 0.3)   # bottom 25th percentile use
]

t5_sem_diff = t5_sem_diff.sort_values(by="use", ascending=False)

t5_sem_diff
# Out:
#                    nickname base_model trained_on tested_on  \
# 260520      T5_amalgam_quac         T5    amalgam      quac
# 273812     T5_amalgam_squad         T5    amalgam     squad
# 272728     T5_amalgam_squad         T5    amalgam     squad
# 272909     T5_amalgam_squad         T5    amalgam     squad
# 285236  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 270069     T5_amalgam_squad         T5    amalgam     squad
# 271355     T5_amalgam_squad         T5    amalgam     squad
# 284105  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 270628     T5_amalgam_squad         T5    amalgam     squad
# 276384     T5_amalgam_squad         T5    amalgam     squad
# 264120      T5_amalgam_quac         T5    amalgam      quac
# 266094     T5_amalgam_squad         T5    amalgam     squad
# 270707     T5_amalgam_squad         T5    amalgam     squad
# 270251     T5_amalgam_squad         T5    amalgam     squad
# 285641  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 266233     T5_amalgam_squad         T5    amalgam     squad
# 267766     T5_amalgam_squad         T5    amalgam     squad
# 270291     T5_amalgam_squad         T5    amalgam     squad
# 276496  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 270125     T5_amalgam_squad         T5    amalgam     squad
# 280753  T5_amalgam_triviaqa         T5    amalgam  triviaqa
#
#             hyperparameter                                             target  \
# 260520  {'defaults': True}                 Who's mistress was Lillie Langtry?
# 273812  {'defaults': True}                  How are ergänzungsschulen funded?
# 272728  {'defaults': True}                           What are phycobilisomes?
# 272909  {'defaults': True}              What plateau has groups of clay pits?
# 285236  {'defaults': True}  What is an oblation in relation to a god? Offe...
# 270069  {'defaults': True}                           What does isobaric mean?
# 271355  {'defaults': True}  What is inequality associated with higher leve...
# 284105  {'defaults': True}                     What does a costermonger sell?
# 270628  {'defaults': True}         Who were two of Kublai's Chinese advisers?
# 276384  {'defaults': True}  What proclamation officially ended limited Hug...
# 264120  {'defaults': True}  did he break any other records with speed boat...
# 266094  {'defaults': True}                           What do pyrenoids store?
# 270707  {'defaults': True}  What Revolutionary War midnight rider was a Hu...
# 270251  {'defaults': True}                         What does rhodophyte mean?
# 285641  {'defaults': True}  The ports of Puck and Jastarnia are in which E...
# 266233  {'defaults': True}  What process down the line does rubisco's flaw...
# 267766  {'defaults': True}  Does BSkyB carry any control over the picture ...
# 270291  {'defaults': True}  Who explained that inertial reference frames e...
# 276496  {'defaults': True}  The substances isoflurane, desflurane, nitrous...
# 270125  {'defaults': True}                What does phycoerytherin appear in?
# 280753  {'defaults': True}       Heliculture is the farming of what for food?
#
#                                                prediction      bleu    rougeL  \
# 260520           Who was Albert Edward Langtry's husband?  0.000000  0.461538
# 273812   What do Ergänzungsschulen charge their students?  0.000000  0.333333
# 272728           What do phycobilins often organize into?  0.000000  0.222222
# 272909  What plateau has only a few natural and artifi...  0.000000  0.352941
# 285236                               What is an oblation?  0.042999  0.444444
# 270069        What isobaric process in the Rankine cycle?  0.000000  0.363636
# 271355  What is associated with lower levels of growth...  0.000000  0.545455
# 284105  The term costermonger refers to a street selle...  0.000000  0.133333
# 270628  Who gave strong influence to Kublai's early co...  0.000000  0.352941
# 276384        What gave Protestant rule to the Huguenots?  0.000000  0.142857
# 264120                       Did he win any other awards?  0.000000  0.533333
# 266094           What is accumulated as pyrenoids mature?  0.000000  0.400000
# 270707          Who was descended from Huguenot refugees?  0.000000  0.266667
# 270251        What is the name of the rhodophyte lineage?  0.000000  0.333333
# 285641    Jastarnia is a seaside resort in which country?  0.000000  0.421053
# 266233                           What cycle uses rubisco?  0.000000  0.266667
# 267766  What is BSkyB's control over the content and c...  0.000000  0.347826
# 270291     Who extended the principle of inertia further?  0.000000  0.100000
# 276496                       Desflurane is used for what?  0.000000  0.315789
# 270125  phycoerytherin is one of the pigments that mak...  0.000000  0.142857
# 280753                             What is heliciculture?  0.000000  0.181818
#
#           meteor  bertscore-f1       use
# 260520  0.352113      0.861289  0.297351
# 273812  0.192308      0.928205  0.295489
# 272728  0.232558      0.878591  0.292014
# 272909  0.451807      0.865636  0.290550
# 285236  0.275000      0.864237  0.286224
# 270069  0.283019      0.855307  0.283750
# 271355  0.661139      0.869704  0.283681
# 284105  0.307692      0.851562  0.282168
# 270628  0.346841      0.872934  0.278422
# 276384  0.187500      0.872132  0.274933
# 264120  0.459794      0.863179  0.273609
# 266094  0.288462      0.909701  0.271904
# 270707  0.206186      0.872630  0.264109
# 270251  0.277778      0.905421  0.261391
# 285641  0.381197      0.861446  0.258191
# 266233  0.132743      0.853177  0.245138
# 267766  0.345736      0.851130  0.241391
# 270291  0.074627      0.850367  0.240342
# 276496  0.119048      0.864587  0.190536
# 270125  0.234375      0.867001  0.168940
# 280753  0.176471      0.882001  0.122069

# %% [markdown]
# ### BERTScore < USE

# %% [markdown]
# All Models: BERScore < USE

# %%
# Find predictions with semantic metric score differences

sem_diff = clean_eval_df[
    (clean_eval_df["bertscore-f1"] <= 0.73)  # top 25th percentile bertscore
    & (clean_eval_df["use"] >= 0.68)   # bottom 25th percentile use 
]

sem_diff = sem_diff.sort_values(by="bertscore-f1", ascending=False)

sem_diff
# Out:
#                   nickname base_model trained_on tested_on  \
# 10484        bart_nq_squad       bart         nq     squad
# 166068      T5_nq_triviaqa         T5         nq  triviaqa
# 258358       T5_amalgam_nq         T5    amalgam        nq
# 123714  bart_amalgam_squad       bart    amalgam     squad
# 200551         T5_squad_nq         T5      squad        nq
# ...                    ...        ...        ...       ...
# 229486      T5_triviaqa_nq         T5   triviaqa        nq
# 158827         T5_nq_squad         T5         nq     squad
# 23063     bart_nq_triviaqa       bart         nq  triviaqa
# 154927         T5_nq_squad         T5         nq     squad
# 163296      T5_nq_triviaqa         T5         nq  triviaqa
#
#             hyperparameter                                             target  \
# 10484   {'defaults': True}  How many pounds of steam per kilowatt hour doe...
# 166068  {'defaults': True}                        What pope resigned in 2013?
# 258358  {'defaults': True}  what is the number of total presidential elect...
# 123714  {'defaults': True}         Which running back did the Panthers waive?
# 200551  {'defaults': True}       when did lynyrd skynyrd's plane crash happen
# ...                    ...                                                ...
# 229486  {'defaults': True}  when did lionel messi play his first game for ...
# 158827  {'defaults': True}                                Who did Emma Marry?
# 23063   {'defaults': True}  Which of England's 1966 World Cup winning foot...
# 154927  {'defaults': True}  What were the win/loss game stats for the Denv...
# 163296  {'defaults': True}   Author J.R.R. Tolkien was born in which country?
#
#                                                prediction  bleu    rougeL  \
# 10484                what is the weight of a steam engine   0.0  0.272727
# 166068     who was the last pope to leave the pontificate   0.0  0.142857
# 258358   how many electors are there in the united states   0.0  0.111111
# 123714              who played for the panthers last year   0.0  0.285714
# 200551                 When did the Convair CV-240 crash?   0.0  0.400000
# ...                                                   ...   ...       ...
# 229486  The Messi family moved to Camp Nou in which year?   0.0  0.100000
# 158827  who was the king of england who married emma i...   0.0  0.266667
# 23063         who played for fulham in the premier league   0.0  0.347826
# 154927  how many times did the broncos win the super bowl   0.0  0.230769
# 163296          where did the last name tolkien come from   0.0  0.111111
#
#           meteor  bertscore-f1       use
# 10484   0.139860      0.729795  0.681846
# 166068  0.079365      0.729795  0.690938
# 258358  0.111111      0.729511  0.697076
# 123714  0.323488      0.729367  0.689400
# 200551  0.323488      0.729049  0.683831
# ...          ...           ...       ...
# 229486  0.049505      0.694685  0.692701
# 158827  0.267857      0.694451  0.756505
# 23063   0.246711      0.694070  0.720818
# 154927  0.097403      0.690972  0.680442
# 163296  0.051020      0.676919  0.710970
#
# [107 rows x 12 columns]

# %%
# Convert to Latex


# Take random two scoring ones
sem_diff = shuffle(sem_diff).head(2)

# Printe entire text
with pd.option_context("max_colwidth", 1000):
    print (sem_diff[["target", "prediction"]].to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                 target &                                prediction \\
# \midrule
#               Who won Super Bowl XLIX? & who did the broncos play in the superbowl \\
# what is the role of hcl in the stomach &           What does hydrochloric acid do? \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# BART Model: BERScore < USE

# %%
# Find BART predictions with semantic metric score differences

bart_sem_diff = bart_df[
    (bart_df["trained_on"] == "amalgam")
    & (bart_df["bertscore-f1"] <= 0.73)  # top 25th percentile bertscore
    & (bart_df["use"] >= 0.68)   # bottom 25th percentile use 
]

bart_sem_diff = bart_sem_diff.sort_values(by="use", ascending=False)

bart_sem_diff
# Out:
#                   nickname base_model trained_on tested_on  \
# 125783  bart_amalgam_squad       bart    amalgam     squad
# 115782     bart_amalgam_nq       bart    amalgam        nq
# 115573     bart_amalgam_nq       bart    amalgam        nq
# 132996  bart_amalgam_squad       bart    amalgam     squad
# 128982  bart_amalgam_squad       bart    amalgam     squad
# 123714  bart_amalgam_squad       bart    amalgam     squad
#
#             hyperparameter                                             target  \
# 125783  {'defaults': True}  What was the number of times the Denver Bronco...
# 115782  {'defaults': True}              where does us highway 1 start and end
# 115573  {'defaults': True}     when does season 7 game of thrones dvd release
# 132996  {'defaults': True}                           Who won Super Bowl XLIX?
# 128982  {'defaults': True}                           Who won Super Bowl XLIX?
# 123714  {'defaults': True}         Which running back did the Panthers waive?
#
#                                                prediction  bleu    rougeL  \
# 125783  how many times have the broncos been to the su...   0.0  0.250000
# 115782  where is the longest highway in the united states   0.0  0.235294
# 115573  when does the new season of the walking dead c...   0.0  0.400000
# 132996          who did the broncos play in the superbowl   0.0  0.153846
# 128982          who did the broncos play in the superbowl   0.0  0.153846
# 123714              who played for the panthers last year   0.0  0.285714
#
#           meteor  bertscore-f1       use
# 125783  0.092166      0.718619  0.827251
# 115782  0.123457      0.710291  0.708976
# 115573  0.343071      0.721894  0.707510
# 132996  0.080645      0.709131  0.704499
# 128982  0.080645      0.709131  0.704499
# 123714  0.323488      0.729367  0.689400

# %% [markdown]
# T5 Model: BERScore < USE

# %%
# Find T5 predictions with semantic metric score differences

t5_sem_diff = t5_df[
    (t5_df["trained_on"] == "amalgam")
    & (t5_df["bertscore-f1"] <= 0.73)  # top 25th percentile bertscore
    & (t5_df["use"] >= 0.68)   # bottom 25th percentile use
]

t5_sem_diff = t5_sem_diff.sort_values(by="use", ascending=False)

t5_sem_diff
# Out:
#              nickname base_model trained_on tested_on      hyperparameter  \
# 258767  T5_amalgam_nq         T5    amalgam        nq  {'defaults': True}
# 258358  T5_amalgam_nq         T5    amalgam        nq  {'defaults': True}
# 259720  T5_amalgam_nq         T5    amalgam        nq  {'defaults': True}
# 259792  T5_amalgam_nq         T5    amalgam        nq  {'defaults': True}
# 258817  T5_amalgam_nq         T5    amalgam        nq  {'defaults': True}
#
#                                                    target  \
# 258767      who will take the throne after the queen dies
# 258358  what is the number of total presidential elect...
# 259720  when is the first a revealed in pretty little ...
# 259792         who sings the rap in baby by justin bieber
# 258817             what is the role of hcl in the stomach
#
#                                                prediction  bleu    rougeL  \
# 258767     who is the heir apparent of queen elizabeth II   0.0  0.333333
# 258358   how many electors are there in the united states   0.0  0.111111
# 259720                 when does mona vanderwaal become a   0.0  0.250000
# 259792  who sings baby baby baby oh i thought you woul...   0.0  0.272727
# 258817                    What does hydrochloric acid do?   0.0  0.142857
#
#           meteor  bertscore-f1       use
# 258767  0.166667      0.728162  0.701911
# 258358  0.111111      0.729511  0.697076
# 259720  0.104167      0.714545  0.691913
# 259792  0.271868      0.704157  0.684645
# 258817  0.057471      0.727882  0.680623

# %% [markdown]
# ## All Perfect Scores

# %%
# Find BART predictions with all metric scores of 100

bart_df_perf = bart_df[
    (bart_df["bleu"] >= 0.99)
    & (bart_df["rougeL"] >= 0.99)
    & (bart_df["meteor"] >= 0.99)
    & (bart_df["bertscore-f1"] >= 0.99)
    & (bart_df["use"] >= 0.99)
]

bart_df_perf = bart_df_perf.sort_values(by="use", ascending=False)

bart_df_perf
# Out:
#                   nickname base_model trained_on tested_on  \
# 126408  bart_amalgam_squad       bart    amalgam     squad
# 69887     bart_squad_squad       bart      squad     squad
# 69150     bart_squad_squad       bart      squad     squad
# 125247  bart_amalgam_squad       bart    amalgam     squad
# 74609     bart_squad_squad       bart      squad     squad
# ...                    ...        ...        ...       ...
# 119041   bart_amalgam_quac       bart    amalgam      quac
# 66602     bart_squad_squad       bart      squad     squad
# 123860  bart_amalgam_squad       bart    amalgam     squad
# 132600  bart_amalgam_squad       bart    amalgam     squad
# 2109            bart_nq_nq       bart         nq        nq
#
#             hyperparameter                                           target  \
# 126408  {'defaults': True}              When was the 8-4-4 system launched?
# 69887   {'defaults': True}    How often do Parliament elections take place?
# 69150   {'defaults': True}              When was the 8-4-4 system launched?
# 125247  {'defaults': True}                    When did Ronald Robinson die?
# 74609   {'defaults': True}    How often do Parliament elections take place?
# ...                    ...                                              ...
# 119041  {'defaults': True}              How did the album do on the charts?
# 66602   {'defaults': True}         When was the University Library founded?
# 123860  {'defaults': True}         When was the University Library founded?
# 132600  {'defaults': True}  What is the main gap to continued urbanization?
# 2109    {'defaults': True}       where did the battle of corinth take place
#
#                                              prediction  bleu  rougeL  \
# 126408              When was the 8-4-4 system launched?   1.0     1.0
# 69887     How often do Parliament elections take place?   1.0     1.0
# 69150               When was the 8-4-4 system launched?   1.0     1.0
# 125247                    When did Ronald Robinson die?   1.0     1.0
# 74609     How often do Parliament elections take place?   1.0     1.0
# ...                                                 ...   ...     ...
# 119041              How did the album do on the charts?   1.0     1.0
# 66602          When was the University Library founded?   1.0     1.0
# 123860         When was the University Library founded?   1.0     1.0
# 132600  What is the main gap to continued urbanization?   1.0     1.0
# 2109         where did the battle of corinth take place   1.0     1.0
#
#           meteor  bertscore-f1       use
# 126408  0.998542           1.0  1.000000
# 69887   0.999023           1.0  1.000000
# 69150   0.998542           1.0  1.000000
# 125247  0.997685           1.0  1.000000
# 74609   0.999023           1.0  1.000000
# ...          ...           ...       ...
# 119041  0.999314           1.0  0.999999
# 66602   0.998542           1.0  0.999999
# 123860  0.998542           1.0  0.999999
# 132600  0.999314           1.0  0.999999
# 2109    0.999023           1.0  0.999999
#
# [1510 rows x 12 columns]

# %%
# Find T5 predictions with all metric scores of 100

t5_df_perf = t5_df[
    (t5_df["bleu"] >= 0.99)
    & (t5_df["rougeL"] >= 0.99)
    & (t5_df["meteor"] >= 0.99)
    & (t5_df["bertscore-f1"] >= 0.99)
    & (t5_df["use"] >= 0.99)
]

t5_df_perf = t5_df_perf.sort_values(by="use", ascending=False)

t5_df_perf
# Out:
#                 nickname base_model trained_on tested_on      hyperparameter  \
# 274775  T5_amalgam_squad         T5    amalgam     squad  {'defaults': True}
# 217754    T5_squad_squad         T5      squad     squad  {'defaults': True}
# 270290  T5_amalgam_squad         T5    amalgam     squad  {'defaults': True}
# 269553  T5_amalgam_squad         T5    amalgam     squad  {'defaults': True}
# 213032    T5_squad_squad         T5      squad     squad  {'defaults': True}
# ...                  ...        ...        ...       ...                 ...
# 272177  T5_amalgam_squad         T5    amalgam     squad  {'defaults': True}
# 271652  T5_amalgam_squad         T5    amalgam     squad  {'defaults': True}
# 275745  T5_amalgam_squad         T5    amalgam     squad  {'defaults': True}
# 209747    T5_squad_squad         T5      squad     squad  {'defaults': True}
# 267005  T5_amalgam_squad         T5    amalgam     squad  {'defaults': True}
#
#                                                    target  \
# 274775                    Who did Philip I want to marry?
# 217754      How often do Parliament elections take place?
# 270290      How often do Parliament elections take place?
# 269553                When was the 8-4-4 system launched?
# 213032      How often do Parliament elections take place?
# ...                                                   ...
# 272177  Who organized the trees of the Amazon into fou...
# 271652                 What was Joseph Haas arrested for?
# 275745    What is the main gap to continued urbanization?
# 209747           When was the University Library founded?
# 267005           When was the University Library founded?
#
#                                                prediction  bleu  rougeL  \
# 274775                    Who did Philip I want to marry?   1.0     1.0
# 217754      How often do Parliament elections take place?   1.0     1.0
# 270290      How often do Parliament elections take place?   1.0     1.0
# 269553                When was the 8-4-4 system launched?   1.0     1.0
# 213032      How often do Parliament elections take place?   1.0     1.0
# ...                                                   ...   ...     ...
# 272177  Who organized the trees of the Amazon into fou...   1.0     1.0
# 271652                 What was Joseph Haas arrested for?   1.0     1.0
# 275745    What is the main gap to continued urbanization?   1.0     1.0
# 209747           When was the University Library founded?   1.0     1.0
# 267005           When was the University Library founded?   1.0     1.0
#
#           meteor  bertscore-f1       use
# 274775  0.999023           1.0  1.000000
# 217754  0.999023           1.0  1.000000
# 270290  0.999023           1.0  1.000000
# 269553  0.998542           1.0  1.000000
# 213032  0.999023           1.0  1.000000
# ...          ...           ...       ...
# 272177  0.999624           1.0  1.000000
# 271652  0.998542           1.0  1.000000
# 275745  0.999314           1.0  0.999999
# 209747  0.998542           1.0  0.999999
# 267005  0.998542           1.0  0.999999
#
# [1311 rows x 12 columns]

# %% [markdown]
# ### Examples of Perfect Semantic but NOT Lexical Scores
#
# Note: There were no examples of perfect lexical but not semantic scores.

# %%
# Find BART predictions with all metric scores of 100

bart_df_perf = bart_df[
    (bart_df["bleu"] < 0.99)
    & (bart_df["rougeL"] < 0.99)
    & (bart_df["meteor"] < 0.99)
    & (bart_df["bertscore-f1"] >= 0.99)
    & (bart_df["use"] >= 0.99)
]

bart_df_perf = bart_df_perf.sort_values(by="use", ascending=False)

bart_df_perf
# Out:
#                   nickname base_model trained_on tested_on  \
# 74375     bart_squad_squad       bart      squad     squad
# 131633  bart_amalgam_squad       bart    amalgam     squad
# 73834     bart_squad_squad       bart      squad     squad
# 115517     bart_amalgam_nq       bart    amalgam        nq
#
#             hyperparameter                                             target  \
# 74375   {'defaults': True}  The European Court of Justice cannot uphold me...
# 131633  {'defaults': True}  The European Court of Justice cannot uphold me...
# 73834   {'defaults': True}           What kind of protists are Euglenophytes?
# 115517  {'defaults': True}  how many lines of symmetry are there in a equi...
#
#                                                prediction      bleu    rougeL  \
# 74375   The European Court of Justice cannot uphold me...  0.782542  0.923077
# 131633  The European Court of Justice cannot uphold me...  0.782542  0.923077
# 73834            What type of protists are Euglenophytes?  0.643459  0.833333
# 115517  how many lines of symmetry are there in an equ...  0.741945  0.909091
#
#           meteor  bertscore-f1       use
# 74375   0.931973      0.996113  0.991793
# 131633  0.931973      0.996113  0.991793
# 73834   0.841270      0.990525  0.991606
# 115517  0.905455      0.997177  0.991213

# %%
# Find T5 predictions with all metric scores of 100

t5_df_perf = t5_df[
    (t5_df["bleu"] < 0.99)
    & (t5_df["rougeL"] < 0.99)
    & (t5_df["meteor"] < 0.99)
    & (t5_df["bertscore-f1"] >= 0.99)
    & (t5_df["use"] >= 0.99)
]

t5_df_perf = t5_df_perf.sort_values(by="use", ascending=False)

t5_df_perf
# Out:
#                 nickname base_model trained_on tested_on      hyperparameter  \
# 267661  T5_amalgam_squad         T5    amalgam     squad  {'defaults': True}
# 216979    T5_squad_squad         T5      squad     squad  {'defaults': True}
# 274237  T5_amalgam_squad         T5    amalgam     squad  {'defaults': True}
#
#                                                    target  \
# 267661  What must the adoption of laws which will have...
# 216979           What kind of protists are Euglenophytes?
# 274237           What kind of protists are Euglenophytes?
#
#                                                prediction      bleu    rougeL  \
# 267661  What must the adoption of laws that will have ...  0.815355  0.933333
# 216979           What type of protists are Euglenophytes?  0.643459  0.833333
# 274237           What type of protists are euglenophytes?  0.000000  0.833333
#
#           meteor  bertscore-f1       use
# 267661  0.936389      0.995413  0.992263
# 216979  0.841270      0.990525  0.991606
# 274237  0.841270      0.990525  0.991606

# %% [markdown]
# ### Specific example of perfect semantic but not lexical

# %%
spec_ex = clean_eval_df[
    (clean_eval_df["target"] == "What kind of protists are Euglenophytes?")
    & (clean_eval_df["bertscore-f1"] >= 0.99)
    & (clean_eval_df["use"] >= 0.99)
]

spec_ex = spec_ex[["nickname", "target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]]

spec_ex
# Out:
#                 nickname                                    target  \
# 73834   bart_squad_squad  What kind of protists are Euglenophytes?
# 216979    T5_squad_squad  What kind of protists are Euglenophytes?
# 274237  T5_amalgam_squad  What kind of protists are Euglenophytes?
#
#                                       prediction      bleu    rougeL   meteor  \
# 73834   What type of protists are Euglenophytes?  0.643459  0.833333  0.84127
# 216979  What type of protists are Euglenophytes?  0.643459  0.833333  0.84127
# 274237  What type of protists are euglenophytes?  0.000000  0.833333  0.84127
#
#         bertscore-f1       use
# 73834       0.990525  0.991606
# 216979      0.990525  0.991606
# 274237      0.990525  0.991606

# %%
# Convert to Latex
print(spec_ex.to_latex(index=False))
# Out:
# \begin{tabular}{lllrrrrr}
# \toprule
#         nickname &                                   target &                               prediction &     bleu &   rougeL &  meteor &  bertscore-f1 &      use \\
# \midrule
# bart\_squad\_squad & What kind of protists are Euglenophytes? & What type of protists are Euglenophytes? & 0.643459 & 0.833333 & 0.84127 &      0.990525 & 0.991606 \\
#   T5\_squad\_squad & What kind of protists are Euglenophytes? & What type of protists are Euglenophytes? & 0.643459 & 0.833333 & 0.84127 &      0.990525 & 0.991606 \\
# T5\_amalgam\_squad & What kind of protists are Euglenophytes? & What type of protists are euglenophytes? & 0.000000 & 0.833333 & 0.84127 &      0.990525 & 0.991606 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Examples of High Semantic but Low Lexical

# %%
# Find predictions with high semantic and low lexical scores

hi_sem_low_lex = clean_eval_df[
    (clean_eval_df["bleu"] < 0.1)  # bottom 25th percentile bleu
    & (clean_eval_df["rougeL"] < 0.13)  # bottom 25th percentile rougeL
    & (clean_eval_df["meteor"] < 0.10)  # bottom 25th percentile meteor
    & (clean_eval_df["bertscore-f1"] >= 0.85)  # top 25th percentile bertscore
    & (clean_eval_df["use"] >= 0.67)   # top 25th percentile use
]

hi_sem_low_lex = hi_sem_low_lex.sort_values(by="use", ascending=False)

hi_sem_low_lex
# Out:
#                  nickname base_model trained_on tested_on      hyperparameter  \
# 35171      bart_quac_quac       bart       quac      quac  {'defaults': True}
# 121058  bart_amalgam_quac       bart    amalgam      quac  {'defaults': True}
# 264203    T5_amalgam_quac         T5    amalgam      quac  {'defaults': True}
# 37325     bart_quac_squad       bart       quac     squad  {'defaults': True}
#
#                                                    target  \
# 35171                                    How did she die?
# 121058                                   How did she die?
# 264203                                   How did she die?
# 37325   What was the total number of patents that Tesl...
#
#                               prediction  bleu  rougeL    meteor  \
# 35171       What was her cause of death?   0.0   0.000  0.096154
# 121058  What was the cause of her death?   0.0   0.000  0.094340
# 264203  What was the cause of her death?   0.0   0.000  0.094340
# 37325      How many patents did he have?   0.0   0.125  0.094340
#
#         bertscore-f1       use
# 35171       0.855320  0.754843
# 121058      0.851208  0.705527
# 264203      0.851208  0.705527
# 37325       0.862127  0.687061

# %%
# Find predictions with high semantic and low lexical scores

hi_sem_low_lex = clean_eval_df[
    (clean_eval_df["rougeL"] < 0.13)  # bottom 25th percentile rougeL
    & (clean_eval_df["meteor"] < 0.10)  # bottom 25th percentile meteor
    & ((clean_eval_df["bertscore-f1"] >= 0.85) | (clean_eval_df["use"] >= 0.67))   # top 25th percentile use
   # & (clean_eval_df["trained_on"] == "amalgam")   # this removes a lot of the dup rows for questions generated
]   # did not inlcude bleu condition because causing issues returning  enough samples... bleu is funky

hi_sem_low_lex = hi_sem_low_lex.sort_values(by="use", ascending=False)
# Multiply scores by 100
hi_sem_low_lex[["bleu", "rougeL", "meteor", "bertscore-f1", "use"]] = hi_sem_low_lex[["bleu", "rougeL", "meteor", "bertscore-f1", "use"]].mul(100).round(2)
hi_sem_low_lex[["target", "prediction"]] = hi_sem_low_lex[["target", "prediction"]]

hi_sem_low_lex = hi_sem_low_lex[["target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]]

hi_sem_low_lex
# Out:
#                                                    target  \
# 202524             who is beauty and the beast written by
# 9511    What is the record number of touchdowns Cam Ne...
# 28942   what is the first basic process in the light r...
# 57571   what is the first basic process in the light r...
# 160891  On what date was the record low temperature in...
# ...                                                   ...
# 127146  Who explained that inertial reference frames e...
# 270291  Who explained that inertial reference frames e...
# 213033  Who explained that inertial reference frames e...
# 245183                  How are ergänzungsschulen funded?
# 238618      What do Plastoglobuli exchange contents with?
#
#                                                prediction  bleu  rougeL  \
# 202524                     Who wrote La Belle et la Bête?   0.0   12.50
# 9511    how many touchdowns did the carolina panthers ...   0.0    9.52
# 28942                      How does photosynthesis begin?   0.0   12.50
# 57571                      How does photosynthesis begin?   0.0   12.50
# 160891        when did fresno get its highest temperature   0.0   11.76
# ...                                                   ...   ...     ...
# 127146     Who extended the principle of inertia further?   0.0   10.00
# 270291     Who extended the principle of inertia further?   0.0   10.00
# 213033     Who extended the principle of inertia further?   0.0   10.00
# 245183  s, fees, and what else? What does a Ergänzungs...   0.0   12.50
# 238618   The plastoglobulus is anchored to which network?   0.0    0.00
#
#         meteor  bertscore-f1    use
# 202524    6.25         71.57  82.44
# 9511      8.47         75.88  77.45
# 28942     4.42         80.56  77.28
# 57571     4.42         80.56  77.28
# 160891    9.43         81.11  77.05
# ...        ...           ...    ...
# 127146    7.46         85.04  24.03
# 270291    7.46         85.04  24.03
# 213033    7.46         85.04  24.03
# 245183    8.47         86.71  13.26
# 238618    7.04         86.28   6.68
#
# [190 rows x 7 columns]

# %%
# Convert to Latex
print(hi_sem_low_lex.to_latex(index=False))

# Print entire text
with pd.option_context("max_colwidth", 1000):
    print(hi_sem_low_lex[["target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]].to_latex(index=False))
# Out:
# \begin{tabular}{llrrrrr}
# \toprule
#                                             target &                                         prediction &  bleu &  rougeL &  meteor &  bertscore-f1 &   use \\
# \midrule
#             who is beauty and the beast written by &                     Who wrote La Belle et la Bête? &   0.0 &   12.50 &    6.25 &         71.57 & 82.44 \\
# What is the record number of touchdowns Cam New... & how many touchdowns did the carolina panthers h... &   0.0 &    9.52 &    8.47 &         75.88 & 77.45 \\
# what is the first basic process in the light re... &                     How does photosynthesis begin? &   0.0 &   12.50 &    4.42 &         80.56 & 77.28 \\
# what is the first basic process in the light re... &                     How does photosynthesis begin? &   0.0 &   12.50 &    4.42 &         80.56 & 77.28 \\
# On what date was the record low temperature in ... &        when did fresno get its highest temperature &   0.0 &   11.76 &    9.43 &         81.11 & 77.05 \\
# After he left Barcelona, football manager Pep G... &          who is guardiola the manager of barcelona &   0.0 &    8.33 &    8.43 &         81.55 & 77.03 \\
#               How large are Cytoplasmic ribosomes? &         what is the size of a chloroplast ribosome &   0.0 &    0.00 &    8.06 &         84.11 & 76.81 \\
# What was the nationality of composer Frederic C... &                where did frédéric chopin come from &   0.0 &   12.50 &    5.75 &         80.00 & 76.61 \\
# Which grape is used to produce top-quality Burg... &          what kind of grapes are grown in burgundy &   0.0 &   10.53 &    9.35 &         80.96 & 76.23 \\
# How much rain per year does Fresno get on average? & what is the average precipitation in fresno cal... &   0.0 &   11.11 &    9.35 &         78.41 & 75.93 \\
# Which planet weighs more than all the other pla... &            What planet is twice as large as Earth? &   0.0 &    9.09 &    6.94 &         82.55 & 75.66 \\
#                                   How did she die? &                       What was her cause of death? &   0.0 &    0.00 &    9.62 &         85.53 & 75.48 \\
# What was the number of 17 interceptions that Pe... &             How many touchdowns did Manning throw? &   0.0 &    9.09 &    6.25 &         80.22 & 75.20 \\
# What was the number of 17 interceptions that Pe... &             How many touchdowns did Manning throw? &   0.0 &    9.09 &    6.25 &         80.22 & 75.20 \\
# What was the number of 17 interceptions that Pe... &             How many touchdowns did Manning throw? &   0.0 &    9.09 &    6.25 &         80.22 & 75.20 \\
# What was the number of 17 interceptions that Pe... &             how many touchdowns did Manning throw? &   0.0 &    9.09 &    6.25 &         80.22 & 75.20 \\
# What was the number of 17 interceptions that Pe... & how many touchdowns did manning throw in his ca... &   0.0 &    8.00 &    3.09 &         76.28 & 74.95 \\
# What vehicle did Doctor Who use for his escape ... &                    What is the name of the TARDIS? &   0.0 &   11.11 &    8.62 &         75.65 & 74.92 \\
# Which band released a 2001 album entitled ‘Amne... &       what was the name of radiohead's first album &   0.0 &   11.76 &    4.63 &         73.78 & 74.70 \\
# Which band released a 2001 album entitled ‘Amne... &      What was the name of Radiohead's first album? &   0.0 &   11.76 &    9.17 &         74.78 & 74.70 \\
# Which band released a 2001 album entitled ‘Amne... &      What was the name of Radiohead's first album? &   0.0 &   11.76 &    9.17 &         74.78 & 74.70 \\
# Which band released a 2001 album entitled ‘Amne... &      What was the name of Radiohead's first album? &   0.0 &   11.76 &    9.17 &         74.78 & 74.70 \\
# What is the fictional location of the tv soap ‘... &         where does eastenders take place in london &   0.0 &   11.76 &    4.03 &         74.94 & 74.27 \\
# "Who produces the perfumes ""Opium"" and ""Rive... &          Opium is a perfume made by which company? &   0.0 &   12.50 &    8.33 &         76.54 & 73.46 \\
# What was the number of 17 interceptions that Pe... &      how many touchdowns did manning throw in 2018 &   0.0 &    8.33 &    3.11 &         76.47 & 73.39 \\
#         what is the population of st petersburg fl & How many people lived in Saint Petersburg in 2015? &   0.0 &   11.76 &    6.10 &         78.74 & 73.23 \\
# From which common English tree are cricket stum... &    what kind of wood is used for stumps in cricket &   0.0 &   10.00 &    9.17 &         79.89 & 73.04 \\
# Which US comic superhero has the real name Stev... &              who is the first super hero in comics &   0.0 &   11.11 &    9.35 &         77.78 & 72.87 \\
# The Amazon rainforest makes up what amount of E... &                    How many rainforests are there? &   0.0 &   12.50 &    8.77 &         84.49 & 72.82 \\
# Which rival of the Mongols is suspected of inve... & Who did some Mongol authors believe stabbed Gen... &   0.0 &    7.14 &    7.58 &         83.08 & 72.70 \\
#                What nationality is singer Rhianna? &           Rihanna Fenty was born in which country? &   0.0 &    0.00 &    8.06 &         77.33 & 72.64 \\
# Luzon and Mindanao are the two largest islands ... & What is the official name of the archipelago of... &   0.0 &    9.09 &    8.33 &         78.99 & 72.59 \\
# In which film series would you expect to film K... &           what book is katniss in the hunger games &   0.0 &    9.09 &    6.99 &         76.92 & 72.07 \\
#         Which country was invaded by Iraq in 1990? &   where did the iraq invasion of kuwait take place &   0.0 &   11.76 &    5.56 &         77.62 & 71.91 \\
# In which film series would you expect to film K... &        what book is katniss in in the hunger games &   0.0 &    8.70 &    6.94 &         76.31 & 71.90 \\
# What was the number of 17 interceptions that Pe... &         How many touchdowns did Eli Manning throw? &   0.0 &    8.70 &    6.21 &         81.06 & 71.88 \\
# when did starbucks become a publicly traded com... & Which year was the Starbucks IPO on the stock m... &   0.0 &   11.11 &    6.02 &         77.21 & 71.83 \\
# From which country was Fulgencio Batista ousted... &        where did batista become president of cuban &   0.0 &   12.50 &    5.15 &         78.56 & 71.62 \\
#               Which tribes did Genghis Khan unite? &                              Who were the Mongols? &   0.0 &    0.00 &    7.35 &         78.48 & 71.57 \\
# The left side of the heart pumps blood to all p... &             What other organs does the heart pump? &   0.0 &   12.50 &    9.96 &         79.80 & 71.53 \\
# What, generally, is the par on a 300 yard golf ... &                   how many holes are there in golf &   0.0 &   11.11 &    7.52 &         78.14 & 71.35 \\
# Which World War 2 American general was known as... & what was the name of the us general who served ... &   0.0 &    8.70 &    7.75 &         78.12 & 71.32 \\
#          name a food you might eat on thanksgiving & what is the main ingredient of thanksgiving dinner &   0.0 &   12.50 &    6.25 &         77.62 & 71.29 \\
#      when did marathon change its name to snickers &     In which year was the Snickers brand launched? &   0.0 &   12.50 &    6.17 &         78.26 & 71.18 \\
#   Author J.R.R. Tolkien was born in which country? &          where did the last name tolkien come from &   0.0 &   11.11 &    5.10 &         67.69 & 71.10 \\
#                                     how did he die &                   What was the cause of his death? &   0.0 &    0.00 &    0.00 &         75.56 & 71.09 \\
#   Where did Tesla look for investors prior to WWI? & : before World War I, Tesla sought funding from... &   0.0 &    9.09 &    9.43 &         80.09 & 70.99 \\
#         Which Tsar of Russia ruled from 1682-1725? &                 Who proclaimed the Russian Empire? &   0.0 &    0.00 &    6.41 &         79.55 & 70.82 \\
#         Which Tsar of Russia ruled from 1682-1725? &                 Who proclaimed the Russian Empire? &   0.0 &    0.00 &    6.41 &         79.55 & 70.82 \\
# Which Apollo mission, which was launched on Jul... &                           What year was Apollo 11? &   0.0 &    8.00 &    6.76 &         75.39 & 70.67 \\
# Which planet in our solar system has the shorte... &                      What other planets are there? &   0.0 &    0.00 &    9.52 &         79.74 & 70.66 \\
# What was the overly generous royalty amount tha... &                         How much did he pay Tesla? &   0.0 &   11.11 &    8.06 &         83.23 & 70.62 \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig,... & Who voiced Bugs Bunny in the Looney Tunes carto... &   0.0 &   10.00 &    5.97 &         76.68 & 70.61 \\
#                                   How did she die? &                   What was the cause of her death? &   0.0 &    0.00 &    9.43 &         85.12 & 70.55 \\
#                                   How did she die? &                   What was the cause of her death? &   0.0 &    0.00 &    9.43 &         85.12 & 70.55 \\
# What was the first name of Mr. Ferrari, the fou... &                               Who founded Ferrari? &   0.0 &   11.11 &    6.37 &         79.25 & 70.54 \\
# What year did Doctor Who finally return to tele... & when was the last time dr who had a christmas s... &   0.0 &   10.00 &    9.90 &         73.90 & 70.43 \\
#          Which fruit is known as ananas in French? &            what is the name of the pineapple plant &   0.0 &   12.50 &    5.62 &         75.34 & 70.42 \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig,... & Who voiced Bugs Bunny in the Looney Tunes and M... &   0.0 &   12.90 &    6.82 &         76.64 & 70.36 \\
#          Which fruit is known as ananas in French? &         what is the scientific name of a pineapple &   0.0 &   12.50 &    5.62 &         74.13 & 70.34 \\
# Which World war 2 American general was nickname... & what was the name of the us general who served ... &   0.0 &    9.09 &    7.75 &         77.32 & 70.26 \\
# Which young general did Genghis Khan send to co... &       who led the mongols in the battle of kuchlug &   0.0 &    0.00 &    0.00 &         74.05 & 70.24 \\
# In 'Scarface' which character was played by Al ... &           who played mr. corleone in the godfather &   0.0 &   12.50 &    9.43 &         75.10 & 70.24 \\
# What is the most rainfall recorded in a 24 hour... &           how much rain does fresno get in one day &   0.0 &    9.09 &    7.41 &         77.01 & 70.21 \\
# What year is the earliest traces of the color C... &           when did red start being used in harvard &   0.0 &   10.00 &    8.00 &         75.77 & 70.19 \\
#            Odysseus was King of which Greek state? & where did the odyssey take place in greek mytho... &   0.0 &   12.50 &    6.17 &         72.90 & 70.17 \\
# Which young general did Genghis Khan send to co... &            who led the mongol army against kuchlug &   0.0 &    0.00 &    0.00 &         75.63 & 70.08 \\
# Marat, Robespierre, Danton are names associated... & what revolution did maximilian robespierre lead in &   0.0 &    8.70 &    5.62 &         75.81 & 70.03 \\
# Which cartoon title character has a friend call... &     who is the captain in the adventures of tintin &   0.0 &   10.53 &    4.63 &         75.84 & 70.02 \\
# Among whom was Genghis Khan's empire split afte... &        who divided the mongol empire into khanates &   0.0 &   11.11 &    4.35 &         76.87 & 69.99 \\
#        what happened to western rome after it fell &              what was the fall of the roman empire &   0.0 &   12.50 &    6.25 &         80.58 & 69.96 \\
#        how much did disneyland paris cost to build & What was the construction budget for the Euro D... &   0.0 &    0.00 &    5.95 &         79.07 & 69.82 \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig,... &          who voiced bugs bunny in the looney tunes &   0.0 &   10.34 &    5.09 &         75.96 & 69.79 \\
# In what year did Lavoisier publish his work on ... & when was the book sur la combustion en général ... &   0.0 &    9.09 &    9.17 &         75.08 & 69.77 \\
# What are we unsure of about how chloroplasts ma... & where does methionine come from in the chloroplast &   0.0 &   10.53 &    8.62 &         83.92 & 69.53 \\
# What was the name given to the German annexatio... &        when did austria become a member of germany &   0.0 &    9.52 &    7.46 &         73.44 & 69.39 \\
# Which boxer fought Mohammed Ali in the fight kn... & Who was the third and final boxing match betwee... &   0.0 &    7.69 &    9.55 &         78.35 & 69.38 \\
#   Who bought Chelsea football club for £1 in 1982? & What was the name of the former owner of Chelse... &   0.0 &    9.52 &    9.71 &         77.83 & 69.37 \\
# What is the next in the series: Nigeria, Sierra... & Which African country is bordered by Botswana, ... &   0.0 &   12.90 &    4.98 &         76.57 & 69.34 \\
# "Which game has been played in England since Tu... & what is the name of the first baseball game played &   0.0 &   10.81 &    9.23 &         74.86 & 69.30 \\
#              when did goku first go super saiyan 4 & What was the name of the battle between Goku an... &   0.0 &   10.53 &    5.95 &         73.38 & 69.30 \\
# In which American state would you find Mt. Rush... &    where is mount rushmore located in south dakota &   0.0 &   11.76 &    9.35 &         76.49 & 69.27 \\
# when did lionel messi play his first game for b... &  The Messi family moved to Camp Nou in which year? &   0.0 &   10.00 &    4.95 &         69.47 & 69.27 \\
# How many people do historians estimate Genghis ... & what was the population of iran during the mong... &   0.0 &    8.70 &    3.68 &         75.21 & 69.20 \\
#        where does half life 2 episode 2 take place &                    where do the gman and alyx meet &   0.0 &   12.50 &    5.68 &         73.19 & 69.11 \\
# Which cigarette manufacturer used to boast of i... & What is the name of the cigarette company that ... &   0.0 &    8.33 &    9.55 &         77.76 & 69.10 \\
# What is the population of the second largest ci... &               How many people live in Los Angeles? &   0.0 &   11.11 &    8.62 &         79.41 & 68.98 \\
# Flourine, Bromine, Iodine and Chlorine are all ... &       what group is chlorine in the periodic table &   0.0 &   10.53 &    7.46 &         81.46 & 68.92 \\
#     What was the black death originally blamed on? &           who caused the plague in the middle ages &   0.0 &   12.50 &    5.62 &         71.36 & 68.91 \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig,... & Who voiced Wile E Coyote in the Looney Tunes ca... &   0.0 &   10.00 &    4.01 &         77.20 & 68.89 \\
# Cayenne, after which the spicy condiment is nam... &       where does the name cayenne pepper come from &   0.0 &    9.09 &    9.32 &         78.54 & 68.86 \\
# What was Edison's reply as to what Tesla didn't... &               where did the phrase tesla come from &   0.0 &    8.33 &    5.92 &         75.50 & 68.86 \\
# Whom did Andy Murray defeat in the Wimbledon me... &         who won the 2017 us open tennis tournament &   0.0 &    9.09 &    3.50 &         78.09 & 68.86 \\
# Whom did Andy Murray defeat in the Wimbledon me... &         who won the 2017 us open tennis tournament &   0.0 &    9.09 &    3.50 &         78.09 & 68.86 \\
# To which order of monks does or did Pope Franci... &             Who were the first non-European popes? &   0.0 &    0.00 &    8.70 &         74.62 & 68.85 \\
# what is the first basic process in the light re... &                    When does photosynthesis begin? &   0.0 &   12.50 &    4.42 &         79.47 & 68.84 \\
#        what happened to western rome after it fell & what was the result of the fall of the roman em... &   0.0 &   10.53 &    6.02 &         79.55 & 68.74 \\
#        what happened to western rome after it fell & what was the result of the fall of the roman em... &   0.0 &   10.53 &    6.02 &         79.55 & 68.74 \\
# Sea World is in Mission Bay Park in which US city? &                where is seaworld san diego located &   0.0 &   11.76 &    4.39 &         78.84 & 68.73 \\
#                    What delivery message was used  &                    How did Baran deliver messages? &   0.0 &    0.00 &    9.80 &         76.96 & 68.72 \\
#                    What delivery message was used  &                    How did Baran deliver messages? &   0.0 &    0.00 &    9.80 &         76.96 & 68.72 \\
#                    What delivery message was used  &                    How did Baran deliver messages? &   0.0 &    0.00 &    9.80 &         76.96 & 68.72 \\
# What was the total number of patents that Tesla... &                      How many patents did he have? &   0.0 &   12.50 &    9.43 &         86.21 & 68.71 \\
# By what name do Czechs know their capital city,... &         where is the capital of the czech republic &   0.0 &   11.11 &    8.62 &         72.71 & 68.66 \\
# In which film series would you expect to film K... & where does peeta Mellark come from in the hunge... &   0.0 &    8.33 &    6.90 &         76.38 & 68.64 \\
# How many people does the Greater Los Angeles Ar... &      what is the population of southern california &   0.0 &   11.76 &    4.72 &         75.78 & 68.62 \\
# How many people does the Greater Los Angeles Ar... &      what is the population of southern california &   0.0 &   11.76 &    4.72 &         75.78 & 68.62 \\
# Which two Mongol leaders added Persia to the Mo... &             who led the mongols in the caspian sea &   0.0 &   11.11 &    9.35 &         79.51 & 68.60 \\
# Which two Mongol leaders added Persia to the Mo... &             who led the mongols in the caspian sea &   0.0 &   11.11 &    9.35 &         79.51 & 68.60 \\
# The 2009 season of the Indian Premier League, a... &       where was the first t20 cricket match played &   0.0 &   12.12 &    7.69 &         73.45 & 68.58 \\
#           Why did Luther condemn vows of celibacy? &  what was the reason for luther's refusal to marry &   0.0 &   11.76 &    6.10 &         76.08 & 68.57 \\
# Kenneth Wolstenholme was a commentator for whic... &       what is the name of the football commentator &   0.0 &   12.50 &    5.62 &         72.34 & 68.47 \\
# Sanskrit is an ancient language of which modern... &              where is sanskrit spoken in the world &   0.0 &   11.76 &    9.43 &         78.04 & 68.43 \\
# what is the first basic process in the light re... &          where does photosynthesis begin in plants &   0.0 &   11.11 &    8.77 &         81.04 & 68.36 \\
# What was Tesla's father's original plans for Te... &                  where did tesla go to high school &   0.0 &   11.76 &    4.72 &         72.28 & 68.34 \\
# What is the population of the Inner Mongolia re... &                how many mongols are there in china &   0.0 &   11.11 &    4.35 &         78.45 & 68.31 \\
# What is the population of the Inner Mongolia re... &                how many mongols are there in china &   0.0 &   11.11 &    4.35 &         78.45 & 68.31 \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig,... &          who played daffy duck in the looney tunes &   0.0 &   10.34 &    4.12 &         76.19 & 68.29 \\
#      What did Shaq have to do with law enforcement &            How did O'Neal become a police officer? &   0.0 &   11.76 &    5.62 &         72.49 & 68.28 \\
#                              Why were they rivals? &                        What was the rivalry about? &   0.0 &    0.00 &    9.80 &         83.54 & 68.28 \\
#  In which children's TV series does Shaggy appear? &           what is the name of the scooby doo movie &   0.0 &    0.00 &    0.00 &         71.29 & 68.25 \\
#            What part of the body produces insulin? &    where does insulin come from in type 2 diabetes &   0.0 &   12.50 &    6.17 &         73.85 & 68.19 \\
#   Which 'superhero's' alter ego is 'Peter Parker'? & what is the name of the first spiderman comic book &   0.0 &   11.11 &    4.59 &         72.27 & 68.14 \\
# How many inhabitants does the Los Angeles area ... &      what is the population of southern california &   0.0 &   12.50 &    5.15 &         76.99 & 68.05 \\
# How many inhabitants does the Los Angeles area ... &      what is the population of southern california &   0.0 &   12.50 &    5.15 &         76.99 & 68.05 \\
#             who played kelly taylor's mom on 90210 & What is the name of the mother of Kelly Walsh i... &   0.0 &    8.70 &    5.68 &         74.48 & 68.03 \\
# Which human blood group can receive blood from ... &        What is the most common type of blood type? &   0.0 &    9.52 &    7.87 &         79.65 & 68.02 \\
# Jose Mourinho was appointed manager of which fo... & What team did José Mourinho manage at in the 19... &   0.0 &    7.41 &    8.24 &         80.21 & 68.02 \\
#         Which Tsar of Russia ruled from 1682-1725? &             who founded the russian empire in 1721 &   0.0 &    0.00 &    6.33 &         77.77 & 67.98 \\
# In which English county was former British Prim... &                  where did thatcher live in the uk &   0.0 &   10.53 &    8.06 &         73.51 & 67.90 \\
# In which U.S. State is the University of Harvar... &             where did harvard college get its name &   0.0 &   10.00 &    4.03 &         73.24 & 67.87 \\
# In 'Brookside', which actress, later to become ... &              who played heather in brookside close &   0.0 &   12.12 &    4.55 &         79.33 & 67.83 \\
# What became the last city on earth to experienc... &  where did the atomic bombings take place in japan &   0.0 &    5.41 &    3.70 &         75.08 & 67.82 \\
# What was Manning's passer rating at the end of ... & How many points did Peyton Manning score in his... &   0.0 &    9.09 &    7.81 &         77.54 & 67.79 \\
#         Which Tsar of Russia ruled from 1682-1725? &         who established the russian empire in 1721 &   0.0 &    0.00 &    0.00 &         78.02 & 67.76 \\
# Which English football league team are known as... & what is the name of peterborough united footbal... &   0.0 &   10.53 &    8.55 &         73.82 & 67.75 \\
#   Which 'superhero's' alter ego is 'Peter Parker'? & What is the name of the super-hero in the comic... &   0.0 &    8.33 &    8.55 &         76.40 & 67.68 \\
#         Roald Dahl's BFG was a big, friendly what? &           what is the name of the giant in the bfg &   0.0 &   10.53 &    9.17 &         74.64 & 67.65 \\
#         Roald Dahl's BFG was a big, friendly what? &           what is the name of the giant in the bFG &   0.0 &   10.53 &    9.17 &         74.64 & 67.65 \\
# What is each section of ten beads on a rosary c... &            How many years are there in the Rosary? &   0.0 &   10.53 &    8.55 &         79.72 & 67.64 \\
# What became the last city on earth to experienc... &      where did the bombing of hiroshima take place &   0.0 &   11.11 &    5.58 &         73.85 & 67.61 \\
# How do centripetal forces act in relation to ve... &      what is the direction of the tangential force &   0.0 &   10.53 &    8.62 &         80.77 & 67.61 \\
# Which young general did Genghis Khan send to co... &     Who commanded the Mongol army against Kuchlug? &   0.0 &    0.00 &    4.31 &         79.79 & 67.60 \\
#                What was the date of Tesla's death? &             when did niota tesla die in new yorker &   0.0 &   12.50 &    5.62 &         71.26 & 67.59 \\
# What year did Newton hold the number one draft ... & when was the first quarterback picked in the su... &   0.0 &    9.52 &    8.47 &         74.79 & 67.57 \\
# What were the names of the founder of British c... &                           Who founded JCB in 1945? &   0.0 &   12.50 &    8.77 &         79.80 & 67.53 \\
# What were the names of the founder of British c... &                           Who founded JCB in 1945? &   0.0 &   12.50 &    8.77 &         79.80 & 67.53 \\
# What were the names of the founder of British c... &                           Who founded JCB in 1945? &   0.0 &   12.50 &    8.77 &         79.80 & 67.53 \\
# What were the names of the founder of British c... &                           Who founded JCB in 1945? &   0.0 &   12.50 &    8.77 &         79.80 & 67.53 \\
# Which boy band consists of Niall Horan, Zayn Ma... &                      who is niall from in x factor &   0.0 &    8.70 &    2.67 &         68.54 & 67.52 \\
# How do Mongolians sometime describe their relat... &                   who is the father of the mongols &   0.0 &    0.00 &    0.00 &         72.42 & 67.46 \\
# what is the number of total presidential electo... &         How many electors are there in each state? &   0.0 &    0.00 &    5.56 &         73.68 & 67.44 \\
# Which group did Steve Marriot go on to form whe... &        What was the name of Steve Marriott's band? &   0.0 &    8.33 &    9.20 &         75.65 & 67.41 \\
# Which group did Steve Marriot go on to form whe... &        What was the name of Steve Marriott's band? &   0.0 &    8.33 &    9.20 &         75.65 & 67.41 \\
# Fossils found that were believed to be ctenopho... &     when did the first ctenophore fossils come out &   0.0 &   10.53 &    8.62 &         82.27 & 67.40 \\
# What percentage of Scotland's voting population... &           How many people voted in the referendum? &   0.0 &    0.00 &    8.62 &         81.14 & 67.39 \\
#     In what year did Savery patent his steam pump? &           when was the first steam engine invented &   0.0 &   12.50 &    5.15 &         77.52 & 67.32 \\
#     In what year did Savery patent his steam pump? &           when was the first steam engine invented &   0.0 &   12.50 &    5.15 &         77.52 & 67.32 \\
# what is the number of total presidential electo... &         How many electors are there in a US state? &   0.0 &    0.00 &    5.49 &         72.67 & 67.29 \\
#        how much did disneyland paris cost to build &   what was the cost of the first disney theme park &   0.0 &   11.11 &    6.10 &         80.01 & 67.27 \\
# Which group of around 200 Greek islands in the ... &                 where is mykonos located in greece &   0.0 &    8.70 &    2.69 &         78.57 & 67.26 \\
# How old were Jimmi Hendrix, Janis Joplin and Ji... &                   What age did Kurt Cobain die at? &   0.0 &    0.00 &    6.99 &         78.12 & 67.25 \\
# In which film series would you expect to film K... &             when does katniss win the hunger games &   0.0 &    9.52 &    3.52 &         75.81 & 67.25 \\
# Which mythological creatures are half horse and... & What was the name of one of the mythical creatu... &   0.0 &   10.53 &    9.90 &         79.79 & 67.23 \\
# who were the the continent of the americas name... &                   Who discovered America on a map? &   0.0 &   11.76 &    9.43 &         74.59 & 67.22 \\
# Malaga airport serves which of the Spanish Costas? &           where is málaga airport located in spain &   0.0 &   12.50 &    5.68 &         80.28 & 67.20 \\
# """Torchwood"" was a spin-off of what popular T... & In which TV series did the character Jack Harkn... &   0.0 &   10.00 &    6.45 &         76.75 & 67.11 \\
# Which human blood group can receive blood from ... &                What is the most common blood type? &   0.0 &   10.53 &    8.00 &         80.67 & 67.05 \\
# Which human blood group can receive blood from ... &                What is the most common blood type? &   0.0 &   10.53 &    8.00 &         80.67 & 67.05 \\
# What happens to the jellyfish nematocysts when ... &              How do ctenophores prey on jellyfish? &   0.0 &   10.53 &    7.52 &         80.05 & 67.01 \\
# Which quadrilateral has one pair of parallel ed... &          what type of quadrilateral is a rectangle &   0.0 &   11.11 &    8.70 &         85.94 & 65.66 \\
#                How many Kenyans are non-religious? & What percentage of Kenya's Muslim population is... &   0.0 &    0.00 &    7.81 &         85.33 & 63.82 \\
#                       How large are Plastoglobuli? &               what is the size of a plastoglobulus &   0.0 &    0.00 &    0.00 &         86.19 & 62.21 \\
#                       How big can ctenophora grow? &          What is the average size of a ctenophore? &   0.0 &    0.00 &    7.94 &         85.11 & 62.19 \\
#                     How large can ctenophora grow? &   What is the maximum size of an adult ctenophore? &   0.0 &    0.00 &    7.81 &         86.46 & 53.38 \\
#                     How large can ctenophora grow? &          What is the average size of a ctenophore? &   0.0 &    0.00 &    7.94 &         86.02 & 52.60 \\
#                       How large are Plastoglobuli? &              what is the length of a plastoglobule &   0.0 &    0.00 &    0.00 &         85.67 & 52.23 \\
# Ashkenazic and sephardic cuisines are associate... &                        What ethnicity is Sephardi? &   0.0 &    0.00 &    9.62 &         85.16 & 51.86 \\
#       How long ago did cyanobacteria enter a cell? &                When was cyanobacterium discovered? &   0.0 &    0.00 &    5.81 &         88.65 & 50.54 \\
#             Curacao was a colony of which country? &                          Where is Curaçao located? &   0.0 &    0.00 &    6.49 &         86.25 & 49.44 \\
#                       Were their songs successful? &                       Did they release any albums? &   0.0 &    0.00 &    9.80 &         85.73 & 46.15 \\
#                       Were their songs successful? &                       Did they release any albums? &   0.0 &    0.00 &    9.80 &         85.73 & 46.15 \\
# What English chemist showed that fire only need... & who discovered that nitroaereus is necessary fo... &   0.0 &   11.76 &    5.10 &         85.58 & 45.36 \\
#                       How large are Plastoglobuli? &           what is the diameter of a plastoglobulus &   0.0 &    0.00 &    0.00 &         85.48 & 45.13 \\
#                  How are ergänzungsschulen funded? &    What does Ergungsschulen charge their students? &   0.0 &    0.00 &    9.62 &         86.88 & 28.78 \\
# Who explained that inertial reference frames eq... &     Who extended the principle of inertia further? &   0.0 &   10.00 &    7.46 &         85.04 & 24.03 \\
# Who explained that inertial reference frames eq... &     Who extended the principle of inertia further? &   0.0 &   10.00 &    7.46 &         85.04 & 24.03 \\
# Who explained that inertial reference frames eq... &     Who extended the principle of inertia further? &   0.0 &   10.00 &    7.46 &         85.04 & 24.03 \\
#                  How are ergänzungsschulen funded? & s, fees, and what else? What does a Ergänzungss... &   0.0 &   12.50 &    8.47 &         86.71 & 13.26 \\
#      What do Plastoglobuli exchange contents with? &   The plastoglobulus is anchored to which network? &   0.0 &    0.00 &    7.04 &         86.28 &  6.68 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{llrrrrr}
# \toprule
#                                                                                                                                                                                                                                                                                                                          target &                                                                           prediction &  bleu &  rougeL &  meteor &  bertscore-f1 &   use \\
# \midrule
#                                                                                                                                                                                                                                                                                          who is beauty and the beast written by &                                                       Who wrote La Belle et la Bête? &   0.0 &   12.50 &    6.25 &         71.57 & 82.44 \\
#                                                                                                                                                                                                                                                                    What is the record number of touchdowns Cam Newton has had?  &                         how many touchdowns did the carolina panthers have last year &   0.0 &    9.52 &    8.47 &         75.88 & 77.45 \\
#                                                                                                                                                                                                                                                         what is the first basic process in the light reaction of photosynthesis &                                                       How does photosynthesis begin? &   0.0 &   12.50 &    4.42 &         80.56 & 77.28 \\
#                                                                                                                                                                                                                                                         what is the first basic process in the light reaction of photosynthesis &                                                       How does photosynthesis begin? &   0.0 &   12.50 &    4.42 &         80.56 & 77.28 \\
#                                                                                                                                                                                                                                                                          On what date was the record low temperature in Fresno? &                                          when did fresno get its highest temperature &   0.0 &   11.76 &    9.43 &         81.11 & 77.05 \\
#                                                                                                                                                                                                                          After he left Barcelona, football manager Pep Guardiola went on to manage which European club in 2013? &                                            who is guardiola the manager of barcelona &   0.0 &    8.33 &    8.43 &         81.55 & 77.03 \\
#                                                                                                                                                                                                                                                                                            How large are Cytoplasmic ribosomes? &                                           what is the size of a chloroplast ribosome &   0.0 &    0.00 &    8.06 &         84.11 & 76.81 \\
#                                                                                                                                                                                                                                                                           What was the nationality of composer Frederic Chopin? &                                                  where did frédéric chopin come from &   0.0 &   12.50 &    5.75 &         80.00 & 76.61 \\
#                                                                                                                                                                                                                                                                  Which grape is used to produce top-quality Burgundy red wines? &                                            what kind of grapes are grown in burgundy &   0.0 &   10.53 &    9.35 &         80.96 & 76.23 \\
#                                                                                                                                                                                                                                                                              How much rain per year does Fresno get on average? &                               what is the average precipitation in fresno california &   0.0 &   11.11 &    9.35 &         78.41 & 75.93 \\
#                                                                                                                                                                                                                                               Which planet weighs more than all the other planets of our solar system combined? &                                              What planet is twice as large as Earth? &   0.0 &    9.09 &    6.94 &         82.55 & 75.66 \\
#                                                                                                                                                                                                                                                                                                                How did she die? &                                                         What was her cause of death? &   0.0 &    0.00 &    9.62 &         85.53 & 75.48 \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                               How many touchdowns did Manning throw? &   0.0 &    9.09 &    6.25 &         80.22 & 75.20 \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                               How many touchdowns did Manning throw? &   0.0 &    9.09 &    6.25 &         80.22 & 75.20 \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                               How many touchdowns did Manning throw? &   0.0 &    9.09 &    6.25 &         80.22 & 75.20 \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                               how many touchdowns did Manning throw? &   0.0 &    9.09 &    6.25 &         80.22 & 75.20 \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                  how many touchdowns did manning throw in his career &   0.0 &    8.00 &    3.09 &         76.28 & 74.95 \\
#                                                                                                                                                                                                                                                                  What vehicle did Doctor Who use for his escape from Gallifrey? &                                                      What is the name of the TARDIS? &   0.0 &   11.11 &    8.62 &         75.65 & 74.92 \\
#                                                                                                                                                                                                                                                                           Which band released a 2001 album entitled ‘Amnesiac’? &                                         what was the name of radiohead's first album &   0.0 &   11.76 &    4.63 &         73.78 & 74.70 \\
#                                                                                                                                                                                                                                                                           Which band released a 2001 album entitled ‘Amnesiac’? &                                        What was the name of Radiohead's first album? &   0.0 &   11.76 &    9.17 &         74.78 & 74.70 \\
#                                                                                                                                                                                                                                                                           Which band released a 2001 album entitled ‘Amnesiac’? &                                        What was the name of Radiohead's first album? &   0.0 &   11.76 &    9.17 &         74.78 & 74.70 \\
#                                                                                                                                                                                                                                                                           Which band released a 2001 album entitled ‘Amnesiac’? &                                        What was the name of Radiohead's first album? &   0.0 &   11.76 &    9.17 &         74.78 & 74.70 \\
#                                                                                                                                                                                                                                                                     What is the fictional location of the tv soap ‘Eastenders’? &                                           where does eastenders take place in london &   0.0 &   11.76 &    4.03 &         74.94 & 74.27 \\
#                                                                                                                                                                                                                                                                      "Who produces the perfumes ""Opium"" and ""Rive Gauche""?" &                                            Opium is a perfume made by which company? &   0.0 &   12.50 &    8.33 &         76.54 & 73.46 \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                        how many touchdowns did manning throw in 2018 &   0.0 &    8.33 &    3.11 &         76.47 & 73.39 \\
#                                                                                                                                                                                                                                                                                      what is the population of st petersburg fl &                                   How many people lived in Saint Petersburg in 2015? &   0.0 &   11.76 &    6.10 &         78.74 & 73.23 \\
#                                                                                                                                                                                                                                                           From which common English tree are cricket stumps traditionally made? &                                      what kind of wood is used for stumps in cricket &   0.0 &   10.00 &    9.17 &         79.89 & 73.04 \\
#                                                                                                                                                                                                                                                                        Which US comic superhero has the real name Steve Rogers? &                                                who is the first super hero in comics &   0.0 &   11.11 &    9.35 &         77.78 & 72.87 \\
#                                                                                                                                                                                                                                                              The Amazon rainforest makes up what amount of Earth's rainforests? &                                                      How many rainforests are there? &   0.0 &   12.50 &    8.77 &         84.49 & 72.82 \\
#                                                                                                                                                                                                           Which rival of the Mongols is suspected of inventing the story that Genghis Khan was murdered by a captured princess? &                                 Who did some Mongol authors believe stabbed Genghis? &   0.0 &    7.14 &    7.58 &         83.08 & 72.70 \\
#                                                                                                                                                                                                                                                                                             What nationality is singer Rhianna? &                                             Rihanna Fenty was born in which country? &   0.0 &    0.00 &    8.06 &         77.33 & 72.64 \\
#                                                                                                                                                                                                                                                                Luzon and Mindanao are the two largest islands in which country? &                     What is the official name of the archipelago of the Philippines? &   0.0 &    9.09 &    8.33 &         78.99 & 72.59 \\
#                                                                                                                                                                                                                                                In which film series would you expect to film Katniss Everdeen and Peeta Malark? &                                             what book is katniss in the hunger games &   0.0 &    9.09 &    6.99 &         76.92 & 72.07 \\
#                                                                                                                                                                                                                                                                                      Which country was invaded by Iraq in 1990? &                                     where did the iraq invasion of kuwait take place &   0.0 &   11.76 &    5.56 &         77.62 & 71.91 \\
#                                                                                                                                                                                                                                                In which film series would you expect to film Katniss Everdeen and Peeta Malark? &                                          what book is katniss in in the hunger games &   0.0 &    8.70 &    6.94 &         76.31 & 71.90 \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                           How many touchdowns did Eli Manning throw? &   0.0 &    8.70 &    6.21 &         81.06 & 71.88 \\
# ...
#                                                                                                                                                                                                                                                                                  In what year did Savery patent his steam pump? &                                             when was the first steam engine invented &   0.0 &   12.50 &    5.15 &         77.52 & 67.32 \\
#                                                                                                                                                                                                                                                                                  In what year did Savery patent his steam pump? &                                             when was the first steam engine invented &   0.0 &   12.50 &    5.15 &         77.52 & 67.32 \\
#                                                                                                                                                                                                                                                                        what is the number of total presidential electoral votes &                                           How many electors are there in a US state? &   0.0 &    0.00 &    5.49 &         72.67 & 67.29 \\
#                                                                                                                                                                                                                                                                                     how much did disneyland paris cost to build &                                     what was the cost of the first disney theme park &   0.0 &   11.11 &    6.10 &         80.01 & 67.27 \\
#                                                                                                                                                                                                                              Which group of around 200 Greek islands in the Aegean Sea includes Andros, Naxos, Paros and Milos? &                                                   where is mykonos located in greece &   0.0 &    8.70 &    2.69 &         78.57 & 67.26 \\
#                                                                                                                                                                                                                                                       How old were Jimmi Hendrix, Janis Joplin and Jim Morrison when they died? &                                                     What age did Kurt Cobain die at? &   0.0 &    0.00 &    6.99 &         78.12 & 67.25 \\
#                                                                                                                                                                                                                                                In which film series would you expect to film Katniss Everdeen and Peeta Malark? &                                               when does katniss win the hunger games &   0.0 &    9.52 &    3.52 &         75.81 & 67.25 \\
#                                                                                                                                                                                                                                                                       Which mythological creatures are half horse and half man? &                                  What was the name of one of the mythical creatures? &   0.0 &   10.53 &    9.90 &         79.79 & 67.23 \\
#                                                                                                                                                                                                                                                                who were the the continent of the americas named after logically &                                                     Who discovered America on a map? &   0.0 &   11.76 &    9.43 &         74.59 & 67.22 \\
#                                                                                                                                                                                                                                                                              Malaga airport serves which of the Spanish Costas? &                                             where is málaga airport located in spain &   0.0 &   12.50 &    5.68 &         80.28 & 67.20 \\
#                                                                                                                                                                                                                                                                         """Torchwood"" was a spin-off of what popular TV show?" &                           In which TV series did the character Jack Harkness appear? &   0.0 &   10.00 &    6.45 &         76.75 & 67.11 \\
#                                                                                                                                                                                                                                                           Which human blood group can receive blood from any other blood group? &                                                  What is the most common blood type? &   0.0 &   10.53 &    8.00 &         80.67 & 67.05 \\
#                                                                                                                                                                                                                                                           Which human blood group can receive blood from any other blood group? &                                                  What is the most common blood type? &   0.0 &   10.53 &    8.00 &         80.67 & 67.05 \\
#                                                                                                                                                                                                                                                 What happens to the jellyfish nematocysts when they are eaten by the haeckelia? &                                                How do ctenophores prey on jellyfish? &   0.0 &   10.53 &    7.52 &         80.05 & 67.01 \\
#                                                                                                                                                                                                                                                           Which quadrilateral has one pair of parallel edges of unequal length? &                                            what type of quadrilateral is a rectangle &   0.0 &   11.11 &    8.70 &         85.94 & 65.66 \\
#                                                                                                                                                                                                                                                                                             How many Kenyans are non-religious? &                        What percentage of Kenya's Muslim population is nonreligious? &   0.0 &    0.00 &    7.81 &         85.33 & 63.82 \\
#                                                                                                                                                                                                                                                                                                    How large are Plastoglobuli? &                                                 what is the size of a plastoglobulus &   0.0 &    0.00 &    0.00 &         86.19 & 62.21 \\
#                                                                                                                                                                                                                                                                                                    How big can ctenophora grow? &                                            What is the average size of a ctenophore? &   0.0 &    0.00 &    7.94 &         85.11 & 62.19 \\
#                                                                                                                                                                                                                                                                                                  How large can ctenophora grow? &                                     What is the maximum size of an adult ctenophore? &   0.0 &    0.00 &    7.81 &         86.46 & 53.38 \\
#                                                                                                                                                                                                                                                                                                  How large can ctenophora grow? &                                            What is the average size of a ctenophore? &   0.0 &    0.00 &    7.94 &         86.02 & 52.60 \\
#                                                                                                                                                                                                                                                                                                    How large are Plastoglobuli? &                                                what is the length of a plastoglobule &   0.0 &    0.00 &    0.00 &         85.67 & 52.23 \\
#                                                                                                                                                                                                                                                       Ashkenazic and sephardic cuisines are associated with which ethnic group? &                                                          What ethnicity is Sephardi? &   0.0 &    0.00 &    9.62 &         85.16 & 51.86 \\
#                                                                                                                                                                                                                                                                                    How long ago did cyanobacteria enter a cell? &                                                  When was cyanobacterium discovered? &   0.0 &    0.00 &    5.81 &         88.65 & 50.54 \\
#                                                                                                                                                                                                                                                                                          Curacao was a colony of which country? &                                                            Where is Curaçao located? &   0.0 &    0.00 &    6.49 &         86.25 & 49.44 \\
#                                                                                                                                                                                                                                                                                                    Were their songs successful? &                                                         Did they release any albums? &   0.0 &    0.00 &    9.80 &         85.73 & 46.15 \\
#                                                                                                                                                                                                                                                                                                    Were their songs successful? &                                                         Did they release any albums? &   0.0 &    0.00 &    9.80 &         85.73 & 46.15 \\
#                                                                                                                                                                                                                                                                   What English chemist showed that fire only needed nitoaereus? &                          who discovered that nitroaereus is necessary for combustion &   0.0 &   11.76 &    5.10 &         85.58 & 45.36 \\
#                                                                                                                                                                                                                                                                                                    How large are Plastoglobuli? &                                             what is the diameter of a plastoglobulus &   0.0 &    0.00 &    0.00 &         85.48 & 45.13 \\
#                                                                                                                                                                                                                                                                                               How are ergänzungsschulen funded? &                                      What does Ergungsschulen charge their students? &   0.0 &    0.00 &    9.62 &         86.88 & 28.78 \\
#                                                                                                                                                                                                                         Who explained that inertial reference frames equaled reference frames subject to constant acceleration? &                                       Who extended the principle of inertia further? &   0.0 &   10.00 &    7.46 &         85.04 & 24.03 \\
#                                                                                                                                                                                                                         Who explained that inertial reference frames equaled reference frames subject to constant acceleration? &                                       Who extended the principle of inertia further? &   0.0 &   10.00 &    7.46 &         85.04 & 24.03 \\
#                                                                                                                                                                                                                         Who explained that inertial reference frames equaled reference frames subject to constant acceleration? &                                       Who extended the principle of inertia further? &   0.0 &   10.00 &    7.46 &         85.04 & 24.03 \\
#                                                                                                                                                                                                                                                                                               How are ergänzungsschulen funded? &                         s, fees, and what else? What does a Ergänzungsschule charge? &   0.0 &   12.50 &    8.47 &         86.71 & 13.26 \\
#                                                                                                                                                                                                                                                                                   What do Plastoglobuli exchange contents with? &                                     The plastoglobulus is anchored to which network? &   0.0 &    0.00 &    7.04 &         86.28 &  6.68 \\
# \bottomrule
# \end{tabular}

# %%
# Convert to Latex
print(hi_sem_low_lex[["target", "prediction"]].to_latex(index=False))

# Print entire text
with pd.option_context("max_colwidth", 1000):
    print (hi_sem_low_lex[["target", "prediction"]].to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                             target &                                         prediction \\
# \midrule
#             who is beauty and the beast written by &                     Who wrote La Belle et la Bête? \\
# What is the record number of touchdowns Cam New... & how many touchdowns did the carolina panthers h... \\
# what is the first basic process in the light re... &                     How does photosynthesis begin? \\
# what is the first basic process in the light re... &                     How does photosynthesis begin? \\
# On what date was the record low temperature in ... &        when did fresno get its highest temperature \\
# After he left Barcelona, football manager Pep G... &          who is guardiola the manager of barcelona \\
#               How large are Cytoplasmic ribosomes? &         what is the size of a chloroplast ribosome \\
# What was the nationality of composer Frederic C... &                where did frédéric chopin come from \\
# Which grape is used to produce top-quality Burg... &          what kind of grapes are grown in burgundy \\
# How much rain per year does Fresno get on average? & what is the average precipitation in fresno cal... \\
# Which planet weighs more than all the other pla... &            What planet is twice as large as Earth? \\
#                                   How did she die? &                       What was her cause of death? \\
# What was the number of 17 interceptions that Pe... &             How many touchdowns did Manning throw? \\
# What was the number of 17 interceptions that Pe... &             How many touchdowns did Manning throw? \\
# What was the number of 17 interceptions that Pe... &             How many touchdowns did Manning throw? \\
# What was the number of 17 interceptions that Pe... &             how many touchdowns did Manning throw? \\
# What was the number of 17 interceptions that Pe... & how many touchdowns did manning throw in his ca... \\
# What vehicle did Doctor Who use for his escape ... &                    What is the name of the TARDIS? \\
# Which band released a 2001 album entitled ‘Amne... &       what was the name of radiohead's first album \\
# Which band released a 2001 album entitled ‘Amne... &      What was the name of Radiohead's first album? \\
# Which band released a 2001 album entitled ‘Amne... &      What was the name of Radiohead's first album? \\
# Which band released a 2001 album entitled ‘Amne... &      What was the name of Radiohead's first album? \\
# What is the fictional location of the tv soap ‘... &         where does eastenders take place in london \\
# "Who produces the perfumes ""Opium"" and ""Rive... &          Opium is a perfume made by which company? \\
# What was the number of 17 interceptions that Pe... &      how many touchdowns did manning throw in 2018 \\
#         what is the population of st petersburg fl & How many people lived in Saint Petersburg in 2015? \\
# From which common English tree are cricket stum... &    what kind of wood is used for stumps in cricket \\
# Which US comic superhero has the real name Stev... &              who is the first super hero in comics \\
# The Amazon rainforest makes up what amount of E... &                    How many rainforests are there? \\
# Which rival of the Mongols is suspected of inve... & Who did some Mongol authors believe stabbed Gen... \\
#                What nationality is singer Rhianna? &           Rihanna Fenty was born in which country? \\
# Luzon and Mindanao are the two largest islands ... & What is the official name of the archipelago of... \\
# In which film series would you expect to film K... &           what book is katniss in the hunger games \\
#         Which country was invaded by Iraq in 1990? &   where did the iraq invasion of kuwait take place \\
# In which film series would you expect to film K... &        what book is katniss in in the hunger games \\
# What was the number of 17 interceptions that Pe... &         How many touchdowns did Eli Manning throw? \\
# when did starbucks become a publicly traded com... & Which year was the Starbucks IPO on the stock m... \\
# From which country was Fulgencio Batista ousted... &        where did batista become president of cuban \\
#               Which tribes did Genghis Khan unite? &                              Who were the Mongols? \\
# The left side of the heart pumps blood to all p... &             What other organs does the heart pump? \\
# What, generally, is the par on a 300 yard golf ... &                   how many holes are there in golf \\
# Which World War 2 American general was known as... & what was the name of the us general who served ... \\
#          name a food you might eat on thanksgiving & what is the main ingredient of thanksgiving dinner \\
#      when did marathon change its name to snickers &     In which year was the Snickers brand launched? \\
#   Author J.R.R. Tolkien was born in which country? &          where did the last name tolkien come from \\
#                                     how did he die &                   What was the cause of his death? \\
#   Where did Tesla look for investors prior to WWI? & : before World War I, Tesla sought funding from... \\
#         Which Tsar of Russia ruled from 1682-1725? &                 Who proclaimed the Russian Empire? \\
#         Which Tsar of Russia ruled from 1682-1725? &                 Who proclaimed the Russian Empire? \\
# Which Apollo mission, which was launched on Jul... &                           What year was Apollo 11? \\
# Which planet in our solar system has the shorte... &                      What other planets are there? \\
# What was the overly generous royalty amount tha... &                         How much did he pay Tesla? \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig,... & Who voiced Bugs Bunny in the Looney Tunes carto... \\
#                                   How did she die? &                   What was the cause of her death? \\
#                                   How did she die? &                   What was the cause of her death? \\
# What was the first name of Mr. Ferrari, the fou... &                               Who founded Ferrari? \\
# What year did Doctor Who finally return to tele... & when was the last time dr who had a christmas s... \\
#          Which fruit is known as ananas in French? &            what is the name of the pineapple plant \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig,... & Who voiced Bugs Bunny in the Looney Tunes and M... \\
#          Which fruit is known as ananas in French? &         what is the scientific name of a pineapple \\
# Which World war 2 American general was nickname... & what was the name of the us general who served ... \\
# Which young general did Genghis Khan send to co... &       who led the mongols in the battle of kuchlug \\
# In 'Scarface' which character was played by Al ... &           who played mr. corleone in the godfather \\
# What is the most rainfall recorded in a 24 hour... &           how much rain does fresno get in one day \\
# What year is the earliest traces of the color C... &           when did red start being used in harvard \\
#            Odysseus was King of which Greek state? & where did the odyssey take place in greek mytho... \\
# Which young general did Genghis Khan send to co... &            who led the mongol army against kuchlug \\
# Marat, Robespierre, Danton are names associated... & what revolution did maximilian robespierre lead in \\
# Which cartoon title character has a friend call... &     who is the captain in the adventures of tintin \\
# Among whom was Genghis Khan's empire split afte... &        who divided the mongol empire into khanates \\
#        what happened to western rome after it fell &              what was the fall of the roman empire \\
#        how much did disneyland paris cost to build & What was the construction budget for the Euro D... \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig,... &          who voiced bugs bunny in the looney tunes \\
# In what year did Lavoisier publish his work on ... & when was the book sur la combustion en général ... \\
# What are we unsure of about how chloroplasts ma... & where does methionine come from in the chloroplast \\
# What was the name given to the German annexatio... &        when did austria become a member of germany \\
# Which boxer fought Mohammed Ali in the fight kn... & Who was the third and final boxing match betwee... \\
#   Who bought Chelsea football club for £1 in 1982? & What was the name of the former owner of Chelse... \\
# What is the next in the series: Nigeria, Sierra... & Which African country is bordered by Botswana, ... \\
# "Which game has been played in England since Tu... & what is the name of the first baseball game played \\
#              when did goku first go super saiyan 4 & What was the name of the battle between Goku an... \\
# In which American state would you find Mt. Rush... &    where is mount rushmore located in south dakota \\
# when did lionel messi play his first game for b... &  The Messi family moved to Camp Nou in which year? \\
# How many people do historians estimate Genghis ... & what was the population of iran during the mong... \\
#        where does half life 2 episode 2 take place &                    where do the gman and alyx meet \\
# Which cigarette manufacturer used to boast of i... & What is the name of the cigarette company that ... \\
# What is the population of the second largest ci... &               How many people live in Los Angeles? \\
# Flourine, Bromine, Iodine and Chlorine are all ... &       what group is chlorine in the periodic table \\
#     What was the black death originally blamed on? &           who caused the plague in the middle ages \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig,... & Who voiced Wile E Coyote in the Looney Tunes ca... \\
# Cayenne, after which the spicy condiment is nam... &       where does the name cayenne pepper come from \\
# What was Edison's reply as to what Tesla didn't... &               where did the phrase tesla come from \\
# Whom did Andy Murray defeat in the Wimbledon me... &         who won the 2017 us open tennis tournament \\
# Whom did Andy Murray defeat in the Wimbledon me... &         who won the 2017 us open tennis tournament \\
# To which order of monks does or did Pope Franci... &             Who were the first non-European popes? \\
# what is the first basic process in the light re... &                    When does photosynthesis begin? \\
#        what happened to western rome after it fell & what was the result of the fall of the roman em... \\
#        what happened to western rome after it fell & what was the result of the fall of the roman em... \\
# Sea World is in Mission Bay Park in which US city? &                where is seaworld san diego located \\
#                    What delivery message was used  &                    How did Baran deliver messages? \\
#                    What delivery message was used  &                    How did Baran deliver messages? \\
#                    What delivery message was used  &                    How did Baran deliver messages? \\
# What was the total number of patents that Tesla... &                      How many patents did he have? \\
# By what name do Czechs know their capital city,... &         where is the capital of the czech republic \\
# In which film series would you expect to film K... & where does peeta Mellark come from in the hunge... \\
# How many people does the Greater Los Angeles Ar... &      what is the population of southern california \\
# How many people does the Greater Los Angeles Ar... &      what is the population of southern california \\
# Which two Mongol leaders added Persia to the Mo... &             who led the mongols in the caspian sea \\
# Which two Mongol leaders added Persia to the Mo... &             who led the mongols in the caspian sea \\
# The 2009 season of the Indian Premier League, a... &       where was the first t20 cricket match played \\
#           Why did Luther condemn vows of celibacy? &  what was the reason for luther's refusal to marry \\
# Kenneth Wolstenholme was a commentator for whic... &       what is the name of the football commentator \\
# Sanskrit is an ancient language of which modern... &              where is sanskrit spoken in the world \\
# what is the first basic process in the light re... &          where does photosynthesis begin in plants \\
# What was Tesla's father's original plans for Te... &                  where did tesla go to high school \\
# What is the population of the Inner Mongolia re... &                how many mongols are there in china \\
# What is the population of the Inner Mongolia re... &                how many mongols are there in china \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig,... &          who played daffy duck in the looney tunes \\
#      What did Shaq have to do with law enforcement &            How did O'Neal become a police officer? \\
#                              Why were they rivals? &                        What was the rivalry about? \\
#  In which children's TV series does Shaggy appear? &           what is the name of the scooby doo movie \\
#            What part of the body produces insulin? &    where does insulin come from in type 2 diabetes \\
#   Which 'superhero's' alter ego is 'Peter Parker'? & what is the name of the first spiderman comic book \\
# How many inhabitants does the Los Angeles area ... &      what is the population of southern california \\
# How many inhabitants does the Los Angeles area ... &      what is the population of southern california \\
#             who played kelly taylor's mom on 90210 & What is the name of the mother of Kelly Walsh i... \\
# Which human blood group can receive blood from ... &        What is the most common type of blood type? \\
# Jose Mourinho was appointed manager of which fo... & What team did José Mourinho manage at in the 19... \\
#         Which Tsar of Russia ruled from 1682-1725? &             who founded the russian empire in 1721 \\
# In which English county was former British Prim... &                  where did thatcher live in the uk \\
# In which U.S. State is the University of Harvar... &             where did harvard college get its name \\
# In 'Brookside', which actress, later to become ... &              who played heather in brookside close \\
# What became the last city on earth to experienc... &  where did the atomic bombings take place in japan \\
# What was Manning's passer rating at the end of ... & How many points did Peyton Manning score in his... \\
#         Which Tsar of Russia ruled from 1682-1725? &         who established the russian empire in 1721 \\
# Which English football league team are known as... & what is the name of peterborough united footbal... \\
#   Which 'superhero's' alter ego is 'Peter Parker'? & What is the name of the super-hero in the comic... \\
#         Roald Dahl's BFG was a big, friendly what? &           what is the name of the giant in the bfg \\
#         Roald Dahl's BFG was a big, friendly what? &           what is the name of the giant in the bFG \\
# What is each section of ten beads on a rosary c... &            How many years are there in the Rosary? \\
# What became the last city on earth to experienc... &      where did the bombing of hiroshima take place \\
# How do centripetal forces act in relation to ve... &      what is the direction of the tangential force \\
# Which young general did Genghis Khan send to co... &     Who commanded the Mongol army against Kuchlug? \\
#                What was the date of Tesla's death? &             when did niota tesla die in new yorker \\
# What year did Newton hold the number one draft ... & when was the first quarterback picked in the su... \\
# What were the names of the founder of British c... &                           Who founded JCB in 1945? \\
# What were the names of the founder of British c... &                           Who founded JCB in 1945? \\
# What were the names of the founder of British c... &                           Who founded JCB in 1945? \\
# What were the names of the founder of British c... &                           Who founded JCB in 1945? \\
# Which boy band consists of Niall Horan, Zayn Ma... &                      who is niall from in x factor \\
# How do Mongolians sometime describe their relat... &                   who is the father of the mongols \\
# what is the number of total presidential electo... &         How many electors are there in each state? \\
# Which group did Steve Marriot go on to form whe... &        What was the name of Steve Marriott's band? \\
# Which group did Steve Marriot go on to form whe... &        What was the name of Steve Marriott's band? \\
# Fossils found that were believed to be ctenopho... &     when did the first ctenophore fossils come out \\
# What percentage of Scotland's voting population... &           How many people voted in the referendum? \\
#     In what year did Savery patent his steam pump? &           when was the first steam engine invented \\
#     In what year did Savery patent his steam pump? &           when was the first steam engine invented \\
# what is the number of total presidential electo... &         How many electors are there in a US state? \\
#        how much did disneyland paris cost to build &   what was the cost of the first disney theme park \\
# Which group of around 200 Greek islands in the ... &                 where is mykonos located in greece \\
# How old were Jimmi Hendrix, Janis Joplin and Ji... &                   What age did Kurt Cobain die at? \\
# In which film series would you expect to film K... &             when does katniss win the hunger games \\
# Which mythological creatures are half horse and... & What was the name of one of the mythical creatu... \\
# who were the the continent of the americas name... &                   Who discovered America on a map? \\
# Malaga airport serves which of the Spanish Costas? &           where is málaga airport located in spain \\
# """Torchwood"" was a spin-off of what popular T... & In which TV series did the character Jack Harkn... \\
# Which human blood group can receive blood from ... &                What is the most common blood type? \\
# Which human blood group can receive blood from ... &                What is the most common blood type? \\
# What happens to the jellyfish nematocysts when ... &              How do ctenophores prey on jellyfish? \\
# Which quadrilateral has one pair of parallel ed... &          what type of quadrilateral is a rectangle \\
#                How many Kenyans are non-religious? & What percentage of Kenya's Muslim population is... \\
#                       How large are Plastoglobuli? &               what is the size of a plastoglobulus \\
#                       How big can ctenophora grow? &          What is the average size of a ctenophore? \\
#                     How large can ctenophora grow? &   What is the maximum size of an adult ctenophore? \\
#                     How large can ctenophora grow? &          What is the average size of a ctenophore? \\
#                       How large are Plastoglobuli? &              what is the length of a plastoglobule \\
# Ashkenazic and sephardic cuisines are associate... &                        What ethnicity is Sephardi? \\
#       How long ago did cyanobacteria enter a cell? &                When was cyanobacterium discovered? \\
#             Curacao was a colony of which country? &                          Where is Curaçao located? \\
#                       Were their songs successful? &                       Did they release any albums? \\
#                       Were their songs successful? &                       Did they release any albums? \\
# What English chemist showed that fire only need... & who discovered that nitroaereus is necessary fo... \\
#                       How large are Plastoglobuli? &           what is the diameter of a plastoglobulus \\
#                  How are ergänzungsschulen funded? &    What does Ergungsschulen charge their students? \\
# Who explained that inertial reference frames eq... &     Who extended the principle of inertia further? \\
# Who explained that inertial reference frames eq... &     Who extended the principle of inertia further? \\
# Who explained that inertial reference frames eq... &     Who extended the principle of inertia further? \\
#                  How are ergänzungsschulen funded? & s, fees, and what else? What does a Ergänzungss... \\
#      What do Plastoglobuli exchange contents with? &   The plastoglobulus is anchored to which network? \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{ll}
# \toprule
#                                                                                                                                                                                                                                                                                                                          target &                                                                           prediction \\
# \midrule
#                                                                                                                                                                                                                                                                                          who is beauty and the beast written by &                                                       Who wrote La Belle et la Bête? \\
#                                                                                                                                                                                                                                                                    What is the record number of touchdowns Cam Newton has had?  &                         how many touchdowns did the carolina panthers have last year \\
#                                                                                                                                                                                                                                                         what is the first basic process in the light reaction of photosynthesis &                                                       How does photosynthesis begin? \\
#                                                                                                                                                                                                                                                         what is the first basic process in the light reaction of photosynthesis &                                                       How does photosynthesis begin? \\
#                                                                                                                                                                                                                                                                          On what date was the record low temperature in Fresno? &                                          when did fresno get its highest temperature \\
#                                                                                                                                                                                                                          After he left Barcelona, football manager Pep Guardiola went on to manage which European club in 2013? &                                            who is guardiola the manager of barcelona \\
#                                                                                                                                                                                                                                                                                            How large are Cytoplasmic ribosomes? &                                           what is the size of a chloroplast ribosome \\
#                                                                                                                                                                                                                                                                           What was the nationality of composer Frederic Chopin? &                                                  where did frédéric chopin come from \\
#                                                                                                                                                                                                                                                                  Which grape is used to produce top-quality Burgundy red wines? &                                            what kind of grapes are grown in burgundy \\
#                                                                                                                                                                                                                                                                              How much rain per year does Fresno get on average? &                               what is the average precipitation in fresno california \\
#                                                                                                                                                                                                                                               Which planet weighs more than all the other planets of our solar system combined? &                                              What planet is twice as large as Earth? \\
#                                                                                                                                                                                                                                                                                                                How did she die? &                                                         What was her cause of death? \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                               How many touchdowns did Manning throw? \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                               How many touchdowns did Manning throw? \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                               How many touchdowns did Manning throw? \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                               how many touchdowns did Manning throw? \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                  how many touchdowns did manning throw in his career \\
#                                                                                                                                                                                                                                                                  What vehicle did Doctor Who use for his escape from Gallifrey? &                                                      What is the name of the TARDIS? \\
#                                                                                                                                                                                                                                                                           Which band released a 2001 album entitled ‘Amnesiac’? &                                         what was the name of radiohead's first album \\
#                                                                                                                                                                                                                                                                           Which band released a 2001 album entitled ‘Amnesiac’? &                                        What was the name of Radiohead's first album? \\
#                                                                                                                                                                                                                                                                           Which band released a 2001 album entitled ‘Amnesiac’? &                                        What was the name of Radiohead's first album? \\
#                                                                                                                                                                                                                                                                           Which band released a 2001 album entitled ‘Amnesiac’? &                                        What was the name of Radiohead's first album? \\
#                                                                                                                                                                                                                                                                     What is the fictional location of the tv soap ‘Eastenders’? &                                           where does eastenders take place in london \\
#                                                                                                                                                                                                                                                                      "Who produces the perfumes ""Opium"" and ""Rive Gauche""?" &                                            Opium is a perfume made by which company? \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                        how many touchdowns did manning throw in 2018 \\
#                                                                                                                                                                                                                                                                                      what is the population of st petersburg fl &                                   How many people lived in Saint Petersburg in 2015? \\
#                                                                                                                                                                                                                                                           From which common English tree are cricket stumps traditionally made? &                                      what kind of wood is used for stumps in cricket \\
#                                                                                                                                                                                                                                                                        Which US comic superhero has the real name Steve Rogers? &                                                who is the first super hero in comics \\
#                                                                                                                                                                                                                                                              The Amazon rainforest makes up what amount of Earth's rainforests? &                                                      How many rainforests are there? \\
#                                                                                                                                                                                                           Which rival of the Mongols is suspected of inventing the story that Genghis Khan was murdered by a captured princess? &                                 Who did some Mongol authors believe stabbed Genghis? \\
#                                                                                                                                                                                                                                                                                             What nationality is singer Rhianna? &                                             Rihanna Fenty was born in which country? \\
#                                                                                                                                                                                                                                                                Luzon and Mindanao are the two largest islands in which country? &                     What is the official name of the archipelago of the Philippines? \\
#                                                                                                                                                                                                                                                In which film series would you expect to film Katniss Everdeen and Peeta Malark? &                                             what book is katniss in the hunger games \\
#                                                                                                                                                                                                                                                                                      Which country was invaded by Iraq in 1990? &                                     where did the iraq invasion of kuwait take place \\
#                                                                                                                                                                                                                                                In which film series would you expect to film Katniss Everdeen and Peeta Malark? &                                          what book is katniss in in the hunger games \\
#                                                                                                                                                                                                                                             What was the number of 17 interceptions that Peyton Manning had by end of the year? &                                           How many touchdowns did Eli Manning throw? \\
#                                                                                                                                                                                                                                                                             when did starbucks become a publicly traded company &                                Which year was the Starbucks IPO on the stock market? \\
#                                                                                                                                                                                                                                                                        From which country was Fulgencio Batista ousted in 1959? &                                          where did batista become president of cuban \\
#                                                                                                                                                                                                                                                                                            Which tribes did Genghis Khan unite? &                                                                Who were the Mongols? \\
#                                                                                                                                                                                                   The left side of the heart pumps blood to all parts of the body, but the right side pumps blood to which organ in particular? &                                               What other organs does the heart pump? \\
#                                                                                                                                                                                                                                                                            What, generally, is the par on a 300 yard golf hole? &                                                     how many holes are there in golf \\
#                                                                                                                                                                                                                                                                  Which World War 2 American general was known as 'Vinegar Joe'? &                                what was the name of the us general who served in ww2 \\
#                                                                                                                                                                                                                                                                                       name a food you might eat on thanksgiving &                                   what is the main ingredient of thanksgiving dinner \\
#                                                                                                                                                                                                                                                                                   when did marathon change its name to snickers &                                       In which year was the Snickers brand launched? \\
#                                                                                                                                                                                                                                                                                Author J.R.R. Tolkien was born in which country? &                                            where did the last name tolkien come from \\
#                                                                                                                                                                                                                                                                                                                  how did he die &                                                     What was the cause of his death? \\
#                                                                                                                                                                                                                                                                                Where did Tesla look for investors prior to WWI? &        : before World War I, Tesla sought funding from his patents in which country? \\
#                                                                                                                                                                                                                                                                                      Which Tsar of Russia ruled from 1682-1725? &                                                   Who proclaimed the Russian Empire? \\
#                                                                                                                                                                                                                                                                                      Which Tsar of Russia ruled from 1682-1725? &                                                   Who proclaimed the Russian Empire? \\
#                                                                                                                                                                                                                            Which Apollo mission, which was launched on July 16, 1969, was the first to put a human on the moon? &                                                             What year was Apollo 11? \\
#                                                                                                                                                                                                                                                                         Which planet in our solar system has the shortest year? &                                                        What other planets are there? \\
#                                                                                                                                                                                                                                                     What was the overly generous royalty amount that Tesla had been receiving?  &                                                           How much did he pay Tesla? \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig, Sylvester the Cat, Tweety Bird, Foghorn Leghorn, Yosemite Sam, Wile E. Coyote, Woody Woodpecker, Barney Rubble, Mr. Spacely, Speed Buggy, Captain Caveman, Heathcliff, Speedy Gonzales, Elmer Fudd and hundreds of others, which American voice actor was born on May 30, 1908? &                            Who voiced Bugs Bunny in the Looney Tunes cartoon series? \\
#                                                                                                                                                                                                                                                                                                                How did she die? &                                                     What was the cause of her death? \\
#                                                                                                                                                                                                                                                                                                                How did she die? &                                                     What was the cause of her death? \\
#                                                                                                                                                                                                                                           What was the first name of Mr. Ferrari, the founder of the car manufacturing company? &                                                                 Who founded Ferrari? \\
#                                                                                                                                                                                                                                                                          What year did Doctor Who finally return to television? &                                when was the last time dr who had a christmas special \\
#                                                                                                                                                                                                                                                                                       Which fruit is known as ananas in French? &                                              what is the name of the pineapple plant \\
# The voice of Bugs Bunny, Daffy Duck, Porky Pig, Sylvester the Cat, Tweety Bird, Foghorn Leghorn, Yosemite Sam, Wile E. Coyote, Woody Woodpecker, Barney Rubble, Mr. Spacely, Speed Buggy, Captain Caveman, Heathcliff, Speedy Gonzales, Elmer Fudd and hundreds of others, which American voice actor was born on May 30, 1908? &              Who voiced Bugs Bunny in the Looney Tunes and Merrie Melodies cartoons? \\
#                                                                                                                                                                                                                                                                                       Which fruit is known as ananas in French? &                                           what is the scientific name of a pineapple \\
#                                                                                                                                                                                                                                                                 Which World war 2 American general was nicknamed “Vinegar Joe”? &                                what was the name of the us general who served in ww2 \\
#                                                                                                                                                                                                                                                               Which young general did Genghis Khan send to conquer Qara Khitai? &                                         who led the mongols in the battle of kuchlug \\
#                                                                                                                                                                                                                                                                          In 'Scarface' which character was played by Al Pacino? &                                             who played mr. corleone in the godfather \\
#                                                                                                                                                                                                                                                               What is the most rainfall recorded in a 24 hour period in Fresno? &                                             how much rain does fresno get in one day \\
#                                                                                                                                                                                                                                                               What year is the earliest traces of the color Crimson at Harvard? &                                             when did red start being used in harvard \\
# ...
#                                                                                                                                                                                                                                                     Which group did Steve Marriot go on to form when he left the 'Small Faces'? &                                          What was the name of Steve Marriott's band? \\
#                                                                                                                                                                                                                                                     Which group did Steve Marriot go on to form when he left the 'Small Faces'? &                                          What was the name of Steve Marriott's band? \\
#                                                                                                                                                                                                                                                                Fossils found that were believed to be ctenophores were how old? &                                       when did the first ctenophore fossils come out \\
#                                                                                                                                                                                                                                                        What percentage of Scotland's voting population failed to actually vote? &                                             How many people voted in the referendum? \\
#                                                                                                                                                                                                                                                                                  In what year did Savery patent his steam pump? &                                             when was the first steam engine invented \\
#                                                                                                                                                                                                                                                                                  In what year did Savery patent his steam pump? &                                             when was the first steam engine invented \\
#                                                                                                                                                                                                                                                                        what is the number of total presidential electoral votes &                                           How many electors are there in a US state? \\
#                                                                                                                                                                                                                                                                                     how much did disneyland paris cost to build &                                     what was the cost of the first disney theme park \\
#                                                                                                                                                                                                                              Which group of around 200 Greek islands in the Aegean Sea includes Andros, Naxos, Paros and Milos? &                                                   where is mykonos located in greece \\
#                                                                                                                                                                                                                                                       How old were Jimmi Hendrix, Janis Joplin and Jim Morrison when they died? &                                                     What age did Kurt Cobain die at? \\
#                                                                                                                                                                                                                                                In which film series would you expect to film Katniss Everdeen and Peeta Malark? &                                               when does katniss win the hunger games \\
#                                                                                                                                                                                                                                                                       Which mythological creatures are half horse and half man? &                                  What was the name of one of the mythical creatures? \\
#                                                                                                                                                                                                                                                                who were the the continent of the americas named after logically &                                                     Who discovered America on a map? \\
#                                                                                                                                                                                                                                                                              Malaga airport serves which of the Spanish Costas? &                                             where is málaga airport located in spain \\
#                                                                                                                                                                                                                                                                         """Torchwood"" was a spin-off of what popular TV show?" &                           In which TV series did the character Jack Harkness appear? \\
#                                                                                                                                                                                                                                                           Which human blood group can receive blood from any other blood group? &                                                  What is the most common blood type? \\
#                                                                                                                                                                                                                                                           Which human blood group can receive blood from any other blood group? &                                                  What is the most common blood type? \\
#                                                                                                                                                                                                                                                 What happens to the jellyfish nematocysts when they are eaten by the haeckelia? &                                                How do ctenophores prey on jellyfish? \\
#                                                                                                                                                                                                                                                           Which quadrilateral has one pair of parallel edges of unequal length? &                                            what type of quadrilateral is a rectangle \\
#                                                                                                                                                                                                                                                                                             How many Kenyans are non-religious? &                        What percentage of Kenya's Muslim population is nonreligious? \\
#                                                                                                                                                                                                                                                                                                    How large are Plastoglobuli? &                                                 what is the size of a plastoglobulus \\
#                                                                                                                                                                                                                                                                                                    How big can ctenophora grow? &                                            What is the average size of a ctenophore? \\
#                                                                                                                                                                                                                                                                                                  How large can ctenophora grow? &                                     What is the maximum size of an adult ctenophore? \\
#                                                                                                                                                                                                                                                                                                  How large can ctenophora grow? &                                            What is the average size of a ctenophore? \\
#                                                                                                                                                                                                                                                                                                    How large are Plastoglobuli? &                                                what is the length of a plastoglobule \\
#                                                                                                                                                                                                                                                       Ashkenazic and sephardic cuisines are associated with which ethnic group? &                                                          What ethnicity is Sephardi? \\
#                                                                                                                                                                                                                                                                                    How long ago did cyanobacteria enter a cell? &                                                  When was cyanobacterium discovered? \\
#                                                                                                                                                                                                                                                                                          Curacao was a colony of which country? &                                                            Where is Curaçao located? \\
#                                                                                                                                                                                                                                                                                                    Were their songs successful? &                                                         Did they release any albums? \\
#                                                                                                                                                                                                                                                                                                    Were their songs successful? &                                                         Did they release any albums? \\
#                                                                                                                                                                                                                                                                   What English chemist showed that fire only needed nitoaereus? &                          who discovered that nitroaereus is necessary for combustion \\
#                                                                                                                                                                                                                                                                                                    How large are Plastoglobuli? &                                             what is the diameter of a plastoglobulus \\
#                                                                                                                                                                                                                                                                                               How are ergänzungsschulen funded? &                                      What does Ergungsschulen charge their students? \\
#                                                                                                                                                                                                                         Who explained that inertial reference frames equaled reference frames subject to constant acceleration? &                                       Who extended the principle of inertia further? \\
#                                                                                                                                                                                                                         Who explained that inertial reference frames equaled reference frames subject to constant acceleration? &                                       Who extended the principle of inertia further? \\
#                                                                                                                                                                                                                         Who explained that inertial reference frames equaled reference frames subject to constant acceleration? &                                       Who extended the principle of inertia further? \\
#                                                                                                                                                                                                                                                                                               How are ergänzungsschulen funded? &                         s, fees, and what else? What does a Ergänzungsschule charge? \\
#                                                                                                                                                                                                                                                                                   What do Plastoglobuli exchange contents with? &                                     The plastoglobulus is anchored to which network? \\
# \bottomrule
# \end{tabular}

# %%
# Convert to Latex
print(hi_sem_low_lex[["base_model", "target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]].to_latex(index=False))
# Out:
# \begin{tabular}{lllrrrrr}
# \toprule
# base\_model &                                             target &                       prediction &  bleu &  rougeL &   meteor &  bertscore-f1 &      use \\
# \midrule
#       bart &                                   How did she die? &     What was her cause of death? &   0.0 &   0.000 & 0.096154 &      0.855320 & 0.754843 \\
#       bart &                                   How did she die? & What was the cause of her death? &   0.0 &   0.000 & 0.094340 &      0.851208 & 0.705527 \\
#         T5 &                                   How did she die? & What was the cause of her death? &   0.0 &   0.000 & 0.094340 &      0.851208 & 0.705527 \\
#       bart & What was the total number of patents that Tesla... &    How many patents did he have? &   0.0 &   0.125 & 0.094340 &      0.862127 & 0.687061 \\
# \bottomrule
# \end{tabular}

# %%
spec_ex = clean_eval_df[
    (clean_eval_df["target"] == "What country has slums known as favelas?")
   # & (clean_eval_df["nickname"] == "T5_nq_squad")
]

spec_ex = spec_ex[["nickname", "target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]]

spec_ex
# Out:
#                       nickname                                    target  \
# 19091         bart_nq_triviaqa  What country has slums known as favelas?
# 47720       bart_quac_triviaqa  What country has slums known as favelas?
# 76349      bart_squad_triviaqa  What country has slums known as favelas?
# 104978  bart_triviaqa_triviaqa  What country has slums known as favelas?
# 133607   bart_amalgam_triviaqa  What country has slums known as favelas?
# 162236          T5_nq_triviaqa  What country has slums known as favelas?
# 190865        T5_quac_triviaqa  What country has slums known as favelas?
# 219494       T5_squad_triviaqa  What country has slums known as favelas?
# 248123    T5_triviaqa_triviaqa  What country has slums known as favelas?
# 276752     T5_amalgam_triviaqa  What country has slums known as favelas?
#
#                                                prediction  bleu    rougeL  \
# 19091                 where did the term favela come from   0.0  0.000000
# 47720                       Where was the favela located?   0.0  0.000000
# 76349                          Where is a favela located?   0.0  0.000000
# 104978          In which country would you find a favela?   0.0  0.133333
# 133607  In which South American country would you find...   0.0  0.117647
# 162236                where did the term favela come from   0.0  0.000000
# 190865  Are there any other interesting aspects about ...   0.0  0.000000
# 219494  What country did the military dictatorship pio...   0.0  0.235294
# 248123                 What country is known as a favela?   0.0  0.571429
# 276752          In which country would you find a favela?   0.0  0.133333
#
#           meteor  bertscore-f1       use
# 19091   0.063291      0.776472  0.619927
# 47720   0.128205      0.820271  0.631844
# 76349   0.128205      0.833733  0.654554
# 104978  0.315501      0.826984  0.725211
# 133607  0.307898      0.801692  0.691679
# 162236  0.063291      0.776472  0.619927
# 190865  0.060976      0.666607  0.092058
# 219494  0.380271      0.834284  0.600600
# 248123  0.703125      0.899238  0.852276
# 276752  0.315501      0.826984  0.725211

# %% [markdown]
# ## Examples of High Lexical but Low Semantic

# %%
# Find predictions with high semantic and low lexical scores

hi_lex_low_sem = clean_eval_df[
    (clean_eval_df["bleu"] >= 0.0)  #  bleu
    & (clean_eval_df["rougeL"] >= 0.43)  # top 25th percentile rougeL
    & (clean_eval_df["meteor"] >= 0.41)  # top 25th percentile meteor
    & (clean_eval_df["bertscore-f1"] < 0.73)  # bottom 25th percentile bertscore
    & (clean_eval_df["use"] < 0.3)   # bottom 25th percentile use
    # & (clean_eval_df["bertscore-f1"] < 0.73)  # top 25th percentile bertscore
    # & (clean_eval_df["use"] < 0.3)   # top 25th percentile use
]

hi_lex_low_sem = hi_lex_low_sem.sort_values(by="use", ascending=False)

# Multiply scores by 100
hi_lex_low_sem[["bleu", "rougeL", "meteor", "bertscore-f1", "use"]] = hi_lex_low_sem[["bleu", "rougeL", "meteor", "bertscore-f1", "use"]].mul(100).round(2)
hi_lex_low_sem[["target", "prediction"]] = hi_lex_low_sem[["target", "prediction"]]

hi_lex_low_sem = hi_lex_low_sem[["target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]]

hi_lex_low_sem
# Out:
#                                                    target  \
# 152223    What was the forerunner of the modern-day IEEE?
# 5397                        What happened after the mass?
# 149879                         What happened to the poor?
# 147979              What was the highlight of his career?
# 149538                         Who was at the conference?
# 159881          What is the exam at the end of Form Four?
# 4834                What was the highlight of his career?
# 235050  What is the most interesting statistic in the ...
# 94938   What building is the most interesting of the l...
# 148449                What was the reaction to the event?
# 5858                            what was the concert for?
# 167257      What is the inscription on the George Cross ?
# 60002                                What was the outcome
#
#                                                prediction  bleu  rougeL  \
# 152223              who was the vice president of the eie   0.0   47.06
# 5397    what happened to the president of the philippines   0.0   46.15
# 149879            what was pepys's response to the plague   0.0   46.15
# 147979        what was the goal of dare in salt lake city   0.0   47.06
# 149538  who was the prime minister of australia at the...   0.0   44.44
# 159881      what is the end of primary education in kenya   0.0   52.63
# 4834    what was the purpose of salt lake city's dare ...   0.0   44.44
# 235050  What is the common belief in Hong Kong that wo...   0.0   45.45
# 94938   What is the name of the university in Warsaw, ...   0.0   45.45
# 148449   what was the name of the man in tiananmen square   0.0   47.06
# 5858    what was the theme song for pirates of the car...   0.0   53.33
# 167257                      what is the purpose of the gc   0.0   53.33
# 60002          What was Keegan's two seasons at The Dell?   0.0   46.15
#
#         meteor  bertscore-f1    use
# 152223   42.13         69.98  28.44
# 5397     41.22         72.16  27.77
# 149879   41.22         71.03  26.66
# 147979   45.73         72.59  26.09
# 149538   47.11         67.51  25.36
# 159881   44.81         72.96  25.14
# 4834     45.18         72.86  24.68
# 235050   49.15         71.49  22.97
# 94938    42.59         72.23  22.18
# 148449   45.73         72.47  20.84
# 5858     49.32         71.09  20.51
# 167257   42.61         72.03  17.99
# 60002    55.56         69.82  12.89

# %%
# Convert to Latex
print(hi_lex_low_sem.to_latex(index=False))

# Print entire text
with pd.option_context("max_colwidth", 1000):
    print(hi_lex_low_sem[["target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]].to_latex(index=False))
# Out:
# \begin{tabular}{llrrrrr}
# \toprule
#                                             target &                                         prediction &  bleu &  rougeL &  meteor &  bertscore-f1 &   use \\
# \midrule
#    What was the forerunner of the modern-day IEEE? &              who was the vice president of the eie &   0.0 &   47.06 &   42.13 &         69.98 & 28.44 \\
#                      What happened after the mass? &  what happened to the president of the philippines &   0.0 &   46.15 &   41.22 &         72.16 & 27.77 \\
#                         What happened to the poor? &            what was pepys's response to the plague &   0.0 &   46.15 &   41.22 &         71.03 & 26.66 \\
#              What was the highlight of his career? &        what was the goal of dare in salt lake city &   0.0 &   47.06 &   45.73 &         72.59 & 26.09 \\
#                         Who was at the conference? & who was the prime minister of australia at the ... &   0.0 &   44.44 &   47.11 &         67.51 & 25.36 \\
#          What is the exam at the end of Form Four? &      what is the end of primary education in kenya &   0.0 &   52.63 &   44.81 &         72.96 & 25.14 \\
#              What was the highlight of his career? & what was the purpose of salt lake city's dare p... &   0.0 &   44.44 &   45.18 &         72.86 & 24.68 \\
# What is the most interesting statistic in the a... & What is the common belief in Hong Kong that wom... &   0.0 &   45.45 &   49.15 &         71.49 & 22.97 \\
# What building is the most interesting of the la... & What is the name of the university in Warsaw, P... &   0.0 &   45.45 &   42.59 &         72.23 & 22.18 \\
#                What was the reaction to the event? &   what was the name of the man in tiananmen square &   0.0 &   47.06 &   45.73 &         72.47 & 20.84 \\
#                          what was the concert for? & what was the theme song for pirates of the cari... &   0.0 &   53.33 &   49.32 &         71.09 & 20.51 \\
#      What is the inscription on the George Cross ? &                      what is the purpose of the gc &   0.0 &   53.33 &   42.61 &         72.03 & 17.99 \\
#                               What was the outcome &         What was Keegan's two seasons at The Dell? &   0.0 &   46.15 &   55.56 &         69.82 & 12.89 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{llrrrrr}
# \toprule
#                                                                       target &                                                             prediction &  bleu &  rougeL &  meteor &  bertscore-f1 &   use \\
# \midrule
#                              What was the forerunner of the modern-day IEEE? &                                  who was the vice president of the eie &   0.0 &   47.06 &   42.13 &         69.98 & 28.44 \\
#                                                What happened after the mass? &                      what happened to the president of the philippines &   0.0 &   46.15 &   41.22 &         72.16 & 27.77 \\
#                                                   What happened to the poor? &                                what was pepys's response to the plague &   0.0 &   46.15 &   41.22 &         71.03 & 26.66 \\
#                                        What was the highlight of his career? &                            what was the goal of dare in salt lake city &   0.0 &   47.06 &   45.73 &         72.59 & 26.09 \\
#                                                   Who was at the conference? &         who was the prime minister of australia at the time of the war &   0.0 &   44.44 &   47.11 &         67.51 & 25.36 \\
#                                    What is the exam at the end of Form Four? &                          what is the end of primary education in kenya &   0.0 &   52.63 &   44.81 &         72.96 & 25.14 \\
#                                        What was the highlight of his career? &                  what was the purpose of salt lake city's dare program &   0.0 &   44.44 &   45.18 &         72.86 & 24.68 \\
#                       What is the most interesting statistic in the article? & What is the common belief in Hong Kong that women are the breadwinner? &   0.0 &   45.45 &   49.15 &         71.49 & 22.97 \\
# What building is the most interesting of the late 19th-century architecture? &                  What is the name of the university in Warsaw, Poland? &   0.0 &   45.45 &   42.59 &         72.23 & 22.18 \\
#                                          What was the reaction to the event? &                       what was the name of the man in tiananmen square &   0.0 &   47.06 &   45.73 &         72.47 & 20.84 \\
#                                                    what was the concert for? &                   what was the theme song for pirates of the caribbean &   0.0 &   53.33 &   49.32 &         71.09 & 20.51 \\
#                                What is the inscription on the George Cross ? &                                          what is the purpose of the gc &   0.0 &   53.33 &   42.61 &         72.03 & 17.99 \\
#                                                         What was the outcome &                             What was Keegan's two seasons at The Dell? &   0.0 &   46.15 &   55.56 &         69.82 & 12.89 \\
# \bottomrule
# \end{tabular}

# %%
# Convert to Latex
print(hi_lex_low_sem[["target", "prediction"]].to_latex(index=False))

# Print entire text
with pd.option_context("max_colwidth", 1000):
    print (hi_lex_low_sem[["target", "prediction"]].to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                             target &                                         prediction \\
# \midrule
#    What was the forerunner of the modern-day IEEE? &              who was the vice president of the eie \\
#                      What happened after the mass? &  what happened to the president of the philippines \\
#                         What happened to the poor? &            what was pepys's response to the plague \\
#              What was the highlight of his career? &        what was the goal of dare in salt lake city \\
#                         Who was at the conference? & who was the prime minister of australia at the ... \\
#          What is the exam at the end of Form Four? &      what is the end of primary education in kenya \\
#              What was the highlight of his career? & what was the purpose of salt lake city's dare p... \\
# What is the most interesting statistic in the a... & What is the common belief in Hong Kong that wom... \\
# What building is the most interesting of the la... & What is the name of the university in Warsaw, P... \\
#                What was the reaction to the event? &   what was the name of the man in tiananmen square \\
#                          what was the concert for? & what was the theme song for pirates of the cari... \\
#      What is the inscription on the George Cross ? &                      what is the purpose of the gc \\
#                               What was the outcome &         What was Keegan's two seasons at The Dell? \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{ll}
# \toprule
#                                                                       target &                                                             prediction \\
# \midrule
#                              What was the forerunner of the modern-day IEEE? &                                  who was the vice president of the eie \\
#                                                What happened after the mass? &                      what happened to the president of the philippines \\
#                                                   What happened to the poor? &                                what was pepys's response to the plague \\
#                                        What was the highlight of his career? &                            what was the goal of dare in salt lake city \\
#                                                   Who was at the conference? &         who was the prime minister of australia at the time of the war \\
#                                    What is the exam at the end of Form Four? &                          what is the end of primary education in kenya \\
#                                        What was the highlight of his career? &                  what was the purpose of salt lake city's dare program \\
#                       What is the most interesting statistic in the article? & What is the common belief in Hong Kong that women are the breadwinner? \\
# What building is the most interesting of the late 19th-century architecture? &                  What is the name of the university in Warsaw, Poland? \\
#                                          What was the reaction to the event? &                       what was the name of the man in tiananmen square \\
#                                                    what was the concert for? &                   what was the theme song for pirates of the caribbean \\
#                                What is the inscription on the George Cross ? &                                          what is the purpose of the gc \\
#                                                         What was the outcome &                             What was Keegan's two seasons at The Dell? \\
# \bottomrule
# \end{tabular}

# %%
spec_ex = clean_eval_df[
    (clean_eval_df["target"] == "Who was at the conference?")
    & (clean_eval_df["nickname"] == "T5_nq_quac")
]

spec_ex = spec_ex[["nickname", "target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]]

spec_ex
# Out:
#           nickname                      target  \
# 149538  T5_nq_quac  Who was at the conference?
#
#                                                prediction  bleu    rougeL  \
# 149538  who was the prime minister of australia at the...   0.0  0.444444
#
#           meteor  bertscore-f1      use
# 149538  0.471082      0.675146  0.25361

# %%
# Convert to Latex
print(spec_ex[["target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]].to_latex(index=False))
# Out:
# \begin{tabular}{llrrrrr}
# \toprule
#                     target &                                         prediction &  bleu &   rougeL &   meteor &  bertscore-f1 &     use \\
# \midrule
# Who was at the conference? & who was the prime minister of australia at the ... &   0.0 & 0.444444 & 0.471082 &      0.675146 & 0.25361 \\
# \bottomrule
# \end{tabular}

# %%
spec_ex = clean_eval_df[
    (clean_eval_df["target"] == "What is the exam at the end of Form Four?")
    & (clean_eval_df["nickname"] == "T5_nq_squad")
]

spec_ex = spec_ex[["nickname", "target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]]

spec_ex
# Out:
#            nickname                                     target  \
# 159881  T5_nq_squad  What is the exam at the end of Form Four?
#
#                                            prediction  bleu    rougeL  \
# 159881  what is the end of primary education in kenya   0.0  0.526316
#
#           meteor  bertscore-f1       use
# 159881  0.448148      0.729596  0.251426

# %%
# Convert to Latex
print(spec_ex[["target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]].to_latex(index=False))
# Out:
# \begin{tabular}{llrrrrr}
# \toprule
#                                    target &                                    prediction &  bleu &   rougeL &   meteor &  bertscore-f1 &      use \\
# \midrule
# What is the exam at the end of Form Four? & what is the end of primary education in kenya &   0.0 & 0.526316 & 0.448148 &      0.729596 & 0.251426 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# Check BLEU scores because looks like they are all 0..?

# %%
bleu_zero = clean_eval_df[clean_eval_df["bleu"] >= 0.0001]

bleu_zero
# Out:
#                    nickname base_model trained_on tested_on  \
# 1                bart_nq_nq       bart         nq        nq
# 5                bart_nq_nq       bart         nq        nq
# 6                bart_nq_nq       bart         nq        nq
# 12               bart_nq_nq       bart         nq        nq
# 14               bart_nq_nq       bart         nq        nq
# ...                     ...        ...        ...       ...
# 286259  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286273  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286278  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286281  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286284  T5_amalgam_triviaqa         T5    amalgam  triviaqa
#
#             hyperparameter                                             target  \
# 1       {'defaults': True}     whats the most liked picture on instagram 2018
# 5       {'defaults': True}  when was the last time the los angeles lakers ...
# 6       {'defaults': True}       where are trigger points located in the body
# 12      {'defaults': True}      when was the last time anyone was on the moon
# 14      {'defaults': True}                 who wrote papa got a brand new bag
# ...                    ...                                                ...
# 286259  {'defaults': True}  What is the common name for the perennial-flow...
# 286273  {'defaults': True}  Feb 15, 1564 saw the birth of what famed Itali...
# 286278  {'defaults': True}  Who played the title role in the 1951 film ‘Ca...
# 286281  {'defaults': True}  Which novelist, born in Bombay in 1865, was aw...
# 286284  {'defaults': True}  What is the name of the structure designed by ...
#
#                                                prediction      bleu    rougeL  \
# 1             what is the most liked picture on instagram  0.680375  0.750000
# 5       when was the last time the lakers won a champi...  0.643219  0.909091
# 6            where are trigger points located in the body  1.000000  1.000000
# 12         when was the last time the us went to the moon  0.403528  0.666667
# 14                      who sang papa got a brand new bag  0.707107  0.875000
# ...                                                   ...       ...       ...
# 286259     What is the common name of the African violet?  0.349833  0.600000
# 286273  Which Italian astronomer discovered the four l...  0.058371  0.424242
# 286278  Who played Captain Horatio Hornblower in the 1...  0.249186  0.480000
# 286281    Who won the Nobel Prize for Literature in 1907?  0.183689  0.560000
# 286284  What is the name of the sculpture designed by ...  0.322477  0.606061
#
#           meteor  bertscore-f1       use
# 1       0.864796      0.932259  0.884909
# 5       0.844068      0.962039  0.961726
# 6       0.999023      1.000000  1.000000
# 12      0.566781      0.926440  0.904742
# 14      0.864796      0.965819  0.852755
# ...          ...           ...       ...
# 286259  0.529487      0.844998  0.599724
# 286273  0.302515      0.836991  0.697034
# 286278  0.612658      0.889873  0.863451
# 286281  0.441557      0.889193  0.795078
# 286284  0.622580      0.913869  0.676564
#
# [33732 rows x 12 columns]

# %% [markdown]
# ## Format code to PEP 8 Standards

# %% [markdown]
# ### Steps
#
# *   Install:

# %%
# !pip install black[jupyter]

# %% [markdown]
# *   To format your code run:

# %%
# !black /content/drive/MyDrive/'Colab Notebooks'/results_text_evaluation.ipynb

# %% [markdown]
# *   Don't save your notebook, hit F5 (Command + r) to refresh the page
# *   Voila!
# *   Now save!
