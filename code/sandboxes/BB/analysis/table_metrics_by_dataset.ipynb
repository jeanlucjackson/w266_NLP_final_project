# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanlucjackson/w266_final_project/blob/main/code/sandboxes/BB/analysis/table_metrics_by_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table for Metrics by Dataset

# %% [markdown]
# ### Imports/Setup

# %%
from os import listdir
from os.path import isfile, join

import csv
import json
import pprint

import pandas as pd
from tqdm import tqdm

# %%
# This cell will authenticate you and mount your Drive in the Colab.
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
evaluation_root = "/content/drive/MyDrive/w266 NLP Final Project/Evaluation/"
filename = join(evaluation_root, "evaluation_database.json")

# Read JSON into dataframe
evaluation_df = pd.read_json(filename)

# %% [markdown]
# Set up ability to remove models with inference hyperparameters

# %%
# Apply this mask to remove all samples from non default inference sets
default_hyperparameter_mask = [sample['defaults'] for sample in evaluation_df.hyperparameter]

# %% [markdown]
# ### Cleanup dataframe

# %%
# Clean up evaluation db df to only include columns needed for text analysis
clean_eval_df = evaluation_df[["nickname", "base_model", "trained_on", "tested_on", "hyperparameter", "target", "prediction", "bleu", "rougeL", "meteor", "bertscore-f1", "use"]]

clean_eval_df
# Out:
#                    nickname base_model trained_on tested_on  \
# 0                bart_nq_nq       bart         nq        nq
# 1                bart_nq_nq       bart         nq        nq
# 2                bart_nq_nq       bart         nq        nq
# 3                bart_nq_nq       bart         nq        nq
# 4                bart_nq_nq       bart         nq        nq
# ...                     ...        ...        ...       ...
# 286285  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286286  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286287  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286288  T5_amalgam_triviaqa         T5    amalgam  triviaqa
# 286289  T5_amalgam_triviaqa         T5    amalgam  triviaqa
#
#             hyperparameter                                             target  \
# 0       {'defaults': True}             what was the real name of saudi arabia
# 1       {'defaults': True}     whats the most liked picture on instagram 2018
# 2       {'defaults': True}      where does the movie proof of life take place
# 3       {'defaults': True}           where is net profit on the balance sheet
# 4       {'defaults': True}   when was fingerprinting first used by the police
# ...                    ...                                                ...
# 286285  {'defaults': True}  Which ex British daily newspaper was first pub...
# 286286  {'defaults': True}  Which cartoon character lived in Bunkerton Cas...
# 286287  {'defaults': True}  In which prison was 'Amy' born in the novel 'L...
# 286288  {'defaults': True}  The Sign Of Four was a detective story written...
# 286289  {'defaults': True}  Albacore, bigeye and longtail are species of w...
#
#                                                prediction      bleu    rougeL  \
# 0         what is the name of the kingdom of saudi arabia  0.000000  0.666667
# 1             what is the most liked picture on instagram  0.680375  0.750000
# 2                    where does alice go in the new movie  0.000000  0.470588
# 3       where does net profit come from in a financial...  0.000000  0.333333
# 4       when was fingerprint technology first used in ...  0.000000  0.588235
# ...                                                   ...       ...       ...
# 286285        What is the name of the city of Manchester?  0.000000  0.093023
# 286286  What was the name of Lord Marmaduke of Bunkerton?  0.000000  0.125000
# 286287  What is the name of the prison in Charles Dick...  0.000000  0.416667
# 286288  Who wrote the novels 'The Sign of Four' and 'A...  0.000000  0.400000
# 286289             What is the largest fish in the world?  0.000000  0.210526
#
#           meteor  bertscore-f1       use
# 0       0.623306      0.915830  0.794086
# 1       0.864796      0.932259  0.884909
# 2       0.354635      0.835192  0.517867
# 3       0.311653      0.856130  0.728012
# 4       0.694444      0.876353  0.704206
# ...          ...           ...       ...
# 286285  0.058309      0.679618  0.322748
# 286286  0.121951      0.794428  0.515345
# 286287  0.248227      0.821790  0.593840
# 286288  0.381426      0.796076  0.585255
# 286289  0.119048      0.769767  0.537810
#
# [286290 rows x 12 columns]

# %% [markdown]
# ### Find means for all models

# %%
# Find the overall averages for each prediction set and metric
eval_means_df = evaluation_df.groupby(["nickname"]).mean()

# Reset index so able to groupby and sort below to find top scoring prediction sets for each metric
eval_means_df = eval_means_df.reset_index("nickname")

eval_means_df
# Out:
#                   nickname      bleu    rouge1    rouge2    rougeL  rougeLsum  \
# 0            T5_amalgam_nq  0.169746  0.551111  0.331145  0.527758   0.527758
# 1          T5_amalgam_quac  0.053671  0.252468  0.122504  0.249039   0.249039
# 2         T5_amalgam_squad  0.142885  0.502334  0.287635  0.470772   0.470772
# 3      T5_amalgam_triviaqa  0.066390  0.424649  0.208584  0.359130   0.359130
# 4                 T5_nq_nq  0.172979  0.551682  0.331158  0.527675   0.527675
# 5               T5_nq_quac  0.001471  0.155335  0.035380  0.151900   0.151900
# 6              T5_nq_squad  0.017446  0.373221  0.160708  0.346182   0.346182
# 7           T5_nq_triviaqa  0.007450  0.318294  0.123126  0.278408   0.278408
# 8               T5_quac_nq  0.000000  0.070207  0.007646  0.068525   0.068525
# 9             T5_quac_quac  0.023456  0.175371  0.067426  0.173453   0.173453
# 10           T5_quac_squad  0.000392  0.099490  0.008595  0.096745   0.096745
# 11        T5_quac_triviaqa  0.000006  0.045922  0.002514  0.043162   0.043162
# 12             T5_squad_nq  0.011952  0.433534  0.215776  0.415383   0.415383
# 13           T5_squad_quac  0.007131  0.190785  0.045122  0.185156   0.185156
# 14          T5_squad_squad  0.147281  0.497753  0.286415  0.467739   0.467739
# 15       T5_squad_triviaqa  0.022352  0.304097  0.111826  0.265502   0.265502
# 16          T5_triviaqa_nq  0.008441  0.350290  0.158218  0.308986   0.308986
# 17        T5_triviaqa_quac  0.001679  0.119800  0.024136  0.110604   0.110604
# 18       T5_triviaqa_squad  0.042573  0.336284  0.135997  0.280593   0.280593
# 19    T5_triviaqa_triviaqa  0.055784  0.405339  0.188400  0.337024   0.337024
# 20         bart_amalgam_nq  0.196693  0.569389  0.353123  0.545003   0.545003
# 21       bart_amalgam_quac  0.027411  0.238066  0.088339  0.233675   0.233675
# 22      bart_amalgam_squad  0.135813  0.493323  0.279320  0.458580   0.458580
# 23   bart_amalgam_triviaqa  0.077973  0.435750  0.221394  0.368721   0.368721
# 24              bart_nq_nq  0.203072  0.576445  0.357042  0.550431   0.550431
# 25            bart_nq_quac  0.001083  0.152988  0.034634  0.149609   0.149609
# 26           bart_nq_squad  0.014385  0.349037  0.139038  0.322623   0.322623
# 27        bart_nq_triviaqa  0.007997  0.331891  0.128535  0.286437   0.286437
# 28            bart_quac_nq  0.005041  0.334154  0.136949  0.326124   0.326124
# 29          bart_quac_quac  0.057220  0.286694  0.140381  0.282748   0.282748
# 30         bart_quac_squad  0.027720  0.306160  0.113318  0.290898   0.290898
# 31      bart_quac_triviaqa  0.006868  0.218799  0.062560  0.197812   0.197812
# 32           bart_squad_nq  0.011793  0.428757  0.212632  0.410598   0.410598
# 33         bart_squad_quac  0.007123  0.189289  0.046604  0.184176   0.184176
# 34        bart_squad_squad  0.151242  0.503386  0.290295  0.469155   0.469155
# 35     bart_squad_triviaqa  0.021929  0.297750  0.110143  0.260254   0.260254
# 36        bart_triviaqa_nq  0.011421  0.402703  0.197217  0.365830   0.365830
# 37      bart_triviaqa_quac  0.001459  0.121788  0.025546  0.113614   0.113614
# 38     bart_triviaqa_squad  0.047023  0.350794  0.141911  0.310570   0.310570
# 39  bart_triviaqa_triviaqa  0.075994  0.434003  0.218682  0.367775   0.367775
#
#       meteor  bertscore-precision  bertscore-recall  bertscore-f1       use  \
# 0   0.497871             0.862055          0.854624      0.858036  0.719863
# 1   0.262385             0.778761          0.778353      0.778060  0.378001
# 2   0.469798             0.873664          0.861667      0.867048  0.656399
# 3   0.337926             0.841297          0.806558      0.822766  0.601577
# 4   0.497261             0.864974          0.854585      0.859476  0.718928
# 5   0.111625             0.692863          0.701502      0.696885  0.287737
# 6   0.273460             0.806934          0.777579      0.791693  0.554671
# 7   0.189823             0.795502          0.740678      0.766649  0.518441
# 8   0.040712             0.667213          0.658704      0.662784  0.180669
# 9   0.189914             0.759456          0.753469      0.756046  0.303081
# 10  0.097564             0.736965          0.693581      0.714181  0.166183
# 11  0.056670             0.702832          0.652224      0.676198  0.119212
# 12  0.357760             0.794365          0.805811      0.799702  0.633868
# 13  0.207983             0.735150          0.774393      0.753711  0.320500
# 14  0.467691             0.875466          0.863300      0.868757  0.650666
# 15  0.221913             0.816005          0.764654      0.788757  0.494978
# 16  0.319191             0.764079          0.800199      0.781309  0.572548
# 17  0.160580             0.689984          0.744248      0.715610  0.244592
# 18  0.327971             0.802970          0.816304      0.808893  0.499839
# 19  0.323068             0.833114          0.801640      0.816313  0.591368
# 20  0.523538             0.866541          0.862605      0.864331  0.729291
# 21  0.250150             0.758532          0.784215      0.770516  0.363810
# 22  0.460132             0.869009          0.857902      0.862849  0.650527
# 23  0.354559             0.843801          0.811313      0.826420  0.609191
# 24  0.528802             0.870647          0.864607      0.867402  0.736651
# 25  0.112613             0.692515          0.702449      0.697180  0.286565
# 26  0.252032             0.797528          0.771140      0.783824  0.540661
# 27  0.200833             0.799940          0.744631      0.770833  0.534304
# 28  0.224375             0.759940          0.741966      0.750539  0.516567
# 29  0.288054             0.796352          0.790242      0.792803  0.418768
# 30  0.245610             0.833189          0.775895      0.802949  0.445580
# 31  0.150911             0.799974          0.716730      0.755470  0.396791
# 32  0.355301             0.792895          0.805120      0.798603  0.630303
# 33  0.205870             0.736757          0.773284      0.753976  0.318477
# 34  0.475293             0.875207          0.865070      0.869525  0.657032
# 35  0.219060             0.815225          0.764171      0.788075  0.492134
# 36  0.367585             0.776905          0.816072      0.795629  0.622989
# 37  0.162960             0.681328          0.740854      0.709303  0.243177
# 38  0.337941             0.809763          0.824938      0.816628  0.535130
# 39  0.350981             0.844371          0.809771      0.825904  0.607768
#
#       bleurt
# 0  -0.329087
# 1  -0.865799
# 2  -0.290063
# 3  -0.668766
# 4  -0.326454
# 5  -1.357303
# 6  -0.727935
# 7  -1.038274
# 8  -1.526871
# 9  -1.124621
# 10 -1.440291
# 11 -1.552169
# 12 -0.629602
# 13 -1.199738
# 14 -0.289706
# 15 -0.913222
# 16 -0.899266
# 17 -1.383934
# 18 -0.805566
# 19 -0.730499
# 20 -0.267204
# 21 -1.044375
# 22 -0.308071
# 23 -0.626564
# 24 -0.250716
# 25 -1.341349
# 26 -0.764717
# 27 -1.017392
# 28 -0.990877
# 29 -0.808246
# 30 -0.831823
# 31 -1.169151
# 32 -0.632910
# 33 -1.214763
# 34 -0.266964
# 35 -0.908754
# 36 -0.736253
# 37 -1.373394
# 38 -0.645328
# 39 -0.631473

# %% [markdown]
# ### Create BART and T5 dataframes

# %%
# Create BART dataframe
bart_df = evaluation_df[evaluation_df["base_model"] == "bart"]

# Create T5 dataframe
t5_df = evaluation_df[evaluation_df["base_model"] == "T5"]

# %% [markdown]
# ## Metrics by Model

# %%
df = clean_eval_df[default_hyperparameter_mask]
df = df.groupby(["base_model"]).mean().sort_values(by="use", ascending=False)

df
# Out:
#                 bleu    rougeL    meteor  bertscore-f1       use
# base_model
# bart        0.051795  0.314182  0.293177      0.797674  0.510399
# T5          0.045889  0.276984  0.264854      0.781927  0.455826

# %%
# Convert to Latex
print(df.to_latex(index=False, header=True))
# Out:
# \begin{tabular}{rrrrr}
# \toprule
#     bleu &   rougeL &   meteor &  bertscore-f1 &      use \\
# 0.051795 & 0.314182 & 0.293177 &      0.797674 & 0.510399 \\
# \midrule
# 0.045889 & 0.276984 & 0.264854 &      0.781927 & 0.455826 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Metrics by Data Tested On

# %%
# Set number of decimal places for scores in pandas df
pd.set_option('precision', 4)

# %% [markdown]
# ### NQ

# %%
# Tested on NQ
nq_df = evaluation_df[(evaluation_df['tested_on'] == 'nq') & (evaluation_df['base_model'] == 'bart')].groupby(['base_model', 'trained_on', 'tested_on']).mean().sort_values(by=['bertscore-f1'], ascending=False)

nq_df
# Out:
#                                    bleu  rouge1  rouge2  rougeL  rougeLsum  \
# base_model trained_on tested_on
# bart       nq         nq         0.2031  0.5764  0.3570  0.5504     0.5504
#            amalgam    nq         0.1967  0.5694  0.3531  0.5450     0.5450
#            squad      nq         0.0118  0.4288  0.2126  0.4106     0.4106
#            triviaqa   nq         0.0114  0.4027  0.1972  0.3658     0.3658
#            quac       nq         0.0050  0.3342  0.1369  0.3261     0.3261
#
#                                  meteor  bertscore-precision  \
# base_model trained_on tested_on
# bart       nq         nq         0.5288               0.8706
#            amalgam    nq         0.5235               0.8665
#            squad      nq         0.3553               0.7929
#            triviaqa   nq         0.3676               0.7769
#            quac       nq         0.2244               0.7599
#
#                                  bertscore-recall  bertscore-f1     use  \
# base_model trained_on tested_on
# bart       nq         nq                   0.8646        0.8674  0.7367
#            amalgam    nq                   0.8626        0.8643  0.7293
#            squad      nq                   0.8051        0.7986  0.6303
#            triviaqa   nq                   0.8161        0.7956  0.6230
#            quac       nq                   0.7420        0.7505  0.5166
#
#                                  bleurt
# base_model trained_on tested_on
# bart       nq         nq        -0.2507
#            amalgam    nq        -0.2672
#            squad      nq        -0.6329
#            triviaqa   nq        -0.7363
#            quac       nq        -0.9909

# %%
# Convert to Latex
print(nq_df.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrrrrrrr}
# \toprule
#   bleu &  rouge1 &  rouge2 &  rougeL &  rougeLsum &  meteor &  bertscore-precision &  bertscore-recall &  bertscore-f1 &    use &  bleurt \\
# 0.2031 &  0.5764 &  0.3570 &  0.5504 &     0.5504 &  0.5288 &               0.8706 &            0.8646 &        0.8674 & 0.7367 & -0.2507 \\
# \midrule
# 0.1967 &  0.5694 &  0.3531 &  0.5450 &     0.5450 &  0.5235 &               0.8665 &            0.8626 &        0.8643 & 0.7293 & -0.2672 \\
# 0.0118 &  0.4288 &  0.2126 &  0.4106 &     0.4106 &  0.3553 &               0.7929 &            0.8051 &        0.7986 & 0.6303 & -0.6329 \\
# 0.0114 &  0.4027 &  0.1972 &  0.3658 &     0.3658 &  0.3676 &               0.7769 &            0.8161 &        0.7956 & 0.6230 & -0.7363 \\
# 0.0050 &  0.3342 &  0.1369 &  0.3261 &     0.3261 &  0.2244 &               0.7599 &            0.7420 &        0.7505 & 0.5166 & -0.9909 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### SQuAD

# %%
# Tested on SQuAD
squad_df = evaluation_df[evaluation_df['tested_on'] == 'squad'].groupby(['base_model', 'trained_on', 'tested_on']).mean().sort_values(by=['bertscore-f1'], ascending=False)

squad_df
# Out:
#                                    bleu  rouge1  rouge2  rougeL  rougeLsum  \
# base_model trained_on tested_on
# bart       squad      squad      0.1512  0.5034  0.2903  0.4692     0.4692
# T5         squad      squad      0.1473  0.4978  0.2864  0.4677     0.4677
#            amalgam    squad      0.1429  0.5023  0.2876  0.4708     0.4708
# bart       amalgam    squad      0.1358  0.4933  0.2793  0.4586     0.4586
#            triviaqa   squad      0.0470  0.3508  0.1419  0.3106     0.3106
# T5         triviaqa   squad      0.0426  0.3363  0.1360  0.2806     0.2806
# bart       quac       squad      0.0277  0.3062  0.1133  0.2909     0.2909
# T5         nq         squad      0.0174  0.3732  0.1607  0.3462     0.3462
# bart       nq         squad      0.0144  0.3490  0.1390  0.3226     0.3226
# T5         quac       squad      0.0004  0.0995  0.0086  0.0967     0.0967
#
#                                  meteor  bertscore-precision  \
# base_model trained_on tested_on
# bart       squad      squad      0.4753               0.8752
# T5         squad      squad      0.4677               0.8755
#            amalgam    squad      0.4698               0.8737
# bart       amalgam    squad      0.4601               0.8690
#            triviaqa   squad      0.3379               0.8098
# T5         triviaqa   squad      0.3280               0.8030
# bart       quac       squad      0.2456               0.8332
# T5         nq         squad      0.2735               0.8069
# bart       nq         squad      0.2520               0.7975
# T5         quac       squad      0.0976               0.7370
#
#                                  bertscore-recall  bertscore-f1     use  \
# base_model trained_on tested_on
# bart       squad      squad                0.8651        0.8695  0.6570
# T5         squad      squad                0.8633        0.8688  0.6507
#            amalgam    squad                0.8617        0.8670  0.6564
# bart       amalgam    squad                0.8579        0.8628  0.6505
#            triviaqa   squad                0.8249        0.8166  0.5351
# T5         triviaqa   squad                0.8163        0.8089  0.4998
# bart       quac       squad                0.7759        0.8029  0.4456
# T5         nq         squad                0.7776        0.7917  0.5547
# bart       nq         squad                0.7711        0.7838  0.5407
# T5         quac       squad                0.6936        0.7142  0.1662
#
#                                  bleurt
# base_model trained_on tested_on
# bart       squad      squad     -0.2670
# T5         squad      squad     -0.2897
#            amalgam    squad     -0.2901
# bart       amalgam    squad     -0.3081
#            triviaqa   squad     -0.6453
# T5         triviaqa   squad     -0.8056
# bart       quac       squad     -0.8318
# T5         nq         squad     -0.7279
# bart       nq         squad     -0.7647
# T5         quac       squad     -1.4403

# %%
# Convert to Latex
print(squad_df.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrrrrrrr}
# \toprule
#   bleu &  rouge1 &  rouge2 &  rougeL &  rougeLsum &  meteor &  bertscore-precision &  bertscore-recall &  bertscore-f1 &    use &  bleurt \\
# 0.1512 &  0.5034 &  0.2903 &  0.4692 &     0.4692 &  0.4753 &               0.8752 &            0.8651 &        0.8695 & 0.6570 & -0.2670 \\
# \midrule
# 0.1473 &  0.4978 &  0.2864 &  0.4677 &     0.4677 &  0.4677 &               0.8755 &            0.8633 &        0.8688 & 0.6507 & -0.2897 \\
# 0.1429 &  0.5023 &  0.2876 &  0.4708 &     0.4708 &  0.4698 &               0.8737 &            0.8617 &        0.8670 & 0.6564 & -0.2901 \\
# 0.1358 &  0.4933 &  0.2793 &  0.4586 &     0.4586 &  0.4601 &               0.8690 &            0.8579 &        0.8628 & 0.6505 & -0.3081 \\
# 0.0470 &  0.3508 &  0.1419 &  0.3106 &     0.3106 &  0.3379 &               0.8098 &            0.8249 &        0.8166 & 0.5351 & -0.6453 \\
# 0.0426 &  0.3363 &  0.1360 &  0.2806 &     0.2806 &  0.3280 &               0.8030 &            0.8163 &        0.8089 & 0.4998 & -0.8056 \\
# 0.0277 &  0.3062 &  0.1133 &  0.2909 &     0.2909 &  0.2456 &               0.8332 &            0.7759 &        0.8029 & 0.4456 & -0.8318 \\
# 0.0174 &  0.3732 &  0.1607 &  0.3462 &     0.3462 &  0.2735 &               0.8069 &            0.7776 &        0.7917 & 0.5547 & -0.7279 \\
# 0.0144 &  0.3490 &  0.1390 &  0.3226 &     0.3226 &  0.2520 &               0.7975 &            0.7711 &        0.7838 & 0.5407 & -0.7647 \\
# 0.0004 &  0.0995 &  0.0086 &  0.0967 &     0.0967 &  0.0976 &               0.7370 &            0.6936 &        0.7142 & 0.1662 & -1.4403 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### TriviaQA

# %%
# Tested on TriviaQA
triviaqa_df = evaluation_df[evaluation_df['tested_on'] == 'triviaqa'].groupby(['base_model', 'trained_on', 'tested_on']).mean().sort_values(by=['bertscore-f1'], ascending=False)

triviaqa_df
# Out:
#                                        bleu  rouge1  rouge2  rougeL  \
# base_model trained_on tested_on
# bart       amalgam    triviaqa   7.7973e-02  0.4357  0.2214  0.3687
#            triviaqa   triviaqa   7.5994e-02  0.4340  0.2187  0.3678
# T5         amalgam    triviaqa   6.6390e-02  0.4246  0.2086  0.3591
#            triviaqa   triviaqa   5.5784e-02  0.4053  0.1884  0.3370
#            squad      triviaqa   2.2352e-02  0.3041  0.1118  0.2655
# bart       squad      triviaqa   2.1929e-02  0.2978  0.1101  0.2603
#            nq         triviaqa   7.9975e-03  0.3319  0.1285  0.2864
# T5         nq         triviaqa   7.4502e-03  0.3183  0.1231  0.2784
# bart       quac       triviaqa   6.8680e-03  0.2188  0.0626  0.1978
# T5         quac       triviaqa   5.7000e-06  0.0459  0.0025  0.0432
#
#                                  rougeLsum  meteor  bertscore-precision  \
# base_model trained_on tested_on
# bart       amalgam    triviaqa      0.3687  0.3546               0.8438
#            triviaqa   triviaqa      0.3678  0.3510               0.8444
# T5         amalgam    triviaqa      0.3591  0.3379               0.8413
#            triviaqa   triviaqa      0.3370  0.3231               0.8331
#            squad      triviaqa      0.2655  0.2219               0.8160
# bart       squad      triviaqa      0.2603  0.2191               0.8152
#            nq         triviaqa      0.2864  0.2008               0.7999
# T5         nq         triviaqa      0.2784  0.1898               0.7955
# bart       quac       triviaqa      0.1978  0.1509               0.8000
# T5         quac       triviaqa      0.0432  0.0567               0.7028
#
#                                  bertscore-recall  bertscore-f1     use  \
# base_model trained_on tested_on
# bart       amalgam    triviaqa             0.8113        0.8264  0.6092
#            triviaqa   triviaqa             0.8098        0.8259  0.6078
# T5         amalgam    triviaqa             0.8066        0.8228  0.6016
#            triviaqa   triviaqa             0.8016        0.8163  0.5914
#            squad      triviaqa             0.7647        0.7888  0.4950
# bart       squad      triviaqa             0.7642        0.7881  0.4921
#            nq         triviaqa             0.7446        0.7708  0.5343
# T5         nq         triviaqa             0.7407        0.7666  0.5184
# bart       quac       triviaqa             0.7167        0.7555  0.3968
# T5         quac       triviaqa             0.6522        0.6762  0.1192
#
#                                  bleurt
# base_model trained_on tested_on
# bart       amalgam    triviaqa  -0.6266
#            triviaqa   triviaqa  -0.6315
# T5         amalgam    triviaqa  -0.6688
#            triviaqa   triviaqa  -0.7305
#            squad      triviaqa  -0.9132
# bart       squad      triviaqa  -0.9088
#            nq         triviaqa  -1.0174
# T5         nq         triviaqa  -1.0383
# bart       quac       triviaqa  -1.1692
# T5         quac       triviaqa  -1.5522

# %%
# Convert to Latex
print(triviaqa_df.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrrrrrrr}
# \toprule
#       bleu &  rouge1 &  rouge2 &  rougeL &  rougeLsum &  meteor &  bertscore-precision &  bertscore-recall &  bertscore-f1 &    use &  bleurt \\
# 7.7973e-02 &  0.4357 &  0.2214 &  0.3687 &     0.3687 &  0.3546 &               0.8438 &            0.8113 &        0.8264 & 0.6092 & -0.6266 \\
# \midrule
# 7.5994e-02 &  0.4340 &  0.2187 &  0.3678 &     0.3678 &  0.3510 &               0.8444 &            0.8098 &        0.8259 & 0.6078 & -0.6315 \\
# 6.6390e-02 &  0.4246 &  0.2086 &  0.3591 &     0.3591 &  0.3379 &               0.8413 &            0.8066 &        0.8228 & 0.6016 & -0.6688 \\
# 5.5784e-02 &  0.4053 &  0.1884 &  0.3370 &     0.3370 &  0.3231 &               0.8331 &            0.8016 &        0.8163 & 0.5914 & -0.7305 \\
# 2.2352e-02 &  0.3041 &  0.1118 &  0.2655 &     0.2655 &  0.2219 &               0.8160 &            0.7647 &        0.7888 & 0.4950 & -0.9132 \\
# 2.1929e-02 &  0.2978 &  0.1101 &  0.2603 &     0.2603 &  0.2191 &               0.8152 &            0.7642 &        0.7881 & 0.4921 & -0.9088 \\
# 7.9975e-03 &  0.3319 &  0.1285 &  0.2864 &     0.2864 &  0.2008 &               0.7999 &            0.7446 &        0.7708 & 0.5343 & -1.0174 \\
# 7.4502e-03 &  0.3183 &  0.1231 &  0.2784 &     0.2784 &  0.1898 &               0.7955 &            0.7407 &        0.7666 & 0.5184 & -1.0383 \\
# 6.8680e-03 &  0.2188 &  0.0626 &  0.1978 &     0.1978 &  0.1509 &               0.8000 &            0.7167 &        0.7555 & 0.3968 & -1.1692 \\
# 5.7000e-06 &  0.0459 &  0.0025 &  0.0432 &     0.0432 &  0.0567 &               0.7028 &            0.6522 &        0.6762 & 0.1192 & -1.5522 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### QuAC

# %%
# Tested on QuAC
quac_df = evaluation_df[evaluation_df['tested_on'] == 'quac'].groupby(['base_model', 'trained_on', 'tested_on']).mean().sort_values(by=['bertscore-f1'], ascending=False)

quac_df
# Out:
#                                    bleu  rouge1  rouge2  rougeL  rougeLsum  \
# base_model trained_on tested_on
# bart       quac       quac       0.0572  0.2867  0.1404  0.2827     0.2827
# T5         amalgam    quac       0.0537  0.2525  0.1225  0.2490     0.2490
# bart       amalgam    quac       0.0274  0.2381  0.0883  0.2337     0.2337
# T5         quac       quac       0.0235  0.1754  0.0674  0.1735     0.1735
# bart       squad      quac       0.0071  0.1893  0.0466  0.1842     0.1842
# T5         squad      quac       0.0071  0.1908  0.0451  0.1852     0.1852
#            triviaqa   quac       0.0017  0.1198  0.0241  0.1106     0.1106
# bart       triviaqa   quac       0.0015  0.1218  0.0255  0.1136     0.1136
#            nq         quac       0.0011  0.1530  0.0346  0.1496     0.1496
# T5         nq         quac       0.0015  0.1553  0.0354  0.1519     0.1519
#
#                                  meteor  bertscore-precision  \
# base_model trained_on tested_on
# bart       quac       quac       0.2881               0.7964
# T5         amalgam    quac       0.2624               0.7788
# bart       amalgam    quac       0.2502               0.7585
# T5         quac       quac       0.1899               0.7595
# bart       squad      quac       0.2059               0.7368
# T5         squad      quac       0.2080               0.7352
#            triviaqa   quac       0.1606               0.6900
# bart       triviaqa   quac       0.1630               0.6813
#            nq         quac       0.1126               0.6925
# T5         nq         quac       0.1116               0.6929
#
#                                  bertscore-recall  bertscore-f1     use  \
# base_model trained_on tested_on
# bart       quac       quac                 0.7902        0.7928  0.4188
# T5         amalgam    quac                 0.7784        0.7781  0.3780
# bart       amalgam    quac                 0.7842        0.7705  0.3638
# T5         quac       quac                 0.7535        0.7560  0.3031
# bart       squad      quac                 0.7733        0.7540  0.3185
# T5         squad      quac                 0.7744        0.7537  0.3205
#            triviaqa   quac                 0.7442        0.7156  0.2446
# bart       triviaqa   quac                 0.7409        0.7093  0.2432
#            nq         quac                 0.7024        0.6972  0.2866
# T5         nq         quac                 0.7015        0.6969  0.2877
#
#                                  bleurt
# base_model trained_on tested_on
# bart       quac       quac      -0.8082
# T5         amalgam    quac      -0.8658
# bart       amalgam    quac      -1.0444
# T5         quac       quac      -1.1246
# bart       squad      quac      -1.2148
# T5         squad      quac      -1.1997
#            triviaqa   quac      -1.3839
# bart       triviaqa   quac      -1.3734
#            nq         quac      -1.3413
# T5         nq         quac      -1.3573

# %%
# Convert to Latex
print(quac_df.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrrrrrrr}
# \toprule
#   bleu &  rouge1 &  rouge2 &  rougeL &  rougeLsum &  meteor &  bertscore-precision &  bertscore-recall &  bertscore-f1 &    use &  bleurt \\
# 0.0572 &  0.2867 &  0.1404 &  0.2827 &     0.2827 &  0.2881 &               0.7964 &            0.7902 &        0.7928 & 0.4188 & -0.8082 \\
# \midrule
# 0.0537 &  0.2525 &  0.1225 &  0.2490 &     0.2490 &  0.2624 &               0.7788 &            0.7784 &        0.7781 & 0.3780 & -0.8658 \\
# 0.0274 &  0.2381 &  0.0883 &  0.2337 &     0.2337 &  0.2502 &               0.7585 &            0.7842 &        0.7705 & 0.3638 & -1.0444 \\
# 0.0235 &  0.1754 &  0.0674 &  0.1735 &     0.1735 &  0.1899 &               0.7595 &            0.7535 &        0.7560 & 0.3031 & -1.1246 \\
# 0.0071 &  0.1893 &  0.0466 &  0.1842 &     0.1842 &  0.2059 &               0.7368 &            0.7733 &        0.7540 & 0.3185 & -1.2148 \\
# 0.0071 &  0.1908 &  0.0451 &  0.1852 &     0.1852 &  0.2080 &               0.7352 &            0.7744 &        0.7537 & 0.3205 & -1.1997 \\
# 0.0017 &  0.1198 &  0.0241 &  0.1106 &     0.1106 &  0.1606 &               0.6900 &            0.7442 &        0.7156 & 0.2446 & -1.3839 \\
# 0.0015 &  0.1218 &  0.0255 &  0.1136 &     0.1136 &  0.1630 &               0.6813 &            0.7409 &        0.7093 & 0.2432 & -1.3734 \\
# 0.0011 &  0.1530 &  0.0346 &  0.1496 &     0.1496 &  0.1126 &               0.6925 &            0.7024 &        0.6972 & 0.2866 & -1.3413 \\
# 0.0015 &  0.1553 &  0.0354 &  0.1519 &     0.1519 &  0.1116 &               0.6929 &            0.7015 &        0.6969 & 0.2877 & -1.3573 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Format code to PEP 8 Standards

# %% [markdown]
# ### Steps
#
# *   Install:

# %%
# !pip install black[jupyter]

# %% [markdown]
# *   To format your code run:

# %%
# !black /content/drive/MyDrive/'Colab Notebooks'/table_metrics_by_dataset.ipynb
# Out:
# All done! ✨ 🍰 ✨
# 1 file left unchanged.

# %% [markdown]
# *   Don't save your notebook, hit F5 (Command + r) to refresh the page
# *   Voila!
# *   Now save!
