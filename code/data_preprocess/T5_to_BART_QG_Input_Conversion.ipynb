# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanlucjackson/w266_final_project/blob/main/code/data_preprocess/T5_to_BART_QG_Input_Conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import re
import numpy as np
import pandas as pd

from pprint import pprint

from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
dataset_root = "/content/drive/MyDrive/w266 NLP Final Project/Data/"
stub=len("generate question: answer: ")

for dataset_name in ['nq', 'quac', 'triviaqa']:
  dataset_folder = dataset_root+dataset_name
  T5_training_file = dataset_folder + '/train_pairs.csv'
  T5_validation_file = dataset_folder + '/valid_pairs.csv'
  BART_training_file = dataset_folder + '/bart_train_pairs.csv'
  BART_validation_file = dataset_folder + '/bart_valid_pairs.csv'

  training_df = pd.read_csv(T5_training_file)[['orig', 'target']]
  validation_df = pd.read_csv(T5_validation_file)[['orig', 'target']]

  training_df['orig'] = training_df.apply (lambda row: 
                                           row['orig'][stub:].replace("context:", "</s>", 1), 
                                           axis=1)

  validation_df['orig'] = validation_df.apply(lambda row: 
                                              row['orig'][stub:].replace("context:", "</s>", 1), 
                                              axis=1)
  training_df.to_csv(BART_training_file)
  validation_df.to_csv(BART_validation_file)

# %%
df = pd.read_csv(dataset_root+"nq/bart_valid_pairs.csv")

# %%
df[:30]
# Out:
#     Unnamed: 0                                               orig  \
# 0            0  al-Mamlakah al-ʻArabīyah as-Suʻūdīyah </s> Fol...
# 1            1  the name announcement of Kylie Jenner's first ...
# 2            2  the (fictional) South American country of Teca...
# 3            3  on the bottom line of the report </s> A common...
# 4            4  the early 20th century </s> Human fingerprints...
# 5            5  in 2010 </s> The Los Angeles Lakers are an Ame...
# 6            6  hyperirritable spots in the fascia surrounding...
# 7            7  Havana Harbor </s> USS Maine (ACR-1) is an Ame...
# 8            8  Patrick Walshe </s> Patrick Walshe (July 26, 1...
# 9            9  four </s> The Winter Olympics has been hosted ...
# 10          10  Merrimen </s> Merrimen, Bosco and Levi try to ...
# 11          11  Hugo von Mohl </s> A cell division under micro...
# 12          12  December 1972 </s> To date, the United States ...
# 13          13  his brother </s> The song is about the narrato...
# 14          14  James Brown </s> "Papa's Got a Brand New Bag" ...
# 15          15  Italy </s> Information gleaned via British Ult...
# 16          16  British Columbia, Canada </s> The Crossing is ...
# 17          17  2004 </s> Napoleon Dynamite is a 2004 American...
# 18          18  Hellenism (Greek: Ἑλληνισμός), the Hellenic et...
# 19          19  extends from the Arctic Ocean in the north to ...
# 20          20  four </s> The first collection of stories abou...
# 21          21  Walter Brennan </s> Chance's friend Pat Wheele...
# 22          22  March 2003 </s> "Seven Nation Army" (also styl...
# 23          23  Japanese </s> Maia Harumi Shibutani was born o...
# 24          24  Welsh poet Dylan Thomas </s> "Do not go gentle...
# 25          25  The International System of Units (SI) </s> Th...
# 26          26  counterclockwise </s> From a vantage point abo...
# 27          27  American singer Selena Gomez </s> "It Ain't Me...
# 28          28  regulate the employment and working conditions...
# 29          29  Ernest Rutherford </s> The Rutherford model is...
#
#                                                target
# 0              what was the real name of saudi arabia
# 1      whats the most liked picture on instagram 2018
# 2       where does the movie proof of life take place
# 3            where is net profit on the balance sheet
# 4    when was fingerprinting first used by the police
# 5   when was the last time the los angeles lakers ...
# 6        where are trigger points located in the body
# 7   where was the u.s.s maine when it exploded in ...
# 8                 who plays nikko in the wizard of oz
# 9   how many times have the winter olympics been i...
# 10              who dies at the end of den of thieves
# 11      who discovered cells divide to make new cells
# 12      when was the last time anyone was on the moon
# 13  in the song i drive your truck who is he talki...
# 14                 who wrote papa got a brand new bag
# 15         where did the allies go after north africa
# 16          where did they film the show the crossing
# 17      when did the movie napoleon dynamite come out
# 18   what is it called when you believe in greek gods
# 19  where is the pacific ocean located on the worl...
# 20           how many winnie the pooh books are there
# 21           who played stumpy in the movie rio bravo
# 22           what year did seven nation army come out
# 23     what is the ethnic background of the shib sibs
# 24      who said i will not go quietly into the night
# 25         what kind of metric system does the us use
# 26             which way does the earth orbit the sun
# 27                     who sings the song it ain't me
# 28   what is the role of the civil service commission
# 29              who made the nuclear model of an atom
