# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanlucjackson/w266_final_project/blob/main/code/evaluation/evaluation_probe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports & Google Drive Mounting

# %%
import json
import pprint

import numpy as np
import pandas as pd

# Hugging Face Evaluation module
# !pip install -q evaluate
import evaluate

# For loading the Universal Sentence Encoder
import tensorflow_hub as hub

# Pandas display setting
pd.options.display.max_colwidth = 500

# %%
# pip installs

# !pip install -q rouge_score
# !pip install bert_score
# Out:
#   Building wheel for rouge-score (setup.py) ... done
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bert_score
#   Downloading bert_score-0.3.12-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 3.6 MB/s
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.8/dist-packages (from bert_score) (4.64.1)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from bert_score) (1.12.1+cu113)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from bert_score) (1.3.5)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from bert_score) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from bert_score) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from bert_score) (1.21.6)
# Collecting transformers>=3.0.0
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 14.8 MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from bert_score) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->bert_score) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.1->bert_score) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0.1->bert_score) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.0.0->bert_score) (4.1.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 46.7 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers>=3.0.0->bert_score) (2022.6.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers>=3.0.0->bert_score) (0.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers>=3.0.0->bert_score) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers>=3.0.0->bert_score) (6.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->bert_score) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->bert_score) (0.11.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->bert_score) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->bert_score) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->bert_score) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->bert_score) (3.0.4)
# Installing collected packages: tokenizers, transformers, bert-score
# Successfully installed bert-score-0.3.12 tokenizers-0.13.2 transformers-4.24.0

# %%
# This cell will authenticate you and mount your Drive in the Colab.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ___
# # `Evaluation_Probe` Class

# %%
class Evaluation_Probe:
  """
  docstring
  """
  
  def __init__(self):
    
    # Dictionary to store functions that compute each metric
    self.metric_computes = {}
    self.internal_computes = {}
    
    # DataFrame to store history of computations
    self.eval_history_df = pd.DataFrame()
    
    # Load all metric modules upon initializing
    self._load_metrics()

  
  def _load_metrics(self):
    """
    Load evaluation modules to run metrics.

    Metrics loaded:
    - BLEU
    - ROUGE-L
    - METEOR
    - BERTScore
    - Universal Sentence Encoder
    """
    
    # BLEU
    bleu = evaluate.load("bleu")

    # ROUGE
    rouge = evaluate.load('rouge')

    # METEOR
    meteor = evaluate.load('meteor')

    # BERTScore
    bertscore = evaluate.load('bertscore')

    # USE
    module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
    use_model = hub.load(module_url)

    # Add functions to metric compute dictionary
    self.metric_computes.update(
        {
            'bleu': bleu,
            'rougeL': rouge,
            'meteor': meteor,
            'bertscore': bertscore,
            'use': use_model
        }
    )
    self.internal_computes.update(
        {
            'bleu': self.bleu_eval,
            'rougeL': self.rougeL_eval,
            'meteor': self.meteor_eval,
            'bertscore': self.bertscore_eval,
            'use': self.use_eval
        }
    )


  def get_metric_compute(self, metric_name):
    return self.metric_computes[metric_name]

  def get_internal_compute(self, metric_name):
    return self.internal_computes[metric_name]

  
  def bleu_eval(self, prediction, target):
    bleu = self.metric_computes['bleu']
    return bleu.compute(predictions=[prediction],
                        references=[target])['bleu']
  
  def use_eval(self, prediction, target):
    """
    Calculate cosine similarity between USE embeds of inputs.
    """
    use_model = self.get_metric_compute('use')
    embeds = use_model(
        [
          target,
          prediction
        ]
    )

    # Calculate correlation between embeddings
    corr = np.inner(embeds, embeds)

    # Grab prediction's correlation score
    pred_corr = corr[0].tolist()[1]

    return pred_corr


  def rougeL_eval(self, prediction, target):
    rouge = self.metric_computes['rougeL']
    return rouge.compute(predictions=[prediction],
                         references=[target])['rougeL']

  def meteor_eval(self, prediction, target):
    meteor = self.metric_computes['meteor']
    return meteor.compute(predictions=[prediction],
                          references=[target])['meteor']
  
  def bertscore_eval(self, prediction, target):
    bertscore = self.metric_computes['bertscore']
    return bertscore.compute(predictions=[prediction],
                             references=[target],
                             model_type='distilbert-base-uncased')['f1'][0]


  def evaluate(self, prediction, target):
    """
    Evaluates a prediction based on the target across all loaded metrics
    in the internal metric dictionary.
    """

    results = {}
    # Add target and prediction
    results.update(
        {
            'target': target,
            'prediction': prediction
        }
    )

    # Evaluate on each metric
    for metric in self.metric_computes.keys():
      results.update(
          {
              metric: self.internal_computes[metric](prediction, target)
          }
      )

    # Add to history DF
    self.update_history(results)
    
    # Return
    return results

  
  def update_history(self, new_row):
    new_row_df = pd.DataFrame(new_row, index=[0])

    self.eval_history_df = pd.concat([self.eval_history_df, new_row_df],
                                     ignore_index=True)


  def get_history(self):
    return self.eval_history_df

# %% [markdown]
# # How to Use `Evaluation_Probe`

# %%
eval = Evaluation_Probe()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
target =     "who has the power to approve or veto legislation constitution?"

prediction = "who has the power to veto a bill?"

# %%
eval.evaluate(prediction, target)
# Out:
# {'target': 'who has the power to approve or veto legislation constitution?',
#  'prediction': 'who has the power to veto a bill?',
#  'bleu': 0.3887514204144021,
#  'rougeL': 0.6666666666666665,
#  'meteor': 0.6226379440665155,
#  'bertscore': 0.9280303120613098,
#  'use': 0.7975350618362427}

# %%
df = eval.get_history()
df
# Out:
#                                                            target  \
# 0  who has the power to approve or veto legislation constitution?
#
#                           prediction      bleu    rougeL    meteor  bertscore  \
# 0  who has the power to veto a bill?  0.388751  0.666667  0.622638    0.92803
#
#         use
# 0  0.797535

# %%
target =     "who scored the game winning run in the last inning of last night's game?"

prediction = "what player scored the final run in yesterday's match to win it?"

eval.evaluate(prediction, target)
# Out:
# {'target': "who scored the game winning run in the last inning of last night's game?",
#  'prediction': "what player scored the final run in yesterday's match to win it?",
#  'bleu': 0.0,
#  'rougeL': 0.3571428571428571,
#  'meteor': 0.3367286392405063,
#  'bertscore': 0.8611516356468201,
#  'use': 0.714165210723877}

# %%
df = eval.get_history()
df
# Out:
#                                                                      target  \
# 0            who has the power to approve or veto legislation constitution?
# 1  who scored the game winning run in the last inning of last night's game?
#
#                                                          prediction      bleu  \
# 0                                 who has the power to veto a bill?  0.388751
# 1  what player scored the final run in yesterday's match to win it?  0.000000
#
#      rougeL    meteor  bertscore       use
# 0  0.666667  0.622638   0.928030  0.797535
# 1  0.357143  0.336729   0.861152  0.714165

# %%
target =     "Who won Super Bowl XLIX?"

prediction = "who did the broncos play in the superbowl"

eval.evaluate(prediction, target)
eval.get_history()
# Out:
#                                                                      target  \
# 0            who has the power to approve or veto legislation constitution?
# 1  who scored the game winning run in the last inning of last night's game?
# 2                                                  Who won Super Bowl XLIX?
#
#                                                          prediction      bleu  \
# 0                                 who has the power to veto a bill?  0.388751
# 1  what player scored the final run in yesterday's match to win it?  0.000000
# 2                         who did the broncos play in the superbowl  0.000000
#
#      rougeL    meteor  bertscore       use
# 0  0.666667  0.622638   0.928030  0.797535
# 1  0.357143  0.336729   0.861152  0.714165
# 2  0.153846  0.080645   0.709131  0.704500

# %%
target =     "what is the role of hcl in the stomach"

prediction = "What does hydrochloric acid do?"

eval.evaluate(prediction, target)
eval.get_history()
# Out:
#                                                                      target  \
# 0            who has the power to approve or veto legislation constitution?
# 1  who scored the game winning run in the last inning of last night's game?
# 2                                                  Who won Super Bowl XLIX?
# 3                                    what is the role of hcl in the stomach
#
#                                                          prediction      bleu  \
# 0                                 who has the power to veto a bill?  0.388751
# 1  what player scored the final run in yesterday's match to win it?  0.000000
# 2                         who did the broncos play in the superbowl  0.000000
# 3                                   What does hydrochloric acid do?  0.000000
#
#      rougeL    meteor  bertscore       use
# 0  0.666667  0.622638   0.928030  0.797535
# 1  0.357143  0.336729   0.861152  0.714165
# 2  0.153846  0.080645   0.709131  0.704500
# 3  0.142857  0.057471   0.727882  0.680623

# %%
eval.get_history()
# Out:
#                                                                      target  \
# 0            who has the power to approve or veto legislation constitution?
# 1  who scored the game winning run in the last inning of last night's game?
# 2                                                  Who won Super Bowl XLIX?
# 3                                    what is the role of hcl in the stomach
#
#                                                          prediction      bleu  \
# 0                                 who has the power to veto a bill?  0.388751
# 1  what player scored the final run in yesterday's match to win it?  0.000000
# 2                         who did the broncos play in the superbowl  0.000000
# 3                                   What does hydrochloric acid do?  0.000000
#
#      rougeL    meteor  bertscore       use
# 0  0.666667  0.622638   0.928030  0.797535
# 1  0.357143  0.336729   0.861152  0.714165
# 2  0.153846  0.080645   0.709131  0.704500
# 3  0.142857  0.057471   0.727882  0.680623

# %%
target =     "who has the power to do anything"

prediction = "who has the power to do nothing"

eval.evaluate(prediction, target)
eval.get_history()
# Out:
#                                                                      target  \
# 0            who has the power to approve or veto legislation constitution?
# 1  who scored the game winning run in the last inning of last night's game?
# 2                                                  Who won Super Bowl XLIX?
# 3                                    what is the role of hcl in the stomach
# 4                                          who has the power to do anything
#
#                                                          prediction      bleu  \
# 0                                 who has the power to veto a bill?  0.388751
# 1  what player scored the final run in yesterday's match to win it?  0.000000
# 2                         who did the broncos play in the superbowl  0.000000
# 3                                   What does hydrochloric acid do?  0.000000
# 4                                   who has the power to do nothing  0.809107
#
#      rougeL    meteor  bertscore       use
# 0  0.666667  0.622638   0.928030  0.797535
# 1  0.357143  0.336729   0.861152  0.714165
# 2  0.153846  0.080645   0.709131  0.704500
# 3  0.142857  0.057471   0.727882  0.680623
# 4  0.857143  0.855159   0.976179  0.904624

# %%
target =     "who has the power to do anything they want"

prediction = "who has the power to do nothing"

eval.evaluate(prediction, target)
eval.get_history()
# Out:
#                                                                      target  \
# 0            who has the power to approve or veto legislation constitution?
# 1  who scored the game winning run in the last inning of last night's game?
# 2                                                  Who won Super Bowl XLIX?
# 3                                    what is the role of hcl in the stomach
# 4                                          who has the power to do anything
# 5                                who has the power to do anything they want
#
#                                                          prediction      bleu  \
# 0                                 who has the power to veto a bill?  0.388751
# 1  what player scored the final run in yesterday's match to win it?  0.000000
# 2                         who did the broncos play in the superbowl  0.000000
# 3                                   What does hydrochloric acid do?  0.000000
# 4                                   who has the power to do nothing  0.809107
# 5                                   who has the power to do nothing  0.608025
#
#      rougeL    meteor  bertscore       use
# 0  0.666667  0.622638   0.928030  0.797535
# 1  0.357143  0.336729   0.861152  0.714165
# 2  0.153846  0.080645   0.709131  0.704500
# 3  0.142857  0.057471   0.727882  0.680623
# 4  0.857143  0.855159   0.976179  0.904624
# 5  0.750000  0.680240   0.912429  0.794857

# %%
target =     "who has the power to do anything"

prediction = "who has the power to do nothing except for what they must"

eval.evaluate(prediction, target)
eval.get_history()
# Out:
#                                                                      target  \
# 0            who has the power to approve or veto legislation constitution?
# 1  who scored the game winning run in the last inning of last night's game?
# 2                                                  Who won Super Bowl XLIX?
# 3                                    what is the role of hcl in the stomach
# 4                                          who has the power to do anything
# 5                                who has the power to do anything they want
# 6                                          who has the power to do anything
#
#                                                          prediction      bleu  \
# 0                                 who has the power to veto a bill?  0.388751
# 1  what player scored the final run in yesterday's match to win it?  0.000000
# 2                         who did the broncos play in the superbowl  0.000000
# 3                                   What does hydrochloric acid do?  0.000000
# 4                                   who has the power to do nothing  0.809107
# 5                                   who has the power to do nothing  0.608025
# 6         who has the power to do nothing except for what they must  0.417226
#
#      rougeL    meteor  bertscore       use
# 0  0.666667  0.622638   0.928030  0.797535
# 1  0.357143  0.336729   0.861152  0.714165
# 2  0.153846  0.080645   0.709131  0.704500
# 3  0.142857  0.057471   0.727882  0.680623
# 4  0.857143  0.855159   0.976179  0.904624
# 5  0.750000  0.680240   0.912429  0.794857
# 6  0.631579  0.798148   0.900351  0.787268

# %%
target =     "who has the power to do anything"

prediction = "who among us has the power"

eval.evaluate(prediction, target)
eval.get_history()
# Out:
#                                                                      target  \
# 0            who has the power to approve or veto legislation constitution?
# 1  who scored the game winning run in the last inning of last night's game?
# 2                                                  Who won Super Bowl XLIX?
# 3                                    what is the role of hcl in the stomach
# 4                                          who has the power to do anything
# 5                                who has the power to do anything they want
# 6                                          who has the power to do anything
# 7                                          who has the power to do anything
#
#                                                          prediction      bleu  \
# 0                                 who has the power to veto a bill?  0.388751
# 1  what player scored the final run in yesterday's match to win it?  0.000000
# 2                         who did the broncos play in the superbowl  0.000000
# 3                                   What does hydrochloric acid do?  0.000000
# 4                                   who has the power to do nothing  0.809107
# 5                                   who has the power to do nothing  0.608025
# 6         who has the power to do nothing except for what they must  0.417226
# 7                                        who among us has the power  0.000000
#
#      rougeL    meteor  bertscore       use
# 0  0.666667  0.622638   0.928030  0.797535
# 1  0.357143  0.336729   0.861152  0.714165
# 2  0.153846  0.080645   0.709131  0.704500
# 3  0.142857  0.057471   0.727882  0.680623
# 4  0.857143  0.855159   0.976179  0.904624
# 5  0.750000  0.680240   0.912429  0.794857
# 6  0.631579  0.798148   0.900351  0.787268
# 7  0.615385  0.543478   0.826104  0.621501

# %%
target =     "this is small test"

prediction = "this is a test"

eval.evaluate(prediction, target)
eval.get_history()
# Out:
#                                                                      target  \
# 0            who has the power to approve or veto legislation constitution?
# 1  who scored the game winning run in the last inning of last night's game?
# 2                                                  Who won Super Bowl XLIX?
# 3                                    what is the role of hcl in the stomach
# 4                                          who has the power to do anything
# 5                                who has the power to do anything they want
# 6                                          who has the power to do anything
# 7                                          who has the power to do anything
# 8                                                        this is small test
#
#                                                          prediction      bleu  \
# 0                                 who has the power to veto a bill?  0.388751
# 1  what player scored the final run in yesterday's match to win it?  0.000000
# 2                         who did the broncos play in the superbowl  0.000000
# 3                                   What does hydrochloric acid do?  0.000000
# 4                                   who has the power to do nothing  0.809107
# 5                                   who has the power to do nothing  0.608025
# 6         who has the power to do nothing except for what they must  0.417226
# 7                                        who among us has the power  0.000000
# 8                                                    this is a test  0.000000
#
#      rougeL    meteor  bertscore       use
# 0  0.666667  0.622638   0.928030  0.797535
# 1  0.357143  0.336729   0.861152  0.714165
# 2  0.153846  0.080645   0.709131  0.704500
# 3  0.142857  0.057471   0.727882  0.680623
# 4  0.857143  0.855159   0.976179  0.904624
# 5  0.750000  0.680240   0.912429  0.794857
# 6  0.631579  0.798148   0.900351  0.787268
# 7  0.615385  0.543478   0.826104  0.621501
# 8  0.750000  0.638889   0.897430  0.708941

# %%
target =     "one two three four hiya"

prediction = "one two three four cheese"

eval.evaluate(prediction, target)
eval.get_history()
# Out:
#                                                                      target  \
# 0            who has the power to approve or veto legislation constitution?
# 1  who scored the game winning run in the last inning of last night's game?
# 2                                                  Who won Super Bowl XLIX?
# 3                                    what is the role of hcl in the stomach
# 4                                          who has the power to do anything
# 5                                who has the power to do anything they want
# 6                                          who has the power to do anything
# 7                                          who has the power to do anything
# 8                                                        this is small test
# 9                                                   one two three four hiya
#
#                                                          prediction      bleu  \
# 0                                 who has the power to veto a bill?  0.388751
# 1  what player scored the final run in yesterday's match to win it?  0.000000
# 2                         who did the broncos play in the superbowl  0.000000
# 3                                   What does hydrochloric acid do?  0.000000
# 4                                   who has the power to do nothing  0.809107
# 5                                   who has the power to do nothing  0.608025
# 6         who has the power to do nothing except for what they must  0.417226
# 7                                        who among us has the power  0.000000
# 8                                                    this is a test  0.000000
# 9                                         one two three four cheese  0.668740
#
#      rougeL    meteor  bertscore       use
# 0  0.666667  0.622638   0.928030  0.797535
# 1  0.357143  0.336729   0.861152  0.714165
# 2  0.153846  0.080645   0.709131  0.704500
# 3  0.142857  0.057471   0.727882  0.680623
# 4  0.857143  0.855159   0.976179  0.904624
# 5  0.750000  0.680240   0.912429  0.794857
# 6  0.631579  0.798148   0.900351  0.787268
# 7  0.615385  0.543478   0.826104  0.621501
# 8  0.750000  0.638889   0.897430  0.708941
# 9  0.800000  0.793750   0.915571  0.643950

# %%
target =     "one two three go"

prediction = "one two three no"

eval.evaluate(prediction, target)
eval.get_history()
# Out:
#                                                                       target  \
# 0             who has the power to approve or veto legislation constitution?
# 1   who scored the game winning run in the last inning of last night's game?
# 2                                                   Who won Super Bowl XLIX?
# 3                                     what is the role of hcl in the stomach
# 4                                           who has the power to do anything
# 5                                 who has the power to do anything they want
# 6                                           who has the power to do anything
# 7                                           who has the power to do anything
# 8                                                         this is small test
# 9                                                    one two three four hiya
# 10                                                          one two three go
#
#                                                           prediction  \
# 0                                  who has the power to veto a bill?
# 1   what player scored the final run in yesterday's match to win it?
# 2                          who did the broncos play in the superbowl
# 3                                    What does hydrochloric acid do?
# 4                                    who has the power to do nothing
# 5                                    who has the power to do nothing
# 6          who has the power to do nothing except for what they must
# 7                                         who among us has the power
# 8                                                     this is a test
# 9                                          one two three four cheese
# 10                                                  one two three no
#
#         bleu    rougeL    meteor  bertscore       use
# 0   0.388751  0.666667  0.622638   0.928030  0.797535
# 1   0.000000  0.357143  0.336729   0.861152  0.714165
# 2   0.000000  0.153846  0.080645   0.709131  0.704500
# 3   0.000000  0.142857  0.057471   0.727882  0.680623
# 4   0.809107  0.857143  0.855159   0.976179  0.904624
# 5   0.608025  0.750000  0.680240   0.912429  0.794857
# 6   0.417226  0.631579  0.798148   0.900351  0.787268
# 7   0.000000  0.615385  0.543478   0.826104  0.621501
# 8   0.000000  0.750000  0.638889   0.897430  0.708941
# 9   0.668740  0.800000  0.793750   0.915571  0.643950
# 10  0.000000  0.750000  0.736111   0.953222  0.795256

# %%
target =     "one two three four okay woah"

prediction = "one two three four no"

eval.evaluate(prediction, target)
eval.get_history()
# Out:
#                                                                       target  \
# 0             who has the power to approve or veto legislation constitution?
# 1   who scored the game winning run in the last inning of last night's game?
# 2                                                   Who won Super Bowl XLIX?
# 3                                     what is the role of hcl in the stomach
# 4                                           who has the power to do anything
# 5                                 who has the power to do anything they want
# 6                                           who has the power to do anything
# 7                                           who has the power to do anything
# 8                                                         this is small test
# 9                                                    one two three four hiya
# 10                                                          one two three go
# 11                                              one two three four okay woah
#
#                                                           prediction  \
# 0                                  who has the power to veto a bill?
# 1   what player scored the final run in yesterday's match to win it?
# 2                          who did the broncos play in the superbowl
# 3                                    What does hydrochloric acid do?
# 4                                    who has the power to do nothing
# 5                                    who has the power to do nothing
# 6          who has the power to do nothing except for what they must
# 7                                         who among us has the power
# 8                                                     this is a test
# 9                                          one two three four cheese
# 10                                                  one two three no
# 11                                             one two three four no
#
#         bleu    rougeL    meteor  bertscore       use
# 0   0.388751  0.666667  0.622638   0.928030  0.797535
# 1   0.000000  0.357143  0.336729   0.861152  0.714165
# 2   0.000000  0.153846  0.080645   0.709131  0.704500
# 3   0.000000  0.142857  0.057471   0.727882  0.680623
# 4   0.809107  0.857143  0.855159   0.976179  0.904624
# 5   0.608025  0.750000  0.680240   0.912429  0.794857
# 6   0.417226  0.631579  0.798148   0.900351  0.787268
# 7   0.000000  0.615385  0.543478   0.826104  0.621501
# 8   0.000000  0.750000  0.638889   0.897430  0.708941
# 9   0.668740  0.800000  0.793750   0.915571  0.643950
# 10  0.000000  0.750000  0.736111   0.953222  0.795256
# 11  0.547518  0.727273  0.672669   0.920958  0.708617

# %%
target =     "three two one go"

prediction = "one two three go"

eval.evaluate(prediction, target)
eval.get_history()
# Out:
#                                                                       target  \
# 0             who has the power to approve or veto legislation constitution?
# 1   who scored the game winning run in the last inning of last night's game?
# 2                                                   Who won Super Bowl XLIX?
# 3                                     what is the role of hcl in the stomach
# 4                                           who has the power to do anything
# 5                                 who has the power to do anything they want
# 6                                           who has the power to do anything
# 7                                           who has the power to do anything
# 8                                                         this is small test
# 9                                                    one two three four hiya
# 10                                                          one two three go
# 11                                              one two three four okay woah
# 12                                                          three two one go
#
#                                                           prediction  \
# 0                                  who has the power to veto a bill?
# 1   what player scored the final run in yesterday's match to win it?
# 2                          who did the broncos play in the superbowl
# 3                                    What does hydrochloric acid do?
# 4                                    who has the power to do nothing
# 5                                    who has the power to do nothing
# 6          who has the power to do nothing except for what they must
# 7                                         who among us has the power
# 8                                                     this is a test
# 9                                          one two three four cheese
# 10                                                  one two three no
# 11                                             one two three four no
# 12                                                  one two three go
#
#         bleu    rougeL    meteor  bertscore       use
# 0   0.388751  0.666667  0.622638   0.928030  0.797535
# 1   0.000000  0.357143  0.336729   0.861152  0.714165
# 2   0.000000  0.153846  0.080645   0.709131  0.704500
# 3   0.000000  0.142857  0.057471   0.727882  0.680623
# 4   0.809107  0.857143  0.855159   0.976179  0.904624
# 5   0.608025  0.750000  0.680240   0.912429  0.794857
# 6   0.417226  0.631579  0.798148   0.900351  0.787268
# 7   0.000000  0.615385  0.543478   0.826104  0.621501
# 8   0.000000  0.750000  0.638889   0.897430  0.708941
# 9   0.668740  0.800000  0.793750   0.915571  0.643950
# 10  0.000000  0.750000  0.736111   0.953222  0.795256
# 11  0.547518  0.727273  0.672669   0.920958  0.708617
# 12  0.000000  0.500000  0.500000   0.944940  0.757540
